# %% [markdown]
# # RPM 0% Noise

# %%
from scipy.io import loadmat, savemat
import os
import numpy as np
import math
import random
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.normal import Normal
from torch.distributions.kl import kl_divergence
from torch.nn import BCEWithLogitsLoss
from util import VNet3
from torch.distributions.beta import Beta
import pandas as pd

def evaluate_likelihood(Y, score):#, sigma
    s = torch.sigmoid(score)
    likelihood = s ** Y * (1 - s) ** (1 - Y)
    return likelihood

test_acc = []

for k in range(5):
    
    
    data = loadmat('./heart_{}.mat'.format(k+1))
    X_train = torch.tensor(data['X_train'], dtype=torch.float32)
    y_train = torch.tensor(data['y_train'], dtype=torch.float32)
    X_meta = torch.tensor(data['X_meta'], dtype=torch.float32)
    y_meta = torch.tensor(data['y_meta'], dtype=torch.float32)
    X_test = torch.tensor(data['X_test'], dtype=torch.float32)
    y_test = torch.tensor(data['y_test'], dtype=torch.float32)
    print(X_train.shape[0], X_meta.shape[0], X_test.shape[0])
    
    l = 1000

    Y_train = y_train.repeat(l, 1).t()
    Y_test = y_test.repeat(l, 1).t()
    Y_meta = y_meta.repeat(l, 1).t()
    
    n, p = np.shape(X_train)
    p = p + 1
    
    
    lam = 100
    beta_prior = MultivariateNormal(loc=torch.zeros(p), covariance_matrix=lam * torch.eye(p))
    v_prior = Beta(0.01 * torch.ones(n), 0.01 * torch.ones(n))

    
    mu = torch.zeros(p, requires_grad=True)
    v_log_diag = torch.rand([p], requires_grad=True)
    v_non_diag = torch.randn([int(p * (p - 1) / 2)], requires_grad=True)
    L_indices_non_diag = torch.tril_indices(row=p, col=p, offset=-1)
    a = torch.rand(n, requires_grad=True)
    b = torch.rand(n, requires_grad=True)

    
    likelihood = BCEWithLogitsLoss(reduction='sum')

    
    l = 1000
    Y_train = y_train.repeat(l, 1).t()

    optimizer = torch.optim.Adam([mu, v_log_diag, v_non_diag, a, b], lr=0.01)

    num_iters = 1000

    loss_all = []

    for iters in range(num_iters):
        
        L = torch.diag(torch.exp(v_log_diag))
        L[L_indices_non_diag[0], L_indices_non_diag[1]] = v_non_diag

        
        beta_post = MultivariateNormal(loc=mu, scale_tril=L)

        
        beta = beta_post.rsample(sample_shape=[l])
    
        v_post = Beta(a, b)
        v = v_post.rsample(sample_shape=[l])

        # pred_logit = torch.matmul(X_train, beta.t())
        pred_logit = torch.matmul(X_train, beta[:,:p-1].t()) + beta[:,p-1].repeat(X_train.shape[0], 1)
        likeli = evaluate_likelihood(Y_train, pred_logit) + 1e-40
        loss = - (v.mean(dim = 0) * torch.log(likeli).mean(dim = 1)).mean() + kl_divergence(beta_post, beta_prior) + kl_divergence(v_post, v_prior).sum()
    
        print(iters, loss.item(), mu[:2])

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_all.append(loss.item())

    print(loss_all[0])
    print(loss_all[-1])
    print(mu)

    plt.plot(loss_all)
    plt.show()
    
    y_test[y_test == 0] = -1
    
    def acc_cal(a,b):
        
        l = a.shape[0]
        assert l == b.shape[0]
    
        t = torch.sign(a * b)
        hit = t[t>0].shape[0]
        # hit = torch.sign(a*b).sum()
    
        return hit / l

    beta_post = MultivariateNormal(loc = mu, scale_tril = L)
    wb = beta_post.rsample(sample_shape=[l])
    aa = torch.matmul(X_test, wb[:,:p-1].t()) + wb[:,p-1].repeat(X_test.shape[0], 1)
    acc = acc_cal(aa.mean(dim = 1), y_test[0])
    test_acc.append(acc)

    print(k+1, test_acc)
# Out:
# 121 28 152
# 0 307.4669189453125 tensor([0., 0.], grad_fn=<SliceBackward>)
# 1 302.3105163574219 tensor([0.0100, 0.0100], grad_fn=<SliceBackward>)
# 2 298.23931884765625 tensor([0.0200, 0.0200], grad_fn=<SliceBackward>)
# 3 293.1122741699219 tensor([0.0300, 0.0300], grad_fn=<SliceBackward>)
# 4 287.5340881347656 tensor([0.0400, 0.0400], grad_fn=<SliceBackward>)
# 5 283.4522399902344 tensor([0.0499, 0.0500], grad_fn=<SliceBackward>)
# 6 277.0639953613281 tensor([0.0599, 0.0599], grad_fn=<SliceBackward>)
# 7 272.54632568359375 tensor([0.0697, 0.0699], grad_fn=<SliceBackward>)
# 8 272.16583251953125 tensor([0.0796, 0.0798], grad_fn=<SliceBackward>)
# 9 262.3485107421875 tensor([0.0895, 0.0897], grad_fn=<SliceBackward>)
# 10 260.9425354003906 tensor([0.0995, 0.0996], grad_fn=<SliceBackward>)
# 11 263.331787109375 tensor([0.1095, 0.1095], grad_fn=<SliceBackward>)
# 12 249.06935119628906 tensor([0.1195, 0.1194], grad_fn=<SliceBackward>)
# 13 246.7637481689453 tensor([0.1296, 0.1292], grad_fn=<SliceBackward>)
# 14 270.66204833984375 tensor([0.1397, 0.1391], grad_fn=<SliceBackward>)
# 15 250.86273193359375 tensor([0.1497, 0.1489], grad_fn=<SliceBackward>)
# 16 232.0293426513672 tensor([0.1598, 0.1587], grad_fn=<SliceBackward>)
# 17 236.1030731201172 tensor([0.1699, 0.1685], grad_fn=<SliceBackward>)
# 18 234.0817108154297 tensor([0.1799, 0.1782], grad_fn=<SliceBackward>)
# 19 230.14190673828125 tensor([0.1899, 0.1879], grad_fn=<SliceBackward>)
# 20 221.39353942871094 tensor([0.1998, 0.1976], grad_fn=<SliceBackward>)
# 21 376.47882080078125 tensor([0.2095, 0.2072], grad_fn=<SliceBackward>)
# 22 207.26541137695312 tensor([0.2192, 0.2169], grad_fn=<SliceBackward>)
# 23 202.79026794433594 tensor([0.2287, 0.2265], grad_fn=<SliceBackward>)
# 24 206.60797119140625 tensor([0.2381, 0.2361], grad_fn=<SliceBackward>)
# 25 203.9779510498047 tensor([0.2475, 0.2457], grad_fn=<SliceBackward>)
# 26 195.20596313476562 tensor([0.2568, 0.2553], grad_fn=<SliceBackward>)
# 27 194.03753662109375 tensor([0.2661, 0.2650], grad_fn=<SliceBackward>)
# 28 194.37078857421875 tensor([0.2753, 0.2746], grad_fn=<SliceBackward>)
# 29 68.6650619506836 tensor([0.2845, 0.2844], grad_fn=<SliceBackward>)
# 30 176.30235290527344 tensor([0.2937, 0.2942], grad_fn=<SliceBackward>)
# 31 184.80099487304688 tensor([0.3026, 0.3039], grad_fn=<SliceBackward>)
# 32 182.02066040039062 tensor([0.3113, 0.3136], grad_fn=<SliceBackward>)
# 33 171.51773071289062 tensor([0.3196, 0.3234], grad_fn=<SliceBackward>)
# 34 150.7818145751953 tensor([0.3278, 0.3333], grad_fn=<SliceBackward>)
# 35 142.0924835205078 tensor([0.3358, 0.3431], grad_fn=<SliceBackward>)
# 36 163.9267578125 tensor([0.3437, 0.3530], grad_fn=<SliceBackward>)
# 37 163.29478454589844 tensor([0.3514, 0.3629], grad_fn=<SliceBackward>)
# 38 130.8762969970703 tensor([0.3588, 0.3730], grad_fn=<SliceBackward>)
# 39 153.320556640625 tensor([0.3659, 0.3830], grad_fn=<SliceBackward>)
# 40 165.91119384765625 tensor([0.3729, 0.3930], grad_fn=<SliceBackward>)
# 41 150.8201904296875 tensor([0.3797, 0.4030], grad_fn=<SliceBackward>)
# 42 137.25392150878906 tensor([0.3862, 0.4130], grad_fn=<SliceBackward>)
# 43 146.46653747558594 tensor([0.3924, 0.4230], grad_fn=<SliceBackward>)
# 44 135.7547149658203 tensor([0.3984, 0.4330], grad_fn=<SliceBackward>)
# 45 140.9773406982422 tensor([0.4040, 0.4428], grad_fn=<SliceBackward>)
# 46 164.34007263183594 tensor([0.4096, 0.4527], grad_fn=<SliceBackward>)
# 47 111.123046875 tensor([0.4151, 0.4625], grad_fn=<SliceBackward>)
# 48 80.75271606445312 tensor([0.4204, 0.4721], grad_fn=<SliceBackward>)
# 49 122.48786163330078 tensor([0.4258, 0.4818], grad_fn=<SliceBackward>)
# 50 174.67828369140625 tensor([0.4314, 0.4913], grad_fn=<SliceBackward>)
# 51 97.07469177246094 tensor([0.4372, 0.5007], grad_fn=<SliceBackward>)
# 52 110.69949340820312 tensor([0.4430, 0.5101], grad_fn=<SliceBackward>)
# 53 95.93955993652344 tensor([0.4493, 0.5193], grad_fn=<SliceBackward>)
# 54 102.25912475585938 tensor([0.4560, 0.5285], grad_fn=<SliceBackward>)
# 55 89.79679107666016 tensor([0.4626, 0.5375], grad_fn=<SliceBackward>)
# 56 92.43215942382812 tensor([0.4695, 0.5465], grad_fn=<SliceBackward>)
# 57 105.67302703857422 tensor([0.4766, 0.5554], grad_fn=<SliceBackward>)
# 58 93.37822723388672 tensor([0.4835, 0.5642], grad_fn=<SliceBackward>)
# 59 105.67093658447266 tensor([0.4905, 0.5731], grad_fn=<SliceBackward>)
# 60 98.50234985351562 tensor([0.4975, 0.5819], grad_fn=<SliceBackward>)
# 61 151.6165008544922 tensor([0.5046, 0.5907], grad_fn=<SliceBackward>)
# 62 96.23853302001953 tensor([0.5116, 0.5994], grad_fn=<SliceBackward>)
# 63 89.09626770019531 tensor([0.5187, 0.6080], grad_fn=<SliceBackward>)
# 64 85.17886352539062 tensor([0.5259, 0.6165], grad_fn=<SliceBackward>)
# 65 77.67974090576172 tensor([0.5332, 0.6250], grad_fn=<SliceBackward>)
# 66 82.16831970214844 tensor([0.5407, 0.6334], grad_fn=<SliceBackward>)
# 67 55.284461975097656 tensor([0.5482, 0.6418], grad_fn=<SliceBackward>)
# 68 196.02880859375 tensor([0.5560, 0.6501], grad_fn=<SliceBackward>)
# 69 79.38084411621094 tensor([0.5635, 0.6585], grad_fn=<SliceBackward>)
# 70 28.08823013305664 tensor([0.5710, 0.6671], grad_fn=<SliceBackward>)
# 71 71.25355529785156 tensor([0.5785, 0.6757], grad_fn=<SliceBackward>)
# 72 89.15762329101562 tensor([0.5861, 0.6843], grad_fn=<SliceBackward>)
# 73 73.60920715332031 tensor([0.5937, 0.6928], grad_fn=<SliceBackward>)
# 74 75.89717864990234 tensor([0.6014, 0.7013], grad_fn=<SliceBackward>)
# 75 82.48298645019531 tensor([0.6088, 0.7099], grad_fn=<SliceBackward>)
# 76 79.09414672851562 tensor([0.6161, 0.7184], grad_fn=<SliceBackward>)
# 77 71.2814712524414 tensor([0.6233, 0.7269], grad_fn=<SliceBackward>)
# 78 76.81745147705078 tensor([0.6306, 0.7353], grad_fn=<SliceBackward>)
# 79 73.51872253417969 tensor([0.6378, 0.7436], grad_fn=<SliceBackward>)
# 80 101.79829406738281 tensor([0.6450, 0.7518], grad_fn=<SliceBackward>)
# 81 66.41727447509766 tensor([0.6523, 0.7599], grad_fn=<SliceBackward>)
# 82 67.21736145019531 tensor([0.6594, 0.7678], grad_fn=<SliceBackward>)
# 83 -211.39630126953125 tensor([0.6663, 0.7756], grad_fn=<SliceBackward>)
# 84 61.66615676879883 tensor([0.6731, 0.7834], grad_fn=<SliceBackward>)
# 85 67.3506088256836 tensor([0.6794, 0.7913], grad_fn=<SliceBackward>)
# 86 72.83328247070312 tensor([0.6855, 0.7991], grad_fn=<SliceBackward>)
# 87 70.40057373046875 tensor([0.6912, 0.8068], grad_fn=<SliceBackward>)
# 88 62.548152923583984 tensor([0.6966, 0.8144], grad_fn=<SliceBackward>)
# 89 63.0018196105957 tensor([0.7019, 0.8218], grad_fn=<SliceBackward>)
# 90 41.241825103759766 tensor([0.7070, 0.8292], grad_fn=<SliceBackward>)
# 91 82.7455062866211 tensor([0.7120, 0.8364], grad_fn=<SliceBackward>)
# 92 75.71780395507812 tensor([0.7168, 0.8435], grad_fn=<SliceBackward>)
# 93 62.35871124267578 tensor([0.7217, 0.8505], grad_fn=<SliceBackward>)
# 94 73.87301635742188 tensor([0.7265, 0.8573], grad_fn=<SliceBackward>)
# 95 73.99501037597656 tensor([0.7314, 0.8641], grad_fn=<SliceBackward>)
# 96 74.3190689086914 tensor([0.7361, 0.8708], grad_fn=<SliceBackward>)
# 97 74.37116241455078 tensor([0.7409, 0.8773], grad_fn=<SliceBackward>)
# 98 74.54975891113281 tensor([0.7456, 0.8838], grad_fn=<SliceBackward>)
# 99 74.67407989501953 tensor([0.7503, 0.8902], grad_fn=<SliceBackward>)
# 100 74.45533752441406 tensor([0.7548, 0.8966], grad_fn=<SliceBackward>)
# 101 74.10331726074219 tensor([0.7592, 0.9029], grad_fn=<SliceBackward>)
# 102 73.85892486572266 tensor([0.7638, 0.9092], grad_fn=<SliceBackward>)
# 103 77.35123443603516 tensor([0.7684, 0.9154], grad_fn=<SliceBackward>)
# 104 73.19058990478516 tensor([0.7731, 0.9216], grad_fn=<SliceBackward>)
# 105 73.1537094116211 tensor([0.7778, 0.9279], grad_fn=<SliceBackward>)
# 106 72.96407318115234 tensor([0.7825, 0.9341], grad_fn=<SliceBackward>)
# 107 72.6296615600586 tensor([0.7869, 0.9403], grad_fn=<SliceBackward>)
# 108 72.27334594726562 tensor([0.7913, 0.9466], grad_fn=<SliceBackward>)
# 109 71.93794250488281 tensor([0.7956, 0.9529], grad_fn=<SliceBackward>)
# 110 71.7099838256836 tensor([0.7996, 0.9592], grad_fn=<SliceBackward>)
# 111 71.43209838867188 tensor([0.8034, 0.9655], grad_fn=<SliceBackward>)
# 112 71.04878234863281 tensor([0.8071, 0.9717], grad_fn=<SliceBackward>)
# 113 70.6279296875 tensor([0.8107, 0.9780], grad_fn=<SliceBackward>)
# 114 70.25071716308594 tensor([0.8141, 0.9843], grad_fn=<SliceBackward>)
# 115 69.95661163330078 tensor([0.8174, 0.9905], grad_fn=<SliceBackward>)
# 116 69.56407928466797 tensor([0.8205, 0.9967], grad_fn=<SliceBackward>)
# 117 69.23837280273438 tensor([0.8235, 1.0030], grad_fn=<SliceBackward>)
# 118 68.89301300048828 tensor([0.8263, 1.0091], grad_fn=<SliceBackward>)
# 119 68.52124786376953 tensor([0.8289, 1.0153], grad_fn=<SliceBackward>)
# 120 68.10830688476562 tensor([0.8315, 1.0214], grad_fn=<SliceBackward>)
# 121 67.48853302001953 tensor([0.8339, 1.0275], grad_fn=<SliceBackward>)
# 122 67.40079498291016 tensor([0.8362, 1.0336], grad_fn=<SliceBackward>)
# 123 67.2333755493164 tensor([0.8385, 1.0397], grad_fn=<SliceBackward>)
# 124 66.9031982421875 tensor([0.8409, 1.0458], grad_fn=<SliceBackward>)
# 125 66.73163604736328 tensor([0.8433, 1.0519], grad_fn=<SliceBackward>)
# 126 66.66036987304688 tensor([0.8456, 1.0579], grad_fn=<SliceBackward>)
# 127 66.10789489746094 tensor([0.8477, 1.0639], grad_fn=<SliceBackward>)
# 128 65.84719848632812 tensor([0.8497, 1.0698], grad_fn=<SliceBackward>)
# 129 65.71575927734375 tensor([0.8518, 1.0757], grad_fn=<SliceBackward>)
# 130 65.24461364746094 tensor([0.8537, 1.0816], grad_fn=<SliceBackward>)
# 131 64.98554229736328 tensor([0.8555, 1.0875], grad_fn=<SliceBackward>)
# 132 64.80142211914062 tensor([0.8575, 1.0933], grad_fn=<SliceBackward>)
# 133 64.57594299316406 tensor([0.8594, 1.0991], grad_fn=<SliceBackward>)
# 134 64.10169219970703 tensor([0.8614, 1.1050], grad_fn=<SliceBackward>)
# 135 64.13993072509766 tensor([0.8633, 1.1108], grad_fn=<SliceBackward>)
# 136 63.6897087097168 tensor([0.8651, 1.1166], grad_fn=<SliceBackward>)
# 137 63.689117431640625 tensor([0.8668, 1.1225], grad_fn=<SliceBackward>)
# 138 63.37433624267578 tensor([0.8686, 1.1283], grad_fn=<SliceBackward>)
# 139 63.179351806640625 tensor([0.8704, 1.1341], grad_fn=<SliceBackward>)
# 140 62.89430618286133 tensor([0.8721, 1.1399], grad_fn=<SliceBackward>)
# 141 62.47304153442383 tensor([0.8739, 1.1458], grad_fn=<SliceBackward>)
# 142 62.322914123535156 tensor([0.8756, 1.1517], grad_fn=<SliceBackward>)
# 143 61.896934509277344 tensor([0.8775, 1.1576], grad_fn=<SliceBackward>)
# 144 61.62550354003906 tensor([0.8794, 1.1635], grad_fn=<SliceBackward>)
# 145 61.47129821777344 tensor([0.8813, 1.1693], grad_fn=<SliceBackward>)
# 146 61.21260070800781 tensor([0.8831, 1.1752], grad_fn=<SliceBackward>)
# 147 60.933223724365234 tensor([0.8848, 1.1810], grad_fn=<SliceBackward>)
# 148 60.779388427734375 tensor([0.8866, 1.1868], grad_fn=<SliceBackward>)
# 149 60.57752990722656 tensor([0.8883, 1.1927], grad_fn=<SliceBackward>)
# 150 60.32946014404297 tensor([0.8902, 1.1985], grad_fn=<SliceBackward>)
# 151 60.0089111328125 tensor([0.8920, 1.2044], grad_fn=<SliceBackward>)
# 152 59.95577621459961 tensor([0.8940, 1.2103], grad_fn=<SliceBackward>)
# 153 59.510108947753906 tensor([0.8961, 1.2162], grad_fn=<SliceBackward>)
# 154 59.256568908691406 tensor([0.8981, 1.2221], grad_fn=<SliceBackward>)
# 155 58.78461837768555 tensor([0.9002, 1.2280], grad_fn=<SliceBackward>)
# 156 58.687400817871094 tensor([0.9021, 1.2340], grad_fn=<SliceBackward>)
# 157 58.501399993896484 tensor([0.9041, 1.2400], grad_fn=<SliceBackward>)
# 158 58.0476188659668 tensor([0.9060, 1.2460], grad_fn=<SliceBackward>)
# 159 57.893104553222656 tensor([0.9080, 1.2520], grad_fn=<SliceBackward>)
# 160 57.8023681640625 tensor([0.9101, 1.2580], grad_fn=<SliceBackward>)
# 161 57.66383743286133 tensor([0.9121, 1.2640], grad_fn=<SliceBackward>)
# 162 57.45472717285156 tensor([0.9141, 1.2700], grad_fn=<SliceBackward>)
# 163 57.224605560302734 tensor([0.9162, 1.2760], grad_fn=<SliceBackward>)
# 164 56.81732940673828 tensor([0.9184, 1.2820], grad_fn=<SliceBackward>)
# 165 56.84063720703125 tensor([0.9206, 1.2881], grad_fn=<SliceBackward>)
# 166 56.463584899902344 tensor([0.9229, 1.2942], grad_fn=<SliceBackward>)
# 167 56.334190368652344 tensor([0.9251, 1.3002], grad_fn=<SliceBackward>)
# 168 56.18252944946289 tensor([0.9273, 1.3063], grad_fn=<SliceBackward>)
# 169 55.827178955078125 tensor([0.9295, 1.3124], grad_fn=<SliceBackward>)
# 170 55.53002166748047 tensor([0.9316, 1.3185], grad_fn=<SliceBackward>)
# 171 55.23999786376953 tensor([0.9337, 1.3246], grad_fn=<SliceBackward>)
# 172 55.06793212890625 tensor([0.9358, 1.3306], grad_fn=<SliceBackward>)
# 173 54.94439697265625 tensor([0.9378, 1.3367], grad_fn=<SliceBackward>)
# 174 54.81641387939453 tensor([0.9396, 1.3428], grad_fn=<SliceBackward>)
# 175 54.59714889526367 tensor([0.9415, 1.3488], grad_fn=<SliceBackward>)
# 176 54.206661224365234 tensor([0.9433, 1.3549], grad_fn=<SliceBackward>)
# 177 54.099525451660156 tensor([0.9451, 1.3609], grad_fn=<SliceBackward>)
# 178 53.7442741394043 tensor([0.9467, 1.3670], grad_fn=<SliceBackward>)
# 179 53.667877197265625 tensor([0.9484, 1.3730], grad_fn=<SliceBackward>)
# 180 53.27082824707031 tensor([0.9500, 1.3790], grad_fn=<SliceBackward>)
# 181 53.1429557800293 tensor([0.9518, 1.3850], grad_fn=<SliceBackward>)
# 182 53.02333450317383 tensor([0.9537, 1.3910], grad_fn=<SliceBackward>)
# 183 52.65186309814453 tensor([0.9555, 1.3970], grad_fn=<SliceBackward>)
# 184 52.63568115234375 tensor([0.9572, 1.4029], grad_fn=<SliceBackward>)
# 185 52.1492919921875 tensor([0.9589, 1.4089], grad_fn=<SliceBackward>)
# 186 52.029136657714844 tensor([0.9604, 1.4148], grad_fn=<SliceBackward>)
# 187 51.928871154785156 tensor([0.9621, 1.4206], grad_fn=<SliceBackward>)
# 188 51.65122985839844 tensor([0.9637, 1.4264], grad_fn=<SliceBackward>)
# 189 51.518409729003906 tensor([0.9654, 1.4323], grad_fn=<SliceBackward>)
# 190 50.982147216796875 tensor([0.9670, 1.4380], grad_fn=<SliceBackward>)
# 191 50.700767517089844 tensor([0.9686, 1.4438], grad_fn=<SliceBackward>)
# 192 50.60057830810547 tensor([0.9703, 1.4494], grad_fn=<SliceBackward>)
# 193 50.202239990234375 tensor([0.9719, 1.4551], grad_fn=<SliceBackward>)
# 194 50.01007080078125 tensor([0.9736, 1.4607], grad_fn=<SliceBackward>)
# 195 49.743324279785156 tensor([0.9754, 1.4662], grad_fn=<SliceBackward>)
# 196 49.1842155456543 tensor([0.9771, 1.4718], grad_fn=<SliceBackward>)
# 197 48.788536071777344 tensor([0.9788, 1.4774], grad_fn=<SliceBackward>)
# 198 48.76201629638672 tensor([0.9805, 1.4829], grad_fn=<SliceBackward>)
# 199 48.391334533691406 tensor([0.9823, 1.4884], grad_fn=<SliceBackward>)
# 200 48.43852615356445 tensor([0.9842, 1.4939], grad_fn=<SliceBackward>)
# 201 48.11570739746094 tensor([0.9863, 1.4993], grad_fn=<SliceBackward>)
# 202 47.81813049316406 tensor([0.9885, 1.5048], grad_fn=<SliceBackward>)
# 203 47.65729522705078 tensor([0.9908, 1.5102], grad_fn=<SliceBackward>)
# 204 47.07672882080078 tensor([0.9933, 1.5156], grad_fn=<SliceBackward>)
# 205 47.2587890625 tensor([0.9958, 1.5211], grad_fn=<SliceBackward>)
# 206 46.74620056152344 tensor([0.9984, 1.5265], grad_fn=<SliceBackward>)
# 207 46.434181213378906 tensor([1.0011, 1.5319], grad_fn=<SliceBackward>)
# 208 46.25104522705078 tensor([1.0036, 1.5372], grad_fn=<SliceBackward>)
# 209 46.105934143066406 tensor([1.0064, 1.5426], grad_fn=<SliceBackward>)
# 210 45.61116409301758 tensor([1.0094, 1.5479], grad_fn=<SliceBackward>)
# 211 45.53063201904297 tensor([1.0123, 1.5531], grad_fn=<SliceBackward>)
# 212 45.19239044189453 tensor([1.0155, 1.5583], grad_fn=<SliceBackward>)
# 213 45.1531867980957 tensor([1.0186, 1.5636], grad_fn=<SliceBackward>)
# 214 44.896732330322266 tensor([1.0216, 1.5688], grad_fn=<SliceBackward>)
# 215 44.7452278137207 tensor([1.0245, 1.5740], grad_fn=<SliceBackward>)
# 216 44.544456481933594 tensor([1.0274, 1.5792], grad_fn=<SliceBackward>)
# 217 44.14805603027344 tensor([1.0302, 1.5843], grad_fn=<SliceBackward>)
# 218 44.07179260253906 tensor([1.0329, 1.5895], grad_fn=<SliceBackward>)
# 219 43.862037658691406 tensor([1.0355, 1.5946], grad_fn=<SliceBackward>)
# 220 43.55010986328125 tensor([1.0380, 1.5998], grad_fn=<SliceBackward>)
# 221 43.4825439453125 tensor([1.0405, 1.6049], grad_fn=<SliceBackward>)
# 222 43.28010559082031 tensor([1.0429, 1.6101], grad_fn=<SliceBackward>)
# 223 43.0311393737793 tensor([1.0454, 1.6152], grad_fn=<SliceBackward>)
# 224 43.02311706542969 tensor([1.0477, 1.6203], grad_fn=<SliceBackward>)
# 225 43.00433349609375 tensor([1.0499, 1.6253], grad_fn=<SliceBackward>)
# 226 42.662208557128906 tensor([1.0521, 1.6304], grad_fn=<SliceBackward>)
# 227 42.39967346191406 tensor([1.0543, 1.6354], grad_fn=<SliceBackward>)
# 228 42.35700225830078 tensor([1.0564, 1.6405], grad_fn=<SliceBackward>)
# 229 42.06514358520508 tensor([1.0585, 1.6455], grad_fn=<SliceBackward>)
# 230 42.102325439453125 tensor([1.0605, 1.6505], grad_fn=<SliceBackward>)
# 231 41.68972396850586 tensor([1.0626, 1.6555], grad_fn=<SliceBackward>)
# 232 41.61376190185547 tensor([1.0647, 1.6605], grad_fn=<SliceBackward>)
# 233 41.91294860839844 tensor([1.0669, 1.6654], grad_fn=<SliceBackward>)
# 234 41.580810546875 tensor([1.0689, 1.6704], grad_fn=<SliceBackward>)
# 235 41.52254867553711 tensor([1.0708, 1.6754], grad_fn=<SliceBackward>)
# 236 41.246910095214844 tensor([1.0727, 1.6803], grad_fn=<SliceBackward>)
# 237 41.09539031982422 tensor([1.0746, 1.6852], grad_fn=<SliceBackward>)
# 238 40.98920822143555 tensor([1.0765, 1.6901], grad_fn=<SliceBackward>)
# 239 40.56184387207031 tensor([1.0783, 1.6950], grad_fn=<SliceBackward>)
# 240 40.55824279785156 tensor([1.0801, 1.6998], grad_fn=<SliceBackward>)
# 241 40.32710647583008 tensor([1.0818, 1.7047], grad_fn=<SliceBackward>)
# 242 40.093040466308594 tensor([1.0832, 1.7095], grad_fn=<SliceBackward>)
# 243 39.99193572998047 tensor([1.0847, 1.7144], grad_fn=<SliceBackward>)
# 244 39.80309295654297 tensor([1.0860, 1.7191], grad_fn=<SliceBackward>)
# 245 39.5372428894043 tensor([1.0873, 1.7239], grad_fn=<SliceBackward>)
# 246 39.49391174316406 tensor([1.0885, 1.7286], grad_fn=<SliceBackward>)
# 247 39.54015350341797 tensor([1.0895, 1.7334], grad_fn=<SliceBackward>)
# 248 39.18395233154297 tensor([1.0906, 1.7380], grad_fn=<SliceBackward>)
# 249 39.06465148925781 tensor([1.0918, 1.7426], grad_fn=<SliceBackward>)
# 250 38.593963623046875 tensor([1.0930, 1.7472], grad_fn=<SliceBackward>)
# 251 38.485965728759766 tensor([1.0943, 1.7518], grad_fn=<SliceBackward>)
# 252 38.16429901123047 tensor([1.0956, 1.7563], grad_fn=<SliceBackward>)
# 253 37.9100227355957 tensor([1.0968, 1.7609], grad_fn=<SliceBackward>)
# 254 37.85246276855469 tensor([1.0981, 1.7654], grad_fn=<SliceBackward>)
# 255 37.62217712402344 tensor([1.0997, 1.7699], grad_fn=<SliceBackward>)
# 256 37.321922302246094 tensor([1.1011, 1.7743], grad_fn=<SliceBackward>)
# 257 36.986541748046875 tensor([1.1026, 1.7788], grad_fn=<SliceBackward>)
# 258 36.75445556640625 tensor([1.1041, 1.7832], grad_fn=<SliceBackward>)
# 259 36.65471649169922 tensor([1.1056, 1.7876], grad_fn=<SliceBackward>)
# 260 36.597572326660156 tensor([1.1069, 1.7920], grad_fn=<SliceBackward>)
# 261 36.491912841796875 tensor([1.1083, 1.7964], grad_fn=<SliceBackward>)
# 262 36.14707946777344 tensor([1.1097, 1.8009], grad_fn=<SliceBackward>)
# 263 35.91891860961914 tensor([1.1112, 1.8052], grad_fn=<SliceBackward>)
# 264 36.033287048339844 tensor([1.1125, 1.8096], grad_fn=<SliceBackward>)
# 265 35.898963928222656 tensor([1.1139, 1.8138], grad_fn=<SliceBackward>)
# 266 35.6244010925293 tensor([1.1152, 1.8181], grad_fn=<SliceBackward>)
# 267 35.23904800415039 tensor([1.1164, 1.8223], grad_fn=<SliceBackward>)
# 268 35.35523986816406 tensor([1.1174, 1.8265], grad_fn=<SliceBackward>)
# 269 35.11589813232422 tensor([1.1184, 1.8307], grad_fn=<SliceBackward>)
# 270 34.945980072021484 tensor([1.1193, 1.8349], grad_fn=<SliceBackward>)
# 271 34.923583984375 tensor([1.1203, 1.8392], grad_fn=<SliceBackward>)
# 272 34.88666534423828 tensor([1.1211, 1.8434], grad_fn=<SliceBackward>)
# 273 34.637176513671875 tensor([1.1218, 1.8476], grad_fn=<SliceBackward>)
# 274 34.696022033691406 tensor([1.1224, 1.8518], grad_fn=<SliceBackward>)
# 275 34.56650161743164 tensor([1.1231, 1.8560], grad_fn=<SliceBackward>)
# 276 34.53993606567383 tensor([1.1237, 1.8601], grad_fn=<SliceBackward>)
# 277 34.19557189941406 tensor([1.1242, 1.8642], grad_fn=<SliceBackward>)
# 278 34.405006408691406 tensor([1.1245, 1.8683], grad_fn=<SliceBackward>)
# 279 34.359397888183594 tensor([1.1248, 1.8724], grad_fn=<SliceBackward>)
# 280 34.01781463623047 tensor([1.1252, 1.8766], grad_fn=<SliceBackward>)
# 281 34.098819732666016 tensor([1.1256, 1.8807], grad_fn=<SliceBackward>)
# 282 33.91244888305664 tensor([1.1261, 1.8849], grad_fn=<SliceBackward>)
# 283 33.95441818237305 tensor([1.1266, 1.8890], grad_fn=<SliceBackward>)
# 284 33.82730484008789 tensor([1.1271, 1.8931], grad_fn=<SliceBackward>)
# 285 33.64314651489258 tensor([1.1275, 1.8972], grad_fn=<SliceBackward>)
# 286 33.785926818847656 tensor([1.1280, 1.9012], grad_fn=<SliceBackward>)
# 287 33.42619323730469 tensor([1.1284, 1.9052], grad_fn=<SliceBackward>)
# 288 33.275596618652344 tensor([1.1287, 1.9092], grad_fn=<SliceBackward>)
# 289 33.192169189453125 tensor([1.1290, 1.9132], grad_fn=<SliceBackward>)
# 290 33.21433639526367 tensor([1.1293, 1.9171], grad_fn=<SliceBackward>)
# 291 32.966651916503906 tensor([1.1294, 1.9210], grad_fn=<SliceBackward>)
# 292 33.04648971557617 tensor([1.1297, 1.9249], grad_fn=<SliceBackward>)
# 293 32.9769287109375 tensor([1.1298, 1.9288], grad_fn=<SliceBackward>)
# 294 32.795108795166016 tensor([1.1300, 1.9326], grad_fn=<SliceBackward>)
# 295 32.773590087890625 tensor([1.1301, 1.9364], grad_fn=<SliceBackward>)
# 296 32.59397506713867 tensor([1.1303, 1.9402], grad_fn=<SliceBackward>)
# 297 32.72114562988281 tensor([1.1306, 1.9440], grad_fn=<SliceBackward>)
# 298 32.777950286865234 tensor([1.1309, 1.9477], grad_fn=<SliceBackward>)
# 299 32.54851531982422 tensor([1.1313, 1.9514], grad_fn=<SliceBackward>)
# 300 32.49736785888672 tensor([1.1318, 1.9552], grad_fn=<SliceBackward>)
# 301 32.481693267822266 tensor([1.1323, 1.9588], grad_fn=<SliceBackward>)
# 302 32.271873474121094 tensor([1.1327, 1.9625], grad_fn=<SliceBackward>)
# 303 32.2899284362793 tensor([1.1330, 1.9662], grad_fn=<SliceBackward>)
# 304 32.08586502075195 tensor([1.1336, 1.9700], grad_fn=<SliceBackward>)
# 305 32.355167388916016 tensor([1.1343, 1.9737], grad_fn=<SliceBackward>)
# 306 32.0873908996582 tensor([1.1349, 1.9774], grad_fn=<SliceBackward>)
# 307 31.958724975585938 tensor([1.1354, 1.9811], grad_fn=<SliceBackward>)
# 308 31.949508666992188 tensor([1.1360, 1.9848], grad_fn=<SliceBackward>)
# 309 31.857192993164062 tensor([1.1366, 1.9885], grad_fn=<SliceBackward>)
# 310 31.79194450378418 tensor([1.1371, 1.9922], grad_fn=<SliceBackward>)
# 311 31.60413932800293 tensor([1.1376, 1.9959], grad_fn=<SliceBackward>)
# 312 31.72446632385254 tensor([1.1381, 1.9995], grad_fn=<SliceBackward>)
# 313 31.542457580566406 tensor([1.1386, 2.0032], grad_fn=<SliceBackward>)
# 314 31.597759246826172 tensor([1.1391, 2.0069], grad_fn=<SliceBackward>)
# 315 31.27604103088379 tensor([1.1397, 2.0105], grad_fn=<SliceBackward>)
# 316 31.30571937561035 tensor([1.1403, 2.0142], grad_fn=<SliceBackward>)
# 317 31.410316467285156 tensor([1.1408, 2.0179], grad_fn=<SliceBackward>)
# 318 31.15266990661621 tensor([1.1411, 2.0217], grad_fn=<SliceBackward>)
# 319 30.952138900756836 tensor([1.1413, 2.0254], grad_fn=<SliceBackward>)
# 320 31.095176696777344 tensor([1.1414, 2.0292], grad_fn=<SliceBackward>)
# 321 30.88885498046875 tensor([1.1415, 2.0329], grad_fn=<SliceBackward>)
# 322 30.890884399414062 tensor([1.1415, 2.0367], grad_fn=<SliceBackward>)
# 323 30.604106903076172 tensor([1.1414, 2.0406], grad_fn=<SliceBackward>)
# 324 30.651935577392578 tensor([1.1414, 2.0444], grad_fn=<SliceBackward>)
# 325 30.596439361572266 tensor([1.1413, 2.0482], grad_fn=<SliceBackward>)
# 326 30.652833938598633 tensor([1.1411, 2.0520], grad_fn=<SliceBackward>)
# 327 30.62851905822754 tensor([1.1410, 2.0557], grad_fn=<SliceBackward>)
# 328 30.208850860595703 tensor([1.1409, 2.0595], grad_fn=<SliceBackward>)
# 329 30.57625389099121 tensor([1.1406, 2.0633], grad_fn=<SliceBackward>)
# 330 30.17793846130371 tensor([1.1404, 2.0670], grad_fn=<SliceBackward>)
# 331 30.16461181640625 tensor([1.1401, 2.0708], grad_fn=<SliceBackward>)
# 332 30.334514617919922 tensor([1.1398, 2.0746], grad_fn=<SliceBackward>)
# 333 30.316734313964844 tensor([1.1396, 2.0784], grad_fn=<SliceBackward>)
# 334 30.055089950561523 tensor([1.1395, 2.0821], grad_fn=<SliceBackward>)
# 335 30.221969604492188 tensor([1.1393, 2.0859], grad_fn=<SliceBackward>)
# 336 30.05533790588379 tensor([1.1391, 2.0897], grad_fn=<SliceBackward>)
# 337 30.071155548095703 tensor([1.1386, 2.0935], grad_fn=<SliceBackward>)
# 338 29.761615753173828 tensor([1.1382, 2.0973], grad_fn=<SliceBackward>)
# 339 29.799274444580078 tensor([1.1378, 2.1011], grad_fn=<SliceBackward>)
# 340 29.60999298095703 tensor([1.1373, 2.1049], grad_fn=<SliceBackward>)
# 341 29.59950065612793 tensor([1.1371, 2.1086], grad_fn=<SliceBackward>)
# 342 29.59903335571289 tensor([1.1368, 2.1123], grad_fn=<SliceBackward>)
# 343 29.6652889251709 tensor([1.1365, 2.1160], grad_fn=<SliceBackward>)
# 344 29.408117294311523 tensor([1.1361, 2.1198], grad_fn=<SliceBackward>)
# 345 29.622098922729492 tensor([1.1357, 2.1236], grad_fn=<SliceBackward>)
# 346 29.324758529663086 tensor([1.1354, 2.1273], grad_fn=<SliceBackward>)
# 347 29.4359188079834 tensor([1.1353, 2.1311], grad_fn=<SliceBackward>)
# 348 29.661529541015625 tensor([1.1354, 2.1349], grad_fn=<SliceBackward>)
# 349 29.34798240661621 tensor([1.1354, 2.1387], grad_fn=<SliceBackward>)
# 350 29.258197784423828 tensor([1.1355, 2.1426], grad_fn=<SliceBackward>)
# 351 29.100914001464844 tensor([1.1355, 2.1464], grad_fn=<SliceBackward>)
# 352 29.31374740600586 tensor([1.1356, 2.1502], grad_fn=<SliceBackward>)
# 353 29.05657958984375 tensor([1.1357, 2.1540], grad_fn=<SliceBackward>)
# 354 29.18001937866211 tensor([1.1357, 2.1577], grad_fn=<SliceBackward>)
# 355 29.089309692382812 tensor([1.1358, 2.1616], grad_fn=<SliceBackward>)
# 356 29.118642807006836 tensor([1.1362, 2.1653], grad_fn=<SliceBackward>)
# 357 28.93998908996582 tensor([1.1368, 2.1691], grad_fn=<SliceBackward>)
# 358 28.94381332397461 tensor([1.1376, 2.1729], grad_fn=<SliceBackward>)
# 359 28.874990463256836 tensor([1.1382, 2.1766], grad_fn=<SliceBackward>)
# 360 28.896678924560547 tensor([1.1388, 2.1804], grad_fn=<SliceBackward>)
# 361 28.722312927246094 tensor([1.1394, 2.1842], grad_fn=<SliceBackward>)
# 362 28.702219009399414 tensor([1.1403, 2.1880], grad_fn=<SliceBackward>)
# 363 28.83072853088379 tensor([1.1412, 2.1918], grad_fn=<SliceBackward>)
# 364 28.762020111083984 tensor([1.1422, 2.1955], grad_fn=<SliceBackward>)
# 365 28.501319885253906 tensor([1.1432, 2.1993], grad_fn=<SliceBackward>)
# 366 28.560298919677734 tensor([1.1441, 2.2031], grad_fn=<SliceBackward>)
# 367 28.45415496826172 tensor([1.1450, 2.2069], grad_fn=<SliceBackward>)
# 368 28.622364044189453 tensor([1.1456, 2.2108], grad_fn=<SliceBackward>)
# 369 28.452014923095703 tensor([1.1462, 2.2147], grad_fn=<SliceBackward>)
# 370 28.38732147216797 tensor([1.1469, 2.2185], grad_fn=<SliceBackward>)
# 371 28.092422485351562 tensor([1.1476, 2.2224], grad_fn=<SliceBackward>)
# 372 28.2349910736084 tensor([1.1484, 2.2262], grad_fn=<SliceBackward>)
# 373 28.38832664489746 tensor([1.1491, 2.2299], grad_fn=<SliceBackward>)
# 374 28.313783645629883 tensor([1.1497, 2.2335], grad_fn=<SliceBackward>)
# 375 28.30437469482422 tensor([1.1506, 2.2372], grad_fn=<SliceBackward>)
# 376 28.24958038330078 tensor([1.1514, 2.2408], grad_fn=<SliceBackward>)
# 377 28.15037727355957 tensor([1.1523, 2.2443], grad_fn=<SliceBackward>)
# 378 28.03244400024414 tensor([1.1531, 2.2479], grad_fn=<SliceBackward>)
# 379 28.130306243896484 tensor([1.1540, 2.2514], grad_fn=<SliceBackward>)
# 380 28.101585388183594 tensor([1.1548, 2.2549], grad_fn=<SliceBackward>)
# 381 27.807466506958008 tensor([1.1556, 2.2585], grad_fn=<SliceBackward>)
# 382 28.029390335083008 tensor([1.1561, 2.2621], grad_fn=<SliceBackward>)
# 383 27.96217918395996 tensor([1.1567, 2.2656], grad_fn=<SliceBackward>)
# 384 27.87712287902832 tensor([1.1572, 2.2691], grad_fn=<SliceBackward>)
# 385 27.998153686523438 tensor([1.1578, 2.2725], grad_fn=<SliceBackward>)
# 386 27.734661102294922 tensor([1.1581, 2.2759], grad_fn=<SliceBackward>)
# 387 27.936424255371094 tensor([1.1583, 2.2793], grad_fn=<SliceBackward>)
# 388 27.768230438232422 tensor([1.1585, 2.2827], grad_fn=<SliceBackward>)
# 389 27.629789352416992 tensor([1.1589, 2.2861], grad_fn=<SliceBackward>)
# 390 27.573068618774414 tensor([1.1592, 2.2894], grad_fn=<SliceBackward>)
# 391 27.862712860107422 tensor([1.1593, 2.2927], grad_fn=<SliceBackward>)
# 392 27.962682723999023 tensor([1.1594, 2.2960], grad_fn=<SliceBackward>)
# 393 27.847225189208984 tensor([1.1597, 2.2992], grad_fn=<SliceBackward>)
# 394 27.992835998535156 tensor([1.1600, 2.3024], grad_fn=<SliceBackward>)
# 395 27.694398880004883 tensor([1.1603, 2.3056], grad_fn=<SliceBackward>)
# 396 27.76984214782715 tensor([1.1606, 2.3089], grad_fn=<SliceBackward>)
# 397 27.530132293701172 tensor([1.1610, 2.3121], grad_fn=<SliceBackward>)
# 398 27.59827423095703 tensor([1.1614, 2.3152], grad_fn=<SliceBackward>)
# 399 27.524646759033203 tensor([1.1618, 2.3184], grad_fn=<SliceBackward>)
# 400 27.50295066833496 tensor([1.1622, 2.3215], grad_fn=<SliceBackward>)
# 401 27.6793212890625 tensor([1.1626, 2.3247], grad_fn=<SliceBackward>)
# 402 27.369970321655273 tensor([1.1632, 2.3278], grad_fn=<SliceBackward>)
# 403 27.51470184326172 tensor([1.1637, 2.3309], grad_fn=<SliceBackward>)
# 404 27.596431732177734 tensor([1.1643, 2.3340], grad_fn=<SliceBackward>)
# 405 27.441259384155273 tensor([1.1649, 2.3370], grad_fn=<SliceBackward>)
# 406 27.479618072509766 tensor([1.1654, 2.3400], grad_fn=<SliceBackward>)
# 407 27.483257293701172 tensor([1.1657, 2.3431], grad_fn=<SliceBackward>)
# 408 27.440919876098633 tensor([1.1660, 2.3461], grad_fn=<SliceBackward>)
# 409 27.432884216308594 tensor([1.1663, 2.3490], grad_fn=<SliceBackward>)
# 410 27.22864532470703 tensor([1.1667, 2.3520], grad_fn=<SliceBackward>)
# 411 27.34479331970215 tensor([1.1672, 2.3549], grad_fn=<SliceBackward>)
# 412 27.37693977355957 tensor([1.1675, 2.3578], grad_fn=<SliceBackward>)
# 413 27.27130699157715 tensor([1.1677, 2.3608], grad_fn=<SliceBackward>)
# 414 27.310009002685547 tensor([1.1679, 2.3637], grad_fn=<SliceBackward>)
# 415 27.300945281982422 tensor([1.1681, 2.3667], grad_fn=<SliceBackward>)
# 416 27.315959930419922 tensor([1.1683, 2.3697], grad_fn=<SliceBackward>)
# 417 27.249130249023438 tensor([1.1686, 2.3727], grad_fn=<SliceBackward>)
# 418 27.14097785949707 tensor([1.1690, 2.3756], grad_fn=<SliceBackward>)
# 419 27.23990249633789 tensor([1.1695, 2.3786], grad_fn=<SliceBackward>)
# 420 27.114665985107422 tensor([1.1698, 2.3816], grad_fn=<SliceBackward>)
# 421 26.964862823486328 tensor([1.1699, 2.3845], grad_fn=<SliceBackward>)
# 422 27.10783576965332 tensor([1.1700, 2.3874], grad_fn=<SliceBackward>)
# 423 26.937541961669922 tensor([1.1703, 2.3904], grad_fn=<SliceBackward>)
# 424 26.915061950683594 tensor([1.1706, 2.3933], grad_fn=<SliceBackward>)
# 425 27.055395126342773 tensor([1.1708, 2.3962], grad_fn=<SliceBackward>)
# 426 26.970794677734375 tensor([1.1711, 2.3991], grad_fn=<SliceBackward>)
# 427 27.084320068359375 tensor([1.1714, 2.4019], grad_fn=<SliceBackward>)
# 428 27.034732818603516 tensor([1.1719, 2.4047], grad_fn=<SliceBackward>)
# 429 26.877685546875 tensor([1.1722, 2.4076], grad_fn=<SliceBackward>)
# 430 26.825336456298828 tensor([1.1726, 2.4104], grad_fn=<SliceBackward>)
# 431 26.898527145385742 tensor([1.1729, 2.4132], grad_fn=<SliceBackward>)
# 432 26.742380142211914 tensor([1.1731, 2.4160], grad_fn=<SliceBackward>)
# 433 26.787879943847656 tensor([1.1733, 2.4188], grad_fn=<SliceBackward>)
# 434 26.826400756835938 tensor([1.1733, 2.4216], grad_fn=<SliceBackward>)
# 435 26.675113677978516 tensor([1.1732, 2.4244], grad_fn=<SliceBackward>)
# 436 26.710247039794922 tensor([1.1731, 2.4272], grad_fn=<SliceBackward>)
# 437 26.731536865234375 tensor([1.1729, 2.4300], grad_fn=<SliceBackward>)
# 438 26.78188705444336 tensor([1.1725, 2.4327], grad_fn=<SliceBackward>)
# 439 26.956789016723633 tensor([1.1723, 2.4354], grad_fn=<SliceBackward>)
# 440 26.55417823791504 tensor([1.1719, 2.4381], grad_fn=<SliceBackward>)
# 441 26.709274291992188 tensor([1.1713, 2.4408], grad_fn=<SliceBackward>)
# 442 26.486801147460938 tensor([1.1708, 2.4434], grad_fn=<SliceBackward>)
# 443 26.59440803527832 tensor([1.1702, 2.4460], grad_fn=<SliceBackward>)
# 444 26.592304229736328 tensor([1.1696, 2.4486], grad_fn=<SliceBackward>)
# 445 26.5561580657959 tensor([1.1690, 2.4512], grad_fn=<SliceBackward>)
# 446 26.406326293945312 tensor([1.1684, 2.4538], grad_fn=<SliceBackward>)
# 447 26.595205307006836 tensor([1.1678, 2.4565], grad_fn=<SliceBackward>)
# 448 26.41426658630371 tensor([1.1673, 2.4590], grad_fn=<SliceBackward>)
# 449 26.466419219970703 tensor([1.1667, 2.4616], grad_fn=<SliceBackward>)
# 450 26.410634994506836 tensor([1.1660, 2.4642], grad_fn=<SliceBackward>)
# 451 26.426820755004883 tensor([1.1651, 2.4667], grad_fn=<SliceBackward>)
# 452 26.345291137695312 tensor([1.1642, 2.4692], grad_fn=<SliceBackward>)
# 453 26.367523193359375 tensor([1.1634, 2.4717], grad_fn=<SliceBackward>)
# 454 26.525720596313477 tensor([1.1629, 2.4741], grad_fn=<SliceBackward>)
# 455 26.222082138061523 tensor([1.1625, 2.4766], grad_fn=<SliceBackward>)
# 456 26.235048294067383 tensor([1.1622, 2.4791], grad_fn=<SliceBackward>)
# 457 26.276695251464844 tensor([1.1620, 2.4816], grad_fn=<SliceBackward>)
# 458 26.07136344909668 tensor([1.1617, 2.4841], grad_fn=<SliceBackward>)
# 459 26.300880432128906 tensor([1.1614, 2.4865], grad_fn=<SliceBackward>)
# 460 26.173137664794922 tensor([1.1610, 2.4889], grad_fn=<SliceBackward>)
# 461 26.19293785095215 tensor([1.1605, 2.4913], grad_fn=<SliceBackward>)
# 462 26.126340866088867 tensor([1.1599, 2.4936], grad_fn=<SliceBackward>)
# 463 26.226848602294922 tensor([1.1594, 2.4959], grad_fn=<SliceBackward>)
# 464 26.200756072998047 tensor([1.1589, 2.4981], grad_fn=<SliceBackward>)
# 465 25.967483520507812 tensor([1.1583, 2.5003], grad_fn=<SliceBackward>)
# 466 26.03243637084961 tensor([1.1580, 2.5025], grad_fn=<SliceBackward>)
# 467 25.900014877319336 tensor([1.1578, 2.5047], grad_fn=<SliceBackward>)
# 468 26.039152145385742 tensor([1.1576, 2.5069], grad_fn=<SliceBackward>)
# 469 26.01655387878418 tensor([1.1573, 2.5091], grad_fn=<SliceBackward>)
# 470 26.04434585571289 tensor([1.1570, 2.5113], grad_fn=<SliceBackward>)
# 471 25.863895416259766 tensor([1.1565, 2.5135], grad_fn=<SliceBackward>)
# 472 25.79788589477539 tensor([1.1561, 2.5158], grad_fn=<SliceBackward>)
# 473 25.7810001373291 tensor([1.1555, 2.5180], grad_fn=<SliceBackward>)
# 474 25.839250564575195 tensor([1.1551, 2.5201], grad_fn=<SliceBackward>)
# 475 25.7774658203125 tensor([1.1547, 2.5222], grad_fn=<SliceBackward>)
# 476 25.791685104370117 tensor([1.1542, 2.5243], grad_fn=<SliceBackward>)
# 477 25.77229881286621 tensor([1.1536, 2.5264], grad_fn=<SliceBackward>)
# 478 25.830556869506836 tensor([1.1530, 2.5284], grad_fn=<SliceBackward>)
# 479 25.718774795532227 tensor([1.1523, 2.5304], grad_fn=<SliceBackward>)
# 480 25.705228805541992 tensor([1.1519, 2.5324], grad_fn=<SliceBackward>)
# 481 25.6966495513916 tensor([1.1515, 2.5344], grad_fn=<SliceBackward>)
# 482 25.67318344116211 tensor([1.1509, 2.5364], grad_fn=<SliceBackward>)
# 483 25.815073013305664 tensor([1.1502, 2.5384], grad_fn=<SliceBackward>)
# 484 25.499675750732422 tensor([1.1496, 2.5404], grad_fn=<SliceBackward>)
# 485 25.812213897705078 tensor([1.1488, 2.5424], grad_fn=<SliceBackward>)
# 486 25.421403884887695 tensor([1.1478, 2.5444], grad_fn=<SliceBackward>)
# 487 25.71931266784668 tensor([1.1470, 2.5464], grad_fn=<SliceBackward>)
# 488 25.62939453125 tensor([1.1461, 2.5484], grad_fn=<SliceBackward>)
# 489 25.426231384277344 tensor([1.1451, 2.5504], grad_fn=<SliceBackward>)
# 490 25.440975189208984 tensor([1.1439, 2.5524], grad_fn=<SliceBackward>)
# 491 25.613704681396484 tensor([1.1427, 2.5545], grad_fn=<SliceBackward>)
# 492 25.62131118774414 tensor([1.1413, 2.5565], grad_fn=<SliceBackward>)
# 493 25.475542068481445 tensor([1.1401, 2.5586], grad_fn=<SliceBackward>)
# 494 25.609825134277344 tensor([1.1388, 2.5607], grad_fn=<SliceBackward>)
# 495 25.477169036865234 tensor([1.1375, 2.5628], grad_fn=<SliceBackward>)
# 496 25.4846248626709 tensor([1.1365, 2.5649], grad_fn=<SliceBackward>)
# 497 25.5926513671875 tensor([1.1356, 2.5669], grad_fn=<SliceBackward>)
# 498 25.392250061035156 tensor([1.1347, 2.5689], grad_fn=<SliceBackward>)
# 499 25.57868003845215 tensor([1.1340, 2.5710], grad_fn=<SliceBackward>)
# 500 25.464445114135742 tensor([1.1331, 2.5731], grad_fn=<SliceBackward>)
# 501 25.440868377685547 tensor([1.1323, 2.5752], grad_fn=<SliceBackward>)
# 502 25.422962188720703 tensor([1.1316, 2.5773], grad_fn=<SliceBackward>)
# 503 25.287656784057617 tensor([1.1310, 2.5794], grad_fn=<SliceBackward>)
# 504 25.18851089477539 tensor([1.1303, 2.5815], grad_fn=<SliceBackward>)
# 505 25.51639747619629 tensor([1.1297, 2.5836], grad_fn=<SliceBackward>)
# 506 25.32442283630371 tensor([1.1292, 2.5857], grad_fn=<SliceBackward>)
# 507 25.201841354370117 tensor([1.1285, 2.5878], grad_fn=<SliceBackward>)
# 508 25.33769989013672 tensor([1.1278, 2.5899], grad_fn=<SliceBackward>)
# 509 25.365272521972656 tensor([1.1273, 2.5919], grad_fn=<SliceBackward>)
# 510 25.32366371154785 tensor([1.1266, 2.5940], grad_fn=<SliceBackward>)
# 511 25.141769409179688 tensor([1.1259, 2.5960], grad_fn=<SliceBackward>)
# 512 25.18625259399414 tensor([1.1252, 2.5981], grad_fn=<SliceBackward>)
# 513 25.141416549682617 tensor([1.1243, 2.6002], grad_fn=<SliceBackward>)
# 514 24.963401794433594 tensor([1.1235, 2.6023], grad_fn=<SliceBackward>)
# 515 25.25150489807129 tensor([1.1229, 2.6043], grad_fn=<SliceBackward>)
# 516 25.101913452148438 tensor([1.1225, 2.6064], grad_fn=<SliceBackward>)
# 517 25.0341739654541 tensor([1.1220, 2.6084], grad_fn=<SliceBackward>)
# 518 25.08932876586914 tensor([1.1214, 2.6104], grad_fn=<SliceBackward>)
# 519 24.94424819946289 tensor([1.1208, 2.6125], grad_fn=<SliceBackward>)
# 520 24.93665313720703 tensor([1.1204, 2.6145], grad_fn=<SliceBackward>)
# 521 24.972524642944336 tensor([1.1201, 2.6164], grad_fn=<SliceBackward>)
# 522 25.101430892944336 tensor([1.1197, 2.6184], grad_fn=<SliceBackward>)
# 523 24.967899322509766 tensor([1.1194, 2.6204], grad_fn=<SliceBackward>)
# 524 24.891441345214844 tensor([1.1191, 2.6223], grad_fn=<SliceBackward>)
# 525 24.871753692626953 tensor([1.1190, 2.6243], grad_fn=<SliceBackward>)
# 526 24.932109832763672 tensor([1.1190, 2.6262], grad_fn=<SliceBackward>)
# 527 24.97981834411621 tensor([1.1189, 2.6280], grad_fn=<SliceBackward>)
# 528 24.894657135009766 tensor([1.1189, 2.6298], grad_fn=<SliceBackward>)
# 529 24.83319854736328 tensor([1.1189, 2.6316], grad_fn=<SliceBackward>)
# 530 24.815282821655273 tensor([1.1188, 2.6333], grad_fn=<SliceBackward>)
# 531 24.55958366394043 tensor([1.1184, 2.6351], grad_fn=<SliceBackward>)
# 532 24.692325592041016 tensor([1.1178, 2.6369], grad_fn=<SliceBackward>)
# 533 24.510696411132812 tensor([1.1173, 2.6387], grad_fn=<SliceBackward>)
# 534 24.695758819580078 tensor([1.1169, 2.6405], grad_fn=<SliceBackward>)
# 535 24.897422790527344 tensor([1.1167, 2.6422], grad_fn=<SliceBackward>)
# 536 24.419971466064453 tensor([1.1166, 2.6438], grad_fn=<SliceBackward>)
# 537 24.681781768798828 tensor([1.1162, 2.6455], grad_fn=<SliceBackward>)
# 538 24.529430389404297 tensor([1.1157, 2.6473], grad_fn=<SliceBackward>)
# 539 24.549909591674805 tensor([1.1152, 2.6490], grad_fn=<SliceBackward>)
# 540 24.491592407226562 tensor([1.1145, 2.6509], grad_fn=<SliceBackward>)
# 541 24.48406219482422 tensor([1.1137, 2.6527], grad_fn=<SliceBackward>)
# 542 24.59764862060547 tensor([1.1128, 2.6545], grad_fn=<SliceBackward>)
# 543 24.423686981201172 tensor([1.1119, 2.6562], grad_fn=<SliceBackward>)
# 544 24.45284080505371 tensor([1.1111, 2.6579], grad_fn=<SliceBackward>)
# 545 24.320781707763672 tensor([1.1103, 2.6597], grad_fn=<SliceBackward>)
# 546 24.40302848815918 tensor([1.1096, 2.6615], grad_fn=<SliceBackward>)
# 547 24.292091369628906 tensor([1.1088, 2.6632], grad_fn=<SliceBackward>)
# 548 24.425918579101562 tensor([1.1079, 2.6649], grad_fn=<SliceBackward>)
# 549 24.275381088256836 tensor([1.1071, 2.6666], grad_fn=<SliceBackward>)
# 550 24.346824645996094 tensor([1.1063, 2.6683], grad_fn=<SliceBackward>)
# 551 24.13848876953125 tensor([1.1054, 2.6700], grad_fn=<SliceBackward>)
# 552 24.220909118652344 tensor([1.1045, 2.6717], grad_fn=<SliceBackward>)
# 553 24.244522094726562 tensor([1.1038, 2.6734], grad_fn=<SliceBackward>)
# 554 24.30425453186035 tensor([1.1034, 2.6750], grad_fn=<SliceBackward>)
# 555 24.020954132080078 tensor([1.1031, 2.6766], grad_fn=<SliceBackward>)
# 556 24.06160545349121 tensor([1.1026, 2.6782], grad_fn=<SliceBackward>)
# 557 24.11663246154785 tensor([1.1023, 2.6798], grad_fn=<SliceBackward>)
# 558 24.041919708251953 tensor([1.1019, 2.6813], grad_fn=<SliceBackward>)
# 559 24.125652313232422 tensor([1.1011, 2.6829], grad_fn=<SliceBackward>)
# 560 23.99590492248535 tensor([1.1004, 2.6845], grad_fn=<SliceBackward>)
# 561 24.123592376708984 tensor([1.0996, 2.6860], grad_fn=<SliceBackward>)
# 562 23.969629287719727 tensor([1.0987, 2.6876], grad_fn=<SliceBackward>)
# 563 24.017566680908203 tensor([1.0976, 2.6891], grad_fn=<SliceBackward>)
# 564 23.910730361938477 tensor([1.0966, 2.6906], grad_fn=<SliceBackward>)
# 565 23.878671646118164 tensor([1.0955, 2.6921], grad_fn=<SliceBackward>)
# 566 24.036481857299805 tensor([1.0945, 2.6935], grad_fn=<SliceBackward>)
# 567 23.891185760498047 tensor([1.0939, 2.6950], grad_fn=<SliceBackward>)
# 568 23.7746639251709 tensor([1.0932, 2.6965], grad_fn=<SliceBackward>)
# 569 23.67612075805664 tensor([1.0927, 2.6980], grad_fn=<SliceBackward>)
# 570 23.841068267822266 tensor([1.0921, 2.6994], grad_fn=<SliceBackward>)
# 571 23.788454055786133 tensor([1.0913, 2.7009], grad_fn=<SliceBackward>)
# 572 23.78982162475586 tensor([1.0905, 2.7024], grad_fn=<SliceBackward>)
# 573 23.753149032592773 tensor([1.0896, 2.7038], grad_fn=<SliceBackward>)
# 574 23.60909652709961 tensor([1.0886, 2.7053], grad_fn=<SliceBackward>)
# 575 23.71826934814453 tensor([1.0874, 2.7067], grad_fn=<SliceBackward>)
# 576 23.86385726928711 tensor([1.0864, 2.7082], grad_fn=<SliceBackward>)
# 577 23.634201049804688 tensor([1.0851, 2.7096], grad_fn=<SliceBackward>)
# 578 23.649320602416992 tensor([1.0838, 2.7111], grad_fn=<SliceBackward>)
# 579 23.462047576904297 tensor([1.0827, 2.7125], grad_fn=<SliceBackward>)
# 580 23.660266876220703 tensor([1.0814, 2.7140], grad_fn=<SliceBackward>)
# 581 23.666744232177734 tensor([1.0806, 2.7154], grad_fn=<SliceBackward>)
# 582 23.523927688598633 tensor([1.0798, 2.7168], grad_fn=<SliceBackward>)
# 583 23.33340072631836 tensor([1.0790, 2.7181], grad_fn=<SliceBackward>)
# 584 23.47494125366211 tensor([1.0780, 2.7196], grad_fn=<SliceBackward>)
# 585 23.45709991455078 tensor([1.0769, 2.7210], grad_fn=<SliceBackward>)
# 586 23.558095932006836 tensor([1.0761, 2.7224], grad_fn=<SliceBackward>)
# 587 23.428180694580078 tensor([1.0753, 2.7238], grad_fn=<SliceBackward>)
# 588 23.35898208618164 tensor([1.0747, 2.7252], grad_fn=<SliceBackward>)
# 589 23.364643096923828 tensor([1.0744, 2.7265], grad_fn=<SliceBackward>)
# 590 23.213096618652344 tensor([1.0741, 2.7278], grad_fn=<SliceBackward>)
# 591 23.424509048461914 tensor([1.0736, 2.7290], grad_fn=<SliceBackward>)
# 592 23.23469352722168 tensor([1.0730, 2.7303], grad_fn=<SliceBackward>)
# 593 23.336286544799805 tensor([1.0725, 2.7315], grad_fn=<SliceBackward>)
# 594 23.175765991210938 tensor([1.0722, 2.7326], grad_fn=<SliceBackward>)
# 595 23.196250915527344 tensor([1.0718, 2.7338], grad_fn=<SliceBackward>)
# 596 23.096698760986328 tensor([1.0714, 2.7349], grad_fn=<SliceBackward>)
# 597 23.29475975036621 tensor([1.0713, 2.7360], grad_fn=<SliceBackward>)
# 598 23.36815071105957 tensor([1.0712, 2.7372], grad_fn=<SliceBackward>)
# 599 23.188278198242188 tensor([1.0710, 2.7383], grad_fn=<SliceBackward>)
# 600 22.972389221191406 tensor([1.0708, 2.7396], grad_fn=<SliceBackward>)
# 601 23.149131774902344 tensor([1.0707, 2.7407], grad_fn=<SliceBackward>)
# 602 23.171127319335938 tensor([1.0706, 2.7419], grad_fn=<SliceBackward>)
# 603 23.213058471679688 tensor([1.0708, 2.7430], grad_fn=<SliceBackward>)
# 604 23.013927459716797 tensor([1.0710, 2.7441], grad_fn=<SliceBackward>)
# 605 23.175926208496094 tensor([1.0711, 2.7452], grad_fn=<SliceBackward>)
# 606 23.090778350830078 tensor([1.0712, 2.7463], grad_fn=<SliceBackward>)
# 607 22.915082931518555 tensor([1.0714, 2.7475], grad_fn=<SliceBackward>)
# 608 22.860328674316406 tensor([1.0716, 2.7487], grad_fn=<SliceBackward>)
# 609 23.063020706176758 tensor([1.0719, 2.7498], grad_fn=<SliceBackward>)
# 610 22.935279846191406 tensor([1.0721, 2.7509], grad_fn=<SliceBackward>)
# 611 22.79772186279297 tensor([1.0722, 2.7521], grad_fn=<SliceBackward>)
# 612 22.808137893676758 tensor([1.0721, 2.7532], grad_fn=<SliceBackward>)
# 613 22.905628204345703 tensor([1.0723, 2.7543], grad_fn=<SliceBackward>)
# 614 22.73427391052246 tensor([1.0723, 2.7555], grad_fn=<SliceBackward>)
# 615 22.93121910095215 tensor([1.0720, 2.7566], grad_fn=<SliceBackward>)
# 616 22.926734924316406 tensor([1.0718, 2.7577], grad_fn=<SliceBackward>)
# 617 22.732040405273438 tensor([1.0718, 2.7588], grad_fn=<SliceBackward>)
# 618 22.730161666870117 tensor([1.0716, 2.7599], grad_fn=<SliceBackward>)
# 619 22.678661346435547 tensor([1.0716, 2.7611], grad_fn=<SliceBackward>)
# 620 22.751955032348633 tensor([1.0716, 2.7622], grad_fn=<SliceBackward>)
# 621 22.73819351196289 tensor([1.0719, 2.7633], grad_fn=<SliceBackward>)
# 622 22.67361068725586 tensor([1.0723, 2.7644], grad_fn=<SliceBackward>)
# 623 22.606346130371094 tensor([1.0729, 2.7655], grad_fn=<SliceBackward>)
# 624 22.81536102294922 tensor([1.0732, 2.7665], grad_fn=<SliceBackward>)
# 625 22.751262664794922 tensor([1.0734, 2.7677], grad_fn=<SliceBackward>)
# 626 22.665109634399414 tensor([1.0735, 2.7689], grad_fn=<SliceBackward>)
# 627 22.6276798248291 tensor([1.0736, 2.7700], grad_fn=<SliceBackward>)
# 628 22.53877830505371 tensor([1.0739, 2.7712], grad_fn=<SliceBackward>)
# 629 22.463211059570312 tensor([1.0741, 2.7722], grad_fn=<SliceBackward>)
# 630 22.453603744506836 tensor([1.0743, 2.7733], grad_fn=<SliceBackward>)
# 631 22.48069190979004 tensor([1.0745, 2.7743], grad_fn=<SliceBackward>)
# 632 22.343961715698242 tensor([1.0746, 2.7753], grad_fn=<SliceBackward>)
# 633 22.35470962524414 tensor([1.0743, 2.7763], grad_fn=<SliceBackward>)
# 634 22.23491096496582 tensor([1.0740, 2.7773], grad_fn=<SliceBackward>)
# 635 22.38813018798828 tensor([1.0737, 2.7783], grad_fn=<SliceBackward>)
# 636 22.33344841003418 tensor([1.0738, 2.7792], grad_fn=<SliceBackward>)
# 637 22.28262710571289 tensor([1.0738, 2.7802], grad_fn=<SliceBackward>)
# 638 22.47673225402832 tensor([1.0738, 2.7813], grad_fn=<SliceBackward>)
# 639 22.178485870361328 tensor([1.0738, 2.7823], grad_fn=<SliceBackward>)
# 640 22.321977615356445 tensor([1.0738, 2.7833], grad_fn=<SliceBackward>)
# 641 22.433761596679688 tensor([1.0742, 2.7842], grad_fn=<SliceBackward>)
# 642 22.44167709350586 tensor([1.0747, 2.7852], grad_fn=<SliceBackward>)
# 643 22.189884185791016 tensor([1.0755, 2.7861], grad_fn=<SliceBackward>)
# 644 22.12750244140625 tensor([1.0763, 2.7871], grad_fn=<SliceBackward>)
# 645 22.15361976623535 tensor([1.0769, 2.7881], grad_fn=<SliceBackward>)
# 646 22.209609985351562 tensor([1.0777, 2.7890], grad_fn=<SliceBackward>)
# 647 22.444448471069336 tensor([1.0782, 2.7899], grad_fn=<SliceBackward>)
# 648 22.171958923339844 tensor([1.0792, 2.7907], grad_fn=<SliceBackward>)
# 649 22.164749145507812 tensor([1.0800, 2.7916], grad_fn=<SliceBackward>)
# 650 22.206279754638672 tensor([1.0808, 2.7924], grad_fn=<SliceBackward>)
# 651 22.305240631103516 tensor([1.0813, 2.7931], grad_fn=<SliceBackward>)
# 652 22.23653793334961 tensor([1.0819, 2.7939], grad_fn=<SliceBackward>)
# 653 22.04596710205078 tensor([1.0823, 2.7946], grad_fn=<SliceBackward>)
# 654 22.13086700439453 tensor([1.0828, 2.7954], grad_fn=<SliceBackward>)
# 655 21.88713836669922 tensor([1.0834, 2.7961], grad_fn=<SliceBackward>)
# 656 22.067626953125 tensor([1.0841, 2.7968], grad_fn=<SliceBackward>)
# 657 21.997005462646484 tensor([1.0847, 2.7974], grad_fn=<SliceBackward>)
# 658 22.045194625854492 tensor([1.0855, 2.7980], grad_fn=<SliceBackward>)
# 659 21.96139144897461 tensor([1.0862, 2.7987], grad_fn=<SliceBackward>)
# 660 22.005332946777344 tensor([1.0869, 2.7993], grad_fn=<SliceBackward>)
# 661 22.00606346130371 tensor([1.0872, 2.7999], grad_fn=<SliceBackward>)
# 662 22.089832305908203 tensor([1.0877, 2.8005], grad_fn=<SliceBackward>)
# 663 21.879108428955078 tensor([1.0883, 2.8011], grad_fn=<SliceBackward>)
# ...
# 784 23.270126342773438 tensor([1.0935, 3.5840], grad_fn=<SliceBackward>)
# 785 23.16810417175293 tensor([1.0921, 3.5852], grad_fn=<SliceBackward>)
# 786 23.249839782714844 tensor([1.0913, 3.5863], grad_fn=<SliceBackward>)
# 787 23.197479248046875 tensor([1.0909, 3.5875], grad_fn=<SliceBackward>)
# 788 23.204593658447266 tensor([1.0909, 3.5886], grad_fn=<SliceBackward>)
# 789 23.140972137451172 tensor([1.0911, 3.5897], grad_fn=<SliceBackward>)
# 790 23.229639053344727 tensor([1.0915, 3.5908], grad_fn=<SliceBackward>)
# 791 23.1077823638916 tensor([1.0918, 3.5919], grad_fn=<SliceBackward>)
# 792 23.177621841430664 tensor([1.0917, 3.5930], grad_fn=<SliceBackward>)
# 793 23.179004669189453 tensor([1.0915, 3.5941], grad_fn=<SliceBackward>)
# 794 23.119937896728516 tensor([1.0907, 3.5951], grad_fn=<SliceBackward>)
# 795 23.223648071289062 tensor([1.0900, 3.5961], grad_fn=<SliceBackward>)
# 796 23.013225555419922 tensor([1.0897, 3.5972], grad_fn=<SliceBackward>)
# 797 23.250635147094727 tensor([1.0894, 3.5981], grad_fn=<SliceBackward>)
# 798 23.05534553527832 tensor([1.0896, 3.5991], grad_fn=<SliceBackward>)
# 799 23.04822540283203 tensor([1.0895, 3.6000], grad_fn=<SliceBackward>)
# 800 23.183311462402344 tensor([1.0889, 3.6009], grad_fn=<SliceBackward>)
# 801 23.108898162841797 tensor([1.0888, 3.6018], grad_fn=<SliceBackward>)
# 802 23.097309112548828 tensor([1.0887, 3.6027], grad_fn=<SliceBackward>)
# 803 22.91204261779785 tensor([1.0886, 3.6035], grad_fn=<SliceBackward>)
# 804 23.120006561279297 tensor([1.0886, 3.6043], grad_fn=<SliceBackward>)
# 805 23.05432891845703 tensor([1.0885, 3.6051], grad_fn=<SliceBackward>)
# 806 23.128890991210938 tensor([1.0882, 3.6060], grad_fn=<SliceBackward>)
# 807 23.116912841796875 tensor([1.0875, 3.6069], grad_fn=<SliceBackward>)
# 808 23.054750442504883 tensor([1.0863, 3.6078], grad_fn=<SliceBackward>)
# 809 22.981449127197266 tensor([1.0851, 3.6088], grad_fn=<SliceBackward>)
# 810 22.929363250732422 tensor([1.0839, 3.6097], grad_fn=<SliceBackward>)
# 811 22.966266632080078 tensor([1.0835, 3.6105], grad_fn=<SliceBackward>)
# 812 22.996334075927734 tensor([1.0830, 3.6113], grad_fn=<SliceBackward>)
# 813 23.001346588134766 tensor([1.0823, 3.6121], grad_fn=<SliceBackward>)
# 814 22.95096206665039 tensor([1.0818, 3.6129], grad_fn=<SliceBackward>)
# 815 22.715530395507812 tensor([1.0817, 3.6137], grad_fn=<SliceBackward>)
# 816 22.902015686035156 tensor([1.0814, 3.6146], grad_fn=<SliceBackward>)
# 817 22.879047393798828 tensor([1.0809, 3.6154], grad_fn=<SliceBackward>)
# 818 22.850269317626953 tensor([1.0800, 3.6162], grad_fn=<SliceBackward>)
# 819 22.820289611816406 tensor([1.0788, 3.6171], grad_fn=<SliceBackward>)
# 820 22.90359878540039 tensor([1.0777, 3.6180], grad_fn=<SliceBackward>)
# 821 22.750057220458984 tensor([1.0766, 3.6188], grad_fn=<SliceBackward>)
# 822 22.909751892089844 tensor([1.0757, 3.6196], grad_fn=<SliceBackward>)
# 823 23.193256378173828 tensor([1.0747, 3.6205], grad_fn=<SliceBackward>)
# 824 22.83990478515625 tensor([1.0740, 3.6215], grad_fn=<SliceBackward>)
# 825 22.787601470947266 tensor([1.0732, 3.6224], grad_fn=<SliceBackward>)
# 826 22.96608543395996 tensor([1.0721, 3.6233], grad_fn=<SliceBackward>)
# 827 22.938411712646484 tensor([1.0712, 3.6242], grad_fn=<SliceBackward>)
# 828 22.904773712158203 tensor([1.0705, 3.6251], grad_fn=<SliceBackward>)
# 829 22.842533111572266 tensor([1.0702, 3.6261], grad_fn=<SliceBackward>)
# 830 22.827625274658203 tensor([1.0700, 3.6271], grad_fn=<SliceBackward>)
# 831 22.76873207092285 tensor([1.0698, 3.6281], grad_fn=<SliceBackward>)
# 832 22.794937133789062 tensor([1.0695, 3.6291], grad_fn=<SliceBackward>)
# 833 22.819189071655273 tensor([1.0693, 3.6301], grad_fn=<SliceBackward>)
# 834 22.5656681060791 tensor([1.0693, 3.6311], grad_fn=<SliceBackward>)
# 835 22.527875900268555 tensor([1.0691, 3.6321], grad_fn=<SliceBackward>)
# 836 22.61359214782715 tensor([1.0689, 3.6330], grad_fn=<SliceBackward>)
# 837 22.6269588470459 tensor([1.0688, 3.6340], grad_fn=<SliceBackward>)
# 838 22.640365600585938 tensor([1.0685, 3.6350], grad_fn=<SliceBackward>)
# 839 22.721343994140625 tensor([1.0684, 3.6360], grad_fn=<SliceBackward>)
# 840 22.499004364013672 tensor([1.0686, 3.6369], grad_fn=<SliceBackward>)
# 841 22.640419006347656 tensor([1.0689, 3.6378], grad_fn=<SliceBackward>)
# 842 22.65110969543457 tensor([1.0694, 3.6387], grad_fn=<SliceBackward>)
# 843 22.73577880859375 tensor([1.0702, 3.6395], grad_fn=<SliceBackward>)
# 844 22.626667022705078 tensor([1.0711, 3.6404], grad_fn=<SliceBackward>)
# 845 22.444650650024414 tensor([1.0714, 3.6412], grad_fn=<SliceBackward>)
# 846 22.476091384887695 tensor([1.0720, 3.6421], grad_fn=<SliceBackward>)
# 847 22.57320785522461 tensor([1.0721, 3.6430], grad_fn=<SliceBackward>)
# 848 22.39109992980957 tensor([1.0723, 3.6438], grad_fn=<SliceBackward>)
# 849 22.53543472290039 tensor([1.0726, 3.6446], grad_fn=<SliceBackward>)
# 850 22.620155334472656 tensor([1.0729, 3.6454], grad_fn=<SliceBackward>)
# 851 22.277481079101562 tensor([1.0730, 3.6462], grad_fn=<SliceBackward>)
# 852 22.52356719970703 tensor([1.0731, 3.6469], grad_fn=<SliceBackward>)
# 853 22.562822341918945 tensor([1.0738, 3.6476], grad_fn=<SliceBackward>)
# 854 22.38934326171875 tensor([1.0746, 3.6483], grad_fn=<SliceBackward>)
# 855 22.4686336517334 tensor([1.0748, 3.6490], grad_fn=<SliceBackward>)
# 856 22.266712188720703 tensor([1.0746, 3.6497], grad_fn=<SliceBackward>)
# 857 22.36202621459961 tensor([1.0742, 3.6503], grad_fn=<SliceBackward>)
# 858 22.480762481689453 tensor([1.0738, 3.6510], grad_fn=<SliceBackward>)
# 859 22.47028350830078 tensor([1.0732, 3.6516], grad_fn=<SliceBackward>)
# 860 22.3612117767334 tensor([1.0727, 3.6523], grad_fn=<SliceBackward>)
# 861 22.467361450195312 tensor([1.0725, 3.6531], grad_fn=<SliceBackward>)
# 862 22.22978401184082 tensor([1.0717, 3.6539], grad_fn=<SliceBackward>)
# 863 22.323383331298828 tensor([1.0709, 3.6546], grad_fn=<SliceBackward>)
# 864 22.3524169921875 tensor([1.0705, 3.6553], grad_fn=<SliceBackward>)
# 865 22.201879501342773 tensor([1.0703, 3.6560], grad_fn=<SliceBackward>)
# 866 22.341381072998047 tensor([1.0699, 3.6567], grad_fn=<SliceBackward>)
# 867 22.210264205932617 tensor([1.0701, 3.6575], grad_fn=<SliceBackward>)
# 868 22.413009643554688 tensor([1.0701, 3.6583], grad_fn=<SliceBackward>)
# 869 22.327634811401367 tensor([1.0702, 3.6590], grad_fn=<SliceBackward>)
# 870 22.199966430664062 tensor([1.0704, 3.6597], grad_fn=<SliceBackward>)
# 871 22.09893226623535 tensor([1.0703, 3.6604], grad_fn=<SliceBackward>)
# 872 22.362943649291992 tensor([1.0702, 3.6611], grad_fn=<SliceBackward>)
# 873 22.046810150146484 tensor([1.0697, 3.6618], grad_fn=<SliceBackward>)
# 874 22.031639099121094 tensor([1.0692, 3.6625], grad_fn=<SliceBackward>)
# 875 22.12242889404297 tensor([1.0689, 3.6631], grad_fn=<SliceBackward>)
# 876 22.15635108947754 tensor([1.0683, 3.6637], grad_fn=<SliceBackward>)
# 877 22.178417205810547 tensor([1.0677, 3.6644], grad_fn=<SliceBackward>)
# 878 22.075458526611328 tensor([1.0672, 3.6651], grad_fn=<SliceBackward>)
# 879 22.127872467041016 tensor([1.0667, 3.6657], grad_fn=<SliceBackward>)
# 880 22.178146362304688 tensor([1.0658, 3.6664], grad_fn=<SliceBackward>)
# 881 22.165908813476562 tensor([1.0646, 3.6670], grad_fn=<SliceBackward>)
# 882 22.215389251708984 tensor([1.0638, 3.6676], grad_fn=<SliceBackward>)
# 883 21.87994384765625 tensor([1.0635, 3.6682], grad_fn=<SliceBackward>)
# 884 22.2449951171875 tensor([1.0631, 3.6688], grad_fn=<SliceBackward>)
# 885 21.950084686279297 tensor([1.0628, 3.6695], grad_fn=<SliceBackward>)
# 886 22.08074951171875 tensor([1.0624, 3.6701], grad_fn=<SliceBackward>)
# 887 21.84869384765625 tensor([1.0620, 3.6707], grad_fn=<SliceBackward>)
# 888 21.873374938964844 tensor([1.0611, 3.6713], grad_fn=<SliceBackward>)
# 889 22.110366821289062 tensor([1.0595, 3.6720], grad_fn=<SliceBackward>)
# 890 22.095394134521484 tensor([1.0580, 3.6727], grad_fn=<SliceBackward>)
# 891 21.758651733398438 tensor([1.0564, 3.6733], grad_fn=<SliceBackward>)
# 892 22.055686950683594 tensor([1.0550, 3.6740], grad_fn=<SliceBackward>)
# 893 21.89446449279785 tensor([1.0541, 3.6747], grad_fn=<SliceBackward>)
# 894 21.921627044677734 tensor([1.0533, 3.6753], grad_fn=<SliceBackward>)
# 895 21.917858123779297 tensor([1.0523, 3.6760], grad_fn=<SliceBackward>)
# 896 21.825414657592773 tensor([1.0510, 3.6768], grad_fn=<SliceBackward>)
# 897 21.909631729125977 tensor([1.0490, 3.6775], grad_fn=<SliceBackward>)
# 898 21.738649368286133 tensor([1.0473, 3.6783], grad_fn=<SliceBackward>)
# 899 21.631471633911133 tensor([1.0455, 3.6791], grad_fn=<SliceBackward>)
# 900 21.66265869140625 tensor([1.0440, 3.6798], grad_fn=<SliceBackward>)
# 901 21.766693115234375 tensor([1.0423, 3.6805], grad_fn=<SliceBackward>)
# 902 21.966171264648438 tensor([1.0406, 3.6813], grad_fn=<SliceBackward>)
# 903 21.758865356445312 tensor([1.0387, 3.6820], grad_fn=<SliceBackward>)
# 904 21.764881134033203 tensor([1.0365, 3.6828], grad_fn=<SliceBackward>)
# 905 21.929580688476562 tensor([1.0346, 3.6835], grad_fn=<SliceBackward>)
# 906 21.697185516357422 tensor([1.0329, 3.6842], grad_fn=<SliceBackward>)
# 907 21.708316802978516 tensor([1.0311, 3.6849], grad_fn=<SliceBackward>)
# 908 21.72257423400879 tensor([1.0296, 3.6856], grad_fn=<SliceBackward>)
# 909 21.60735321044922 tensor([1.0282, 3.6865], grad_fn=<SliceBackward>)
# 910 21.918182373046875 tensor([1.0267, 3.6873], grad_fn=<SliceBackward>)
# 911 21.777517318725586 tensor([1.0256, 3.6881], grad_fn=<SliceBackward>)
# 912 21.56812858581543 tensor([1.0249, 3.6889], grad_fn=<SliceBackward>)
# 913 21.93992042541504 tensor([1.0236, 3.6898], grad_fn=<SliceBackward>)
# 914 21.665403366088867 tensor([1.0228, 3.6906], grad_fn=<SliceBackward>)
# 915 21.768478393554688 tensor([1.0214, 3.6915], grad_fn=<SliceBackward>)
# 916 21.690982818603516 tensor([1.0197, 3.6924], grad_fn=<SliceBackward>)
# 917 21.37824249267578 tensor([1.0183, 3.6934], grad_fn=<SliceBackward>)
# 918 21.69940948486328 tensor([1.0170, 3.6943], grad_fn=<SliceBackward>)
# 919 21.724563598632812 tensor([1.0154, 3.6953], grad_fn=<SliceBackward>)
# 920 21.637584686279297 tensor([1.0139, 3.6962], grad_fn=<SliceBackward>)
# 921 21.517086029052734 tensor([1.0126, 3.6973], grad_fn=<SliceBackward>)
# 922 21.801057815551758 tensor([1.0111, 3.6983], grad_fn=<SliceBackward>)
# 923 21.61450958251953 tensor([1.0098, 3.6994], grad_fn=<SliceBackward>)
# 924 21.50714111328125 tensor([1.0086, 3.7004], grad_fn=<SliceBackward>)
# 925 21.725814819335938 tensor([1.0075, 3.7013], grad_fn=<SliceBackward>)
# 926 21.569969177246094 tensor([1.0066, 3.7023], grad_fn=<SliceBackward>)
# 927 21.66073989868164 tensor([1.0057, 3.7032], grad_fn=<SliceBackward>)
# 928 21.768936157226562 tensor([1.0051, 3.7041], grad_fn=<SliceBackward>)
# 929 21.67110252380371 tensor([1.0046, 3.7049], grad_fn=<SliceBackward>)
# 930 21.67339324951172 tensor([1.0048, 3.7057], grad_fn=<SliceBackward>)
# 931 21.806522369384766 tensor([1.0051, 3.7064], grad_fn=<SliceBackward>)
# 932 21.4605655670166 tensor([1.0052, 3.7073], grad_fn=<SliceBackward>)
# 933 21.57555389404297 tensor([1.0052, 3.7081], grad_fn=<SliceBackward>)
# 934 21.559980392456055 tensor([1.0050, 3.7090], grad_fn=<SliceBackward>)
# 935 21.47712516784668 tensor([1.0049, 3.7099], grad_fn=<SliceBackward>)
# 936 21.537818908691406 tensor([1.0047, 3.7108], grad_fn=<SliceBackward>)
# 937 21.685680389404297 tensor([1.0047, 3.7117], grad_fn=<SliceBackward>)
# 938 21.457500457763672 tensor([1.0046, 3.7125], grad_fn=<SliceBackward>)
# 939 21.39922332763672 tensor([1.0044, 3.7133], grad_fn=<SliceBackward>)
# 940 21.643247604370117 tensor([1.0045, 3.7140], grad_fn=<SliceBackward>)
# 941 21.535690307617188 tensor([1.0047, 3.7147], grad_fn=<SliceBackward>)
# 942 21.483970642089844 tensor([1.0050, 3.7153], grad_fn=<SliceBackward>)
# 943 21.677074432373047 tensor([1.0055, 3.7159], grad_fn=<SliceBackward>)
# 944 21.57044792175293 tensor([1.0062, 3.7165], grad_fn=<SliceBackward>)
# 945 21.653169631958008 tensor([1.0065, 3.7172], grad_fn=<SliceBackward>)
# 946 21.545656204223633 tensor([1.0066, 3.7178], grad_fn=<SliceBackward>)
# 947 21.43367576599121 tensor([1.0064, 3.7184], grad_fn=<SliceBackward>)
# 948 21.308902740478516 tensor([1.0061, 3.7190], grad_fn=<SliceBackward>)
# 949 21.438732147216797 tensor([1.0058, 3.7196], grad_fn=<SliceBackward>)
# 950 21.46584129333496 tensor([1.0055, 3.7201], grad_fn=<SliceBackward>)
# 951 21.378097534179688 tensor([1.0053, 3.7207], grad_fn=<SliceBackward>)
# 952 21.48231315612793 tensor([1.0051, 3.7211], grad_fn=<SliceBackward>)
# 953 21.540042877197266 tensor([1.0047, 3.7216], grad_fn=<SliceBackward>)
# 954 21.520021438598633 tensor([1.0040, 3.7221], grad_fn=<SliceBackward>)
# 955 21.44993782043457 tensor([1.0035, 3.7226], grad_fn=<SliceBackward>)
# 956 21.511249542236328 tensor([1.0025, 3.7231], grad_fn=<SliceBackward>)
# 957 21.443737030029297 tensor([1.0014, 3.7236], grad_fn=<SliceBackward>)
# 958 21.347545623779297 tensor([1.0005, 3.7241], grad_fn=<SliceBackward>)
# 959 21.692668914794922 tensor([0.9998, 3.7246], grad_fn=<SliceBackward>)
# 960 21.431299209594727 tensor([0.9988, 3.7251], grad_fn=<SliceBackward>)
# 961 21.38685417175293 tensor([0.9978, 3.7258], grad_fn=<SliceBackward>)
# 962 21.41423797607422 tensor([0.9971, 3.7264], grad_fn=<SliceBackward>)
# 963 21.317867279052734 tensor([0.9970, 3.7270], grad_fn=<SliceBackward>)
# 964 21.573909759521484 tensor([0.9968, 3.7277], grad_fn=<SliceBackward>)
# 965 21.383106231689453 tensor([0.9969, 3.7282], grad_fn=<SliceBackward>)
# 966 21.417335510253906 tensor([0.9969, 3.7288], grad_fn=<SliceBackward>)
# 967 21.44940948486328 tensor([0.9969, 3.7293], grad_fn=<SliceBackward>)
# 968 21.49907684326172 tensor([0.9969, 3.7298], grad_fn=<SliceBackward>)
# 969 21.52633285522461 tensor([0.9974, 3.7303], grad_fn=<SliceBackward>)
# 970 21.431514739990234 tensor([0.9984, 3.7309], grad_fn=<SliceBackward>)
# 971 21.43655014038086 tensor([0.9993, 3.7314], grad_fn=<SliceBackward>)
# 972 21.413658142089844 tensor([1.0005, 3.7319], grad_fn=<SliceBackward>)
# 973 21.312063217163086 tensor([1.0018, 3.7323], grad_fn=<SliceBackward>)
# 974 21.38266944885254 tensor([1.0034, 3.7328], grad_fn=<SliceBackward>)
# 975 21.203664779663086 tensor([1.0048, 3.7332], grad_fn=<SliceBackward>)
# 976 21.388057708740234 tensor([1.0061, 3.7336], grad_fn=<SliceBackward>)
# 977 21.476818084716797 tensor([1.0074, 3.7339], grad_fn=<SliceBackward>)
# 978 21.27983856201172 tensor([1.0085, 3.7344], grad_fn=<SliceBackward>)
# 979 21.404726028442383 tensor([1.0094, 3.7348], grad_fn=<SliceBackward>)
# 980 21.349468231201172 tensor([1.0104, 3.7351], grad_fn=<SliceBackward>)
# 981 21.44285774230957 tensor([1.0109, 3.7355], grad_fn=<SliceBackward>)
# 982 21.382396697998047 tensor([1.0118, 3.7358], grad_fn=<SliceBackward>)
# 983 21.438400268554688 tensor([1.0128, 3.7361], grad_fn=<SliceBackward>)
# 984 21.38645362854004 tensor([1.0144, 3.7365], grad_fn=<SliceBackward>)
# 985 21.16069984436035 tensor([1.0158, 3.7368], grad_fn=<SliceBackward>)
# 986 21.532791137695312 tensor([1.0173, 3.7372], grad_fn=<SliceBackward>)
# 987 21.3844051361084 tensor([1.0183, 3.7377], grad_fn=<SliceBackward>)
# 988 21.415237426757812 tensor([1.0192, 3.7380], grad_fn=<SliceBackward>)
# 989 21.39162826538086 tensor([1.0195, 3.7384], grad_fn=<SliceBackward>)
# 990 21.1431941986084 tensor([1.0196, 3.7389], grad_fn=<SliceBackward>)
# 991 21.425294876098633 tensor([1.0195, 3.7394], grad_fn=<SliceBackward>)
# 992 21.482715606689453 tensor([1.0192, 3.7399], grad_fn=<SliceBackward>)
# 993 21.391677856445312 tensor([1.0188, 3.7404], grad_fn=<SliceBackward>)
# 994 21.41445541381836 tensor([1.0186, 3.7409], grad_fn=<SliceBackward>)
# 995 21.26642608642578 tensor([1.0184, 3.7414], grad_fn=<SliceBackward>)
# 996 21.26250648498535 tensor([1.0183, 3.7419], grad_fn=<SliceBackward>)
# 997 21.239442825317383 tensor([1.0179, 3.7423], grad_fn=<SliceBackward>)
# 998 21.34638214111328 tensor([1.0179, 3.7428], grad_fn=<SliceBackward>)
# 999 21.229780197143555 tensor([1.0172, 3.7433], grad_fn=<SliceBackward>)
# 327.26300048828125
# 21.229780197143555
# tensor([ 1.0167,  3.7439,  2.3835, -0.3236, -0.2000, -0.5895,  1.6788, -1.9639,
#          2.6110,  3.1929,  2.3323,  4.1740,  4.3751,  2.5949],
#        requires_grad=True)
# 5 [0.7763157894736842, 0.8486842105263158, 0.7894736842105263, 0.7763157894736842, 0.8223684210526315]

# %%
print(test_acc)
test_acc = np.array(test_acc)
print('{}({})'.format(test_acc.mean(), test_acc.std()))
# Out:
# [0.7763157894736842, 0.8486842105263158, 0.7894736842105263, 0.7763157894736842, 0.8223684210526315]
# 0.8026315789473685(0.028525636037735273)

# %% [markdown]
# # RPM 10% Noise

# %%
from scipy.io import loadmat, savemat
import os
import numpy as np
import math
import random
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.normal import Normal
from torch.distributions.kl import kl_divergence
from torch.nn import BCEWithLogitsLoss
from util import VNet3
from torch.distributions.beta import Beta
import pandas as pd

def evaluate_likelihood(Y, score):#, sigma
    s = torch.sigmoid(score)
    likelihood = s ** Y * (1 - s) ** (1 - Y)
    return likelihood

test_acc = []

for k in range(5):
    
    
    data = loadmat('./heart_10%_{}.mat'.format(k+1))
    X_train = torch.tensor(data['X_train'], dtype=torch.float32)
    y_train = torch.tensor(data['y_train'], dtype=torch.float32)
    X_meta = torch.tensor(data['X_meta'], dtype=torch.float32)
    y_meta = torch.tensor(data['y_meta'], dtype=torch.float32)
    X_test = torch.tensor(data['X_test'], dtype=torch.float32)
    y_test = torch.tensor(data['y_test'], dtype=torch.float32)
    print(X_train.shape[0], X_meta.shape[0], X_test.shape[0])
    
    l = 1000

    Y_train = y_train.repeat(l, 1).t()
    Y_test = y_test.repeat(l, 1).t()
    Y_meta = y_meta.repeat(l, 1).t()
    
    n, p = np.shape(X_train)
    p = p + 1
    
    
    lam = 100
    beta_prior = MultivariateNormal(loc=torch.zeros(p), covariance_matrix=lam * torch.eye(p))
    v_prior = Beta(0.01 * torch.ones(n), 0.01 * torch.ones(n))

    
    mu = torch.zeros(p, requires_grad=True)
    v_log_diag = torch.rand([p], requires_grad=True)
    v_non_diag = torch.randn([int(p * (p - 1) / 2)], requires_grad=True)
    L_indices_non_diag = torch.tril_indices(row=p, col=p, offset=-1)
    a = torch.rand(n, requires_grad=True)
    b = torch.rand(n, requires_grad=True)

    
    likelihood = BCEWithLogitsLoss(reduction='sum')

    
    l = 1000
    Y_train = y_train.repeat(l, 1).t()

    optimizer = torch.optim.Adam([mu, v_log_diag, v_non_diag, a, b], lr=0.01)

    num_iters = 1000

    loss_all = []

    for iters in range(num_iters):
        
        L = torch.diag(torch.exp(v_log_diag))
        L[L_indices_non_diag[0], L_indices_non_diag[1]] = v_non_diag

        
        beta_post = MultivariateNormal(loc=mu, scale_tril=L)

        
        beta = beta_post.rsample(sample_shape=[l])
    
        v_post = Beta(a, b)
        v = v_post.rsample(sample_shape=[l])

        # pred_logit = torch.matmul(X_train, beta.t())
        pred_logit = torch.matmul(X_train, beta[:,:p-1].t()) + beta[:,p-1].repeat(X_train.shape[0], 1)
        likeli = evaluate_likelihood(Y_train, pred_logit) + 1e-40
        loss = - (v.mean(dim = 0) * torch.log(likeli).mean(dim = 1)).mean() + kl_divergence(beta_post, beta_prior) + kl_divergence(v_post, v_prior).sum()
    
        print(iters, loss.item(), mu[:2])

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_all.append(loss.item())

    print(loss_all[0])
    print(loss_all[-1])
    print(mu)

    plt.plot(loss_all)
    plt.show()
    
    y_test[y_test == 0] = -1
    
    def acc_cal(a,b):
        
        l = a.shape[0]
        assert l == b.shape[0]
    
        t = torch.sign(a * b)
        hit = t[t>0].shape[0]
        # hit = torch.sign(a*b).sum()
    
        return hit / l

    beta_post = MultivariateNormal(loc = mu, scale_tril = L)
    wb = beta_post.rsample(sample_shape=[l])
    aa = torch.matmul(X_test, wb[:,:p-1].t()) + wb[:,p-1].repeat(X_test.shape[0], 1)
    acc = acc_cal(aa.mean(dim = 1), y_test[0])
    test_acc.append(acc)

    print(k+1, test_acc)
# Out:
# 121 26 152
# 0 324.07061767578125 tensor([0., 0.], grad_fn=<SliceBackward>)
# 1 318.94073486328125 tensor([0.0100, 0.0100], grad_fn=<SliceBackward>)
# 2 313.533203125 tensor([0.0200, 0.0200], grad_fn=<SliceBackward>)
# 3 307.41583251953125 tensor([0.0300, 0.0300], grad_fn=<SliceBackward>)
# 4 304.7711181640625 tensor([0.0400, 0.0400], grad_fn=<SliceBackward>)
# 5 302.3777770996094 tensor([0.0499, 0.0500], grad_fn=<SliceBackward>)
# 6 293.2635498046875 tensor([0.0598, 0.0600], grad_fn=<SliceBackward>)
# 7 287.4561462402344 tensor([0.0697, 0.0700], grad_fn=<SliceBackward>)
# 8 291.13153076171875 tensor([0.0796, 0.0800], grad_fn=<SliceBackward>)
# 9 284.46771240234375 tensor([0.0896, 0.0900], grad_fn=<SliceBackward>)
# 10 273.9062194824219 tensor([0.0995, 0.0999], grad_fn=<SliceBackward>)
# 11 278.2524108886719 tensor([0.1094, 0.1100], grad_fn=<SliceBackward>)
# 12 264.9117736816406 tensor([0.1193, 0.1200], grad_fn=<SliceBackward>)
# 13 259.1634216308594 tensor([0.1293, 0.1300], grad_fn=<SliceBackward>)
# 14 276.5908203125 tensor([0.1392, 0.1400], grad_fn=<SliceBackward>)
# 15 260.4105224609375 tensor([0.1492, 0.1500], grad_fn=<SliceBackward>)
# 16 262.1673583984375 tensor([0.1592, 0.1599], grad_fn=<SliceBackward>)
# 17 242.0634002685547 tensor([0.1693, 0.1699], grad_fn=<SliceBackward>)
# 18 240.7406005859375 tensor([0.1793, 0.1798], grad_fn=<SliceBackward>)
# 19 232.2975311279297 tensor([0.1893, 0.1897], grad_fn=<SliceBackward>)
# 20 232.36192321777344 tensor([0.1993, 0.1995], grad_fn=<SliceBackward>)
# 21 233.0947723388672 tensor([0.2093, 0.2093], grad_fn=<SliceBackward>)
# 22 218.799560546875 tensor([0.2193, 0.2191], grad_fn=<SliceBackward>)
# 23 217.823974609375 tensor([0.2292, 0.2288], grad_fn=<SliceBackward>)
# 24 209.38015747070312 tensor([0.2392, 0.2386], grad_fn=<SliceBackward>)
# 25 206.678955078125 tensor([0.2493, 0.2483], grad_fn=<SliceBackward>)
# 26 212.0436248779297 tensor([0.2593, 0.2579], grad_fn=<SliceBackward>)
# 27 162.56051635742188 tensor([0.2692, 0.2675], grad_fn=<SliceBackward>)
# 28 171.04127502441406 tensor([0.2792, 0.2771], grad_fn=<SliceBackward>)
# 29 194.1561737060547 tensor([0.2892, 0.2867], grad_fn=<SliceBackward>)
# 30 173.5294952392578 tensor([0.2991, 0.2963], grad_fn=<SliceBackward>)
# 31 162.27655029296875 tensor([0.3091, 0.3059], grad_fn=<SliceBackward>)
# 32 177.58929443359375 tensor([0.3190, 0.3154], grad_fn=<SliceBackward>)
# 33 147.256591796875 tensor([0.3289, 0.3250], grad_fn=<SliceBackward>)
# 34 156.3402099609375 tensor([0.3387, 0.3345], grad_fn=<SliceBackward>)
# 35 148.1649932861328 tensor([0.3485, 0.3439], grad_fn=<SliceBackward>)
# 36 163.997314453125 tensor([0.3581, 0.3534], grad_fn=<SliceBackward>)
# 37 131.76669311523438 tensor([0.3676, 0.3630], grad_fn=<SliceBackward>)
# 38 153.80398559570312 tensor([0.3771, 0.3725], grad_fn=<SliceBackward>)
# 39 149.9632568359375 tensor([0.3865, 0.3819], grad_fn=<SliceBackward>)
# 40 151.41229248046875 tensor([0.3959, 0.3912], grad_fn=<SliceBackward>)
# 41 148.20611572265625 tensor([0.4051, 0.4006], grad_fn=<SliceBackward>)
# 42 156.97930908203125 tensor([0.4142, 0.4100], grad_fn=<SliceBackward>)
# 43 142.09210205078125 tensor([0.4232, 0.4196], grad_fn=<SliceBackward>)
# 44 126.90555572509766 tensor([0.4322, 0.4292], grad_fn=<SliceBackward>)
# 45 142.6614990234375 tensor([0.4410, 0.4389], grad_fn=<SliceBackward>)
# 46 63.23536682128906 tensor([0.4497, 0.4487], grad_fn=<SliceBackward>)
# 47 119.58563232421875 tensor([0.4583, 0.4585], grad_fn=<SliceBackward>)
# 48 592.0947265625 tensor([0.4666, 0.4681], grad_fn=<SliceBackward>)
# 49 128.65426635742188 tensor([0.4749, 0.4778], grad_fn=<SliceBackward>)
# 50 126.4129409790039 tensor([0.4832, 0.4874], grad_fn=<SliceBackward>)
# 51 124.23332214355469 tensor([0.4912, 0.4970], grad_fn=<SliceBackward>)
# 52 122.39483642578125 tensor([0.4992, 0.5065], grad_fn=<SliceBackward>)
# 53 122.1649169921875 tensor([0.5071, 0.5160], grad_fn=<SliceBackward>)
# 54 121.06511688232422 tensor([0.5149, 0.5253], grad_fn=<SliceBackward>)
# 55 118.52609252929688 tensor([0.5224, 0.5344], grad_fn=<SliceBackward>)
# 56 106.25875854492188 tensor([0.5297, 0.5434], grad_fn=<SliceBackward>)
# 57 109.39094543457031 tensor([0.5369, 0.5522], grad_fn=<SliceBackward>)
# 58 108.97319793701172 tensor([0.5441, 0.5609], grad_fn=<SliceBackward>)
# 59 81.69822692871094 tensor([0.5511, 0.5696], grad_fn=<SliceBackward>)
# 60 108.22777557373047 tensor([0.5580, 0.5780], grad_fn=<SliceBackward>)
# 61 106.4092788696289 tensor([0.5649, 0.5863], grad_fn=<SliceBackward>)
# 62 88.85009765625 tensor([0.5717, 0.5945], grad_fn=<SliceBackward>)
# 63 146.67478942871094 tensor([0.5784, 0.6025], grad_fn=<SliceBackward>)
# 64 84.42340087890625 tensor([0.5850, 0.6106], grad_fn=<SliceBackward>)
# 65 91.15867614746094 tensor([0.5916, 0.6186], grad_fn=<SliceBackward>)
# 66 552.5687866210938 tensor([0.5980, 0.6265], grad_fn=<SliceBackward>)
# 67 35.0694580078125 tensor([0.6044, 0.6345], grad_fn=<SliceBackward>)
# 68 88.30668640136719 tensor([0.6107, 0.6425], grad_fn=<SliceBackward>)
# 69 87.47725677490234 tensor([0.6169, 0.6505], grad_fn=<SliceBackward>)
# 70 -616.5310668945312 tensor([0.6231, 0.6585], grad_fn=<SliceBackward>)
# 71 74.04153442382812 tensor([0.6294, 0.6664], grad_fn=<SliceBackward>)
# 72 93.29129791259766 tensor([0.6357, 0.6744], grad_fn=<SliceBackward>)
# 73 67.68294525146484 tensor([0.6421, 0.6823], grad_fn=<SliceBackward>)
# 74 56.27769088745117 tensor([0.6487, 0.6902], grad_fn=<SliceBackward>)
# 75 78.18267059326172 tensor([0.6553, 0.6980], grad_fn=<SliceBackward>)
# 76 153.669921875 tensor([0.6618, 0.7058], grad_fn=<SliceBackward>)
# 77 63.576507568359375 tensor([0.6683, 0.7133], grad_fn=<SliceBackward>)
# 78 69.72281646728516 tensor([0.6747, 0.7208], grad_fn=<SliceBackward>)
# 79 78.79368591308594 tensor([0.6811, 0.7282], grad_fn=<SliceBackward>)
# 80 69.80473327636719 tensor([0.6876, 0.7352], grad_fn=<SliceBackward>)
# 81 75.82963562011719 tensor([0.6940, 0.7420], grad_fn=<SliceBackward>)
# 82 -400.1144104003906 tensor([0.7004, 0.7486], grad_fn=<SliceBackward>)
# 83 76.1409683227539 tensor([0.7069, 0.7551], grad_fn=<SliceBackward>)
# 84 75.40353393554688 tensor([0.7136, 0.7615], grad_fn=<SliceBackward>)
# 85 74.2581787109375 tensor([0.7204, 0.7679], grad_fn=<SliceBackward>)
# 86 61.94758605957031 tensor([0.7275, 0.7742], grad_fn=<SliceBackward>)
# 87 45.53834533691406 tensor([0.7346, 0.7805], grad_fn=<SliceBackward>)
# 88 73.71987915039062 tensor([0.7418, 0.7868], grad_fn=<SliceBackward>)
# 89 72.89710998535156 tensor([0.7491, 0.7930], grad_fn=<SliceBackward>)
# 90 63.738739013671875 tensor([0.7565, 0.7993], grad_fn=<SliceBackward>)
# 91 84.36475372314453 tensor([0.7639, 0.8055], grad_fn=<SliceBackward>)
# 92 73.33323669433594 tensor([0.7715, 0.8119], grad_fn=<SliceBackward>)
# 93 73.45618438720703 tensor([0.7790, 0.8182], grad_fn=<SliceBackward>)
# 94 74.99329376220703 tensor([0.7865, 0.8245], grad_fn=<SliceBackward>)
# 95 73.48474884033203 tensor([0.7940, 0.8308], grad_fn=<SliceBackward>)
# 96 73.22545623779297 tensor([0.8016, 0.8371], grad_fn=<SliceBackward>)
# 97 77.87181091308594 tensor([0.8092, 0.8434], grad_fn=<SliceBackward>)
# 98 73.27950286865234 tensor([0.8170, 0.8497], grad_fn=<SliceBackward>)
# 99 73.51631927490234 tensor([0.8247, 0.8560], grad_fn=<SliceBackward>)
# 100 73.43223571777344 tensor([0.8325, 0.8621], grad_fn=<SliceBackward>)
# 101 73.25360107421875 tensor([0.8403, 0.8682], grad_fn=<SliceBackward>)
# 102 73.00089263916016 tensor([0.8480, 0.8742], grad_fn=<SliceBackward>)
# 103 72.93299102783203 tensor([0.8557, 0.8802], grad_fn=<SliceBackward>)
# 104 72.78861999511719 tensor([0.8633, 0.8862], grad_fn=<SliceBackward>)
# 105 72.4131088256836 tensor([0.8708, 0.8922], grad_fn=<SliceBackward>)
# 106 72.242919921875 tensor([0.8783, 0.8982], grad_fn=<SliceBackward>)
# 107 71.93096923828125 tensor([0.8857, 0.9041], grad_fn=<SliceBackward>)
# 108 71.62777709960938 tensor([0.8930, 0.9098], grad_fn=<SliceBackward>)
# 109 71.19342803955078 tensor([0.9002, 0.9155], grad_fn=<SliceBackward>)
# 110 70.85235595703125 tensor([0.9074, 0.9211], grad_fn=<SliceBackward>)
# 111 70.71456909179688 tensor([0.9145, 0.9267], grad_fn=<SliceBackward>)
# 112 70.45777893066406 tensor([0.9215, 0.9322], grad_fn=<SliceBackward>)
# 113 70.10875701904297 tensor([0.9286, 0.9377], grad_fn=<SliceBackward>)
# 114 69.92493438720703 tensor([0.9357, 0.9431], grad_fn=<SliceBackward>)
# 115 69.37223052978516 tensor([0.9428, 0.9485], grad_fn=<SliceBackward>)
# 116 68.93234252929688 tensor([0.9498, 0.9539], grad_fn=<SliceBackward>)
# 117 68.74223327636719 tensor([0.9568, 0.9592], grad_fn=<SliceBackward>)
# 118 68.35810852050781 tensor([0.9637, 0.9644], grad_fn=<SliceBackward>)
# 119 68.12213134765625 tensor([0.9706, 0.9697], grad_fn=<SliceBackward>)
# 120 67.81450653076172 tensor([0.9775, 0.9749], grad_fn=<SliceBackward>)
# 121 67.41448974609375 tensor([0.9844, 0.9800], grad_fn=<SliceBackward>)
# 122 67.3824462890625 tensor([0.9913, 0.9851], grad_fn=<SliceBackward>)
# 123 66.98942565917969 tensor([0.9981, 0.9902], grad_fn=<SliceBackward>)
# 124 66.48381805419922 tensor([1.0050, 0.9951], grad_fn=<SliceBackward>)
# 125 66.16415405273438 tensor([1.0118, 1.0001], grad_fn=<SliceBackward>)
# 126 65.93119812011719 tensor([1.0187, 1.0049], grad_fn=<SliceBackward>)
# 127 65.51502227783203 tensor([1.0255, 1.0097], grad_fn=<SliceBackward>)
# 128 65.26527404785156 tensor([1.0324, 1.0145], grad_fn=<SliceBackward>)
# 129 65.07181549072266 tensor([1.0392, 1.0193], grad_fn=<SliceBackward>)
# 130 64.82440948486328 tensor([1.0461, 1.0241], grad_fn=<SliceBackward>)
# 131 64.46223449707031 tensor([1.0529, 1.0288], grad_fn=<SliceBackward>)
# 132 64.23298645019531 tensor([1.0597, 1.0335], grad_fn=<SliceBackward>)
# 133 63.86235427856445 tensor([1.0665, 1.0382], grad_fn=<SliceBackward>)
# 134 63.51111602783203 tensor([1.0733, 1.0429], grad_fn=<SliceBackward>)
# 135 63.202117919921875 tensor([1.0801, 1.0475], grad_fn=<SliceBackward>)
# 136 62.97687530517578 tensor([1.0869, 1.0521], grad_fn=<SliceBackward>)
# 137 62.76209259033203 tensor([1.0938, 1.0567], grad_fn=<SliceBackward>)
# 138 62.339717864990234 tensor([1.1008, 1.0613], grad_fn=<SliceBackward>)
# 139 62.13196563720703 tensor([1.1077, 1.0658], grad_fn=<SliceBackward>)
# 140 61.85734939575195 tensor([1.1147, 1.0703], grad_fn=<SliceBackward>)
# 141 61.51915740966797 tensor([1.1216, 1.0748], grad_fn=<SliceBackward>)
# 142 61.12458038330078 tensor([1.1284, 1.0793], grad_fn=<SliceBackward>)
# 143 61.01856994628906 tensor([1.1353, 1.0837], grad_fn=<SliceBackward>)
# 144 60.53987121582031 tensor([1.1421, 1.0880], grad_fn=<SliceBackward>)
# 145 60.175994873046875 tensor([1.1489, 1.0923], grad_fn=<SliceBackward>)
# 146 59.99637222290039 tensor([1.1557, 1.0967], grad_fn=<SliceBackward>)
# 147 59.658958435058594 tensor([1.1625, 1.1009], grad_fn=<SliceBackward>)
# 148 59.37290954589844 tensor([1.1692, 1.1052], grad_fn=<SliceBackward>)
# 149 59.14308547973633 tensor([1.1760, 1.1093], grad_fn=<SliceBackward>)
# 150 58.65787124633789 tensor([1.1826, 1.1135], grad_fn=<SliceBackward>)
# 151 58.37633514404297 tensor([1.1892, 1.1175], grad_fn=<SliceBackward>)
# 152 58.07991027832031 tensor([1.1958, 1.1215], grad_fn=<SliceBackward>)
# 153 57.725135803222656 tensor([1.2024, 1.1254], grad_fn=<SliceBackward>)
# 154 57.18793487548828 tensor([1.2090, 1.1293], grad_fn=<SliceBackward>)
# 155 57.109310150146484 tensor([1.2155, 1.1332], grad_fn=<SliceBackward>)
# 156 56.88812255859375 tensor([1.2220, 1.1369], grad_fn=<SliceBackward>)
# 157 56.80259704589844 tensor([1.2284, 1.1406], grad_fn=<SliceBackward>)
# 158 56.5040283203125 tensor([1.2347, 1.1442], grad_fn=<SliceBackward>)
# 159 56.311737060546875 tensor([1.2409, 1.1477], grad_fn=<SliceBackward>)
# 160 55.80400466918945 tensor([1.2470, 1.1511], grad_fn=<SliceBackward>)
# 161 55.680572509765625 tensor([1.2530, 1.1546], grad_fn=<SliceBackward>)
# 162 55.642730712890625 tensor([1.2590, 1.1579], grad_fn=<SliceBackward>)
# 163 55.68720245361328 tensor([1.2649, 1.1612], grad_fn=<SliceBackward>)
# 164 55.287696838378906 tensor([1.2709, 1.1645], grad_fn=<SliceBackward>)
# 165 54.83866882324219 tensor([1.2768, 1.1677], grad_fn=<SliceBackward>)
# 166 54.80643844604492 tensor([1.2827, 1.1709], grad_fn=<SliceBackward>)
# 167 54.27012252807617 tensor([1.2886, 1.1740], grad_fn=<SliceBackward>)
# 168 54.047996520996094 tensor([1.2945, 1.1772], grad_fn=<SliceBackward>)
# 169 53.75884246826172 tensor([1.3004, 1.1802], grad_fn=<SliceBackward>)
# 170 53.538818359375 tensor([1.3061, 1.1833], grad_fn=<SliceBackward>)
# 171 53.28045654296875 tensor([1.3119, 1.1865], grad_fn=<SliceBackward>)
# 172 53.13957214355469 tensor([1.3176, 1.1895], grad_fn=<SliceBackward>)
# 173 52.75503158569336 tensor([1.3233, 1.1926], grad_fn=<SliceBackward>)
# 174 52.65182876586914 tensor([1.3289, 1.1958], grad_fn=<SliceBackward>)
# 175 52.51519012451172 tensor([1.3346, 1.1988], grad_fn=<SliceBackward>)
# 176 52.2806282043457 tensor([1.3402, 1.2020], grad_fn=<SliceBackward>)
# 177 51.98907470703125 tensor([1.3458, 1.2051], grad_fn=<SliceBackward>)
# 178 51.73963928222656 tensor([1.3515, 1.2083], grad_fn=<SliceBackward>)
# 179 51.53477096557617 tensor([1.3571, 1.2115], grad_fn=<SliceBackward>)
# 180 51.134002685546875 tensor([1.3628, 1.2148], grad_fn=<SliceBackward>)
# 181 50.83412170410156 tensor([1.3684, 1.2181], grad_fn=<SliceBackward>)
# 182 50.85860824584961 tensor([1.3739, 1.2213], grad_fn=<SliceBackward>)
# 183 50.564300537109375 tensor([1.3795, 1.2246], grad_fn=<SliceBackward>)
# 184 50.13947677612305 tensor([1.3851, 1.2279], grad_fn=<SliceBackward>)
# 185 50.08746337890625 tensor([1.3907, 1.2313], grad_fn=<SliceBackward>)
# 186 50.071502685546875 tensor([1.3962, 1.2346], grad_fn=<SliceBackward>)
# 187 49.69173812866211 tensor([1.4017, 1.2380], grad_fn=<SliceBackward>)
# 188 49.509117126464844 tensor([1.4072, 1.2415], grad_fn=<SliceBackward>)
# 189 49.31764221191406 tensor([1.4127, 1.2449], grad_fn=<SliceBackward>)
# 190 49.31081008911133 tensor([1.4181, 1.2483], grad_fn=<SliceBackward>)
# 191 48.93780517578125 tensor([1.4236, 1.2517], grad_fn=<SliceBackward>)
# 192 48.93248748779297 tensor([1.4290, 1.2550], grad_fn=<SliceBackward>)
# 193 48.55968475341797 tensor([1.4345, 1.2583], grad_fn=<SliceBackward>)
# 194 48.50445556640625 tensor([1.4400, 1.2617], grad_fn=<SliceBackward>)
# 195 48.26360321044922 tensor([1.4454, 1.2650], grad_fn=<SliceBackward>)
# 196 47.890438079833984 tensor([1.4507, 1.2683], grad_fn=<SliceBackward>)
# 197 47.68659973144531 tensor([1.4560, 1.2715], grad_fn=<SliceBackward>)
# 198 47.61888122558594 tensor([1.4613, 1.2748], grad_fn=<SliceBackward>)
# 199 47.39265441894531 tensor([1.4665, 1.2781], grad_fn=<SliceBackward>)
# 200 47.31455612182617 tensor([1.4718, 1.2813], grad_fn=<SliceBackward>)
# 201 46.97843933105469 tensor([1.4771, 1.2846], grad_fn=<SliceBackward>)
# 202 46.76155471801758 tensor([1.4824, 1.2878], grad_fn=<SliceBackward>)
# 203 46.466552734375 tensor([1.4877, 1.2911], grad_fn=<SliceBackward>)
# 204 46.57611846923828 tensor([1.4929, 1.2943], grad_fn=<SliceBackward>)
# 205 46.43558120727539 tensor([1.4981, 1.2975], grad_fn=<SliceBackward>)
# 206 45.98615646362305 tensor([1.5033, 1.3007], grad_fn=<SliceBackward>)
# 207 46.02060317993164 tensor([1.5084, 1.3038], grad_fn=<SliceBackward>)
# 208 45.918243408203125 tensor([1.5135, 1.3068], grad_fn=<SliceBackward>)
# 209 45.3359375 tensor([1.5186, 1.3098], grad_fn=<SliceBackward>)
# 210 45.40087890625 tensor([1.5236, 1.3127], grad_fn=<SliceBackward>)
# 211 45.37437438964844 tensor([1.5287, 1.3156], grad_fn=<SliceBackward>)
# 212 45.11624526977539 tensor([1.5337, 1.3185], grad_fn=<SliceBackward>)
# 213 45.191162109375 tensor([1.5386, 1.3213], grad_fn=<SliceBackward>)
# 214 44.86651611328125 tensor([1.5436, 1.3241], grad_fn=<SliceBackward>)
# 215 44.89055633544922 tensor([1.5485, 1.3269], grad_fn=<SliceBackward>)
# 216 44.57699966430664 tensor([1.5534, 1.3298], grad_fn=<SliceBackward>)
# 217 44.40581130981445 tensor([1.5582, 1.3326], grad_fn=<SliceBackward>)
# 218 44.46922302246094 tensor([1.5629, 1.3355], grad_fn=<SliceBackward>)
# 219 44.273223876953125 tensor([1.5677, 1.3383], grad_fn=<SliceBackward>)
# 220 44.16670227050781 tensor([1.5725, 1.3411], grad_fn=<SliceBackward>)
# 221 43.95709228515625 tensor([1.5773, 1.3439], grad_fn=<SliceBackward>)
# 222 43.87793731689453 tensor([1.5821, 1.3466], grad_fn=<SliceBackward>)
# 223 43.60923767089844 tensor([1.5869, 1.3494], grad_fn=<SliceBackward>)
# 224 43.554847717285156 tensor([1.5918, 1.3521], grad_fn=<SliceBackward>)
# 225 43.163089752197266 tensor([1.5966, 1.3549], grad_fn=<SliceBackward>)
# 226 43.25625228881836 tensor([1.6013, 1.3577], grad_fn=<SliceBackward>)
# 227 43.21582794189453 tensor([1.6060, 1.3604], grad_fn=<SliceBackward>)
# 228 42.7928581237793 tensor([1.6107, 1.3631], grad_fn=<SliceBackward>)
# 229 42.64252471923828 tensor([1.6155, 1.3658], grad_fn=<SliceBackward>)
# 230 42.74992370605469 tensor([1.6203, 1.3685], grad_fn=<SliceBackward>)
# 231 42.2982292175293 tensor([1.6250, 1.3711], grad_fn=<SliceBackward>)
# 232 42.2232666015625 tensor([1.6297, 1.3738], grad_fn=<SliceBackward>)
# 233 42.032073974609375 tensor([1.6344, 1.3765], grad_fn=<SliceBackward>)
# 234 42.02216339111328 tensor([1.6391, 1.3791], grad_fn=<SliceBackward>)
# 235 41.796749114990234 tensor([1.6437, 1.3817], grad_fn=<SliceBackward>)
# 236 41.5760498046875 tensor([1.6484, 1.3844], grad_fn=<SliceBackward>)
# 237 41.47761917114258 tensor([1.6530, 1.3869], grad_fn=<SliceBackward>)
# 238 41.30560302734375 tensor([1.6575, 1.3894], grad_fn=<SliceBackward>)
# 239 41.22742462158203 tensor([1.6621, 1.3920], grad_fn=<SliceBackward>)
# 240 41.104095458984375 tensor([1.6666, 1.3946], grad_fn=<SliceBackward>)
# 241 41.058738708496094 tensor([1.6712, 1.3971], grad_fn=<SliceBackward>)
# 242 40.88197708129883 tensor([1.6758, 1.3997], grad_fn=<SliceBackward>)
# 243 40.71184539794922 tensor([1.6804, 1.4024], grad_fn=<SliceBackward>)
# 244 40.84043884277344 tensor([1.6851, 1.4050], grad_fn=<SliceBackward>)
# 245 40.26518630981445 tensor([1.6898, 1.4077], grad_fn=<SliceBackward>)
# 246 40.402069091796875 tensor([1.6945, 1.4105], grad_fn=<SliceBackward>)
# 247 40.28105926513672 tensor([1.6991, 1.4132], grad_fn=<SliceBackward>)
# 248 39.94696044921875 tensor([1.7037, 1.4159], grad_fn=<SliceBackward>)
# 249 39.87233352661133 tensor([1.7083, 1.4186], grad_fn=<SliceBackward>)
# 250 39.588748931884766 tensor([1.7129, 1.4213], grad_fn=<SliceBackward>)
# 251 39.408111572265625 tensor([1.7175, 1.4241], grad_fn=<SliceBackward>)
# 252 39.41307830810547 tensor([1.7220, 1.4268], grad_fn=<SliceBackward>)
# 253 38.94561767578125 tensor([1.7266, 1.4295], grad_fn=<SliceBackward>)
# 254 39.145442962646484 tensor([1.7311, 1.4321], grad_fn=<SliceBackward>)
# 255 38.687782287597656 tensor([1.7356, 1.4348], grad_fn=<SliceBackward>)
# 256 38.68938446044922 tensor([1.7400, 1.4373], grad_fn=<SliceBackward>)
# 257 38.693572998046875 tensor([1.7443, 1.4399], grad_fn=<SliceBackward>)
# 258 38.402305603027344 tensor([1.7487, 1.4424], grad_fn=<SliceBackward>)
# 259 38.34945297241211 tensor([1.7530, 1.4448], grad_fn=<SliceBackward>)
# 260 38.26017761230469 tensor([1.7573, 1.4472], grad_fn=<SliceBackward>)
# 261 38.12054443359375 tensor([1.7616, 1.4496], grad_fn=<SliceBackward>)
# 262 38.02396774291992 tensor([1.7659, 1.4522], grad_fn=<SliceBackward>)
# 263 37.673343658447266 tensor([1.7701, 1.4548], grad_fn=<SliceBackward>)
# 264 37.49912643432617 tensor([1.7744, 1.4573], grad_fn=<SliceBackward>)
# 265 37.19972229003906 tensor([1.7786, 1.4600], grad_fn=<SliceBackward>)
# 266 37.03281021118164 tensor([1.7828, 1.4625], grad_fn=<SliceBackward>)
# 267 36.99567413330078 tensor([1.7870, 1.4652], grad_fn=<SliceBackward>)
# 268 36.92054748535156 tensor([1.7911, 1.4678], grad_fn=<SliceBackward>)
# 269 36.96522521972656 tensor([1.7951, 1.4704], grad_fn=<SliceBackward>)
# 270 36.641300201416016 tensor([1.7991, 1.4730], grad_fn=<SliceBackward>)
# 271 36.67703628540039 tensor([1.8031, 1.4757], grad_fn=<SliceBackward>)
# 272 36.30933380126953 tensor([1.8071, 1.4783], grad_fn=<SliceBackward>)
# 273 36.484901428222656 tensor([1.8111, 1.4810], grad_fn=<SliceBackward>)
# 274 35.96890640258789 tensor([1.8151, 1.4835], grad_fn=<SliceBackward>)
# 275 35.96906280517578 tensor([1.8190, 1.4861], grad_fn=<SliceBackward>)
# 276 35.6324462890625 tensor([1.8230, 1.4888], grad_fn=<SliceBackward>)
# 277 35.542816162109375 tensor([1.8269, 1.4914], grad_fn=<SliceBackward>)
# 278 35.566524505615234 tensor([1.8309, 1.4940], grad_fn=<SliceBackward>)
# 279 35.54263687133789 tensor([1.8348, 1.4966], grad_fn=<SliceBackward>)
# 280 35.39128875732422 tensor([1.8386, 1.4993], grad_fn=<SliceBackward>)
# 281 35.229583740234375 tensor([1.8424, 1.5020], grad_fn=<SliceBackward>)
# 282 35.19508743286133 tensor([1.8461, 1.5048], grad_fn=<SliceBackward>)
# 283 34.912864685058594 tensor([1.8498, 1.5076], grad_fn=<SliceBackward>)
# 284 34.66975021362305 tensor([1.8536, 1.5105], grad_fn=<SliceBackward>)
# 285 34.59527587890625 tensor([1.8573, 1.5133], grad_fn=<SliceBackward>)
# 286 34.40272521972656 tensor([1.8610, 1.5162], grad_fn=<SliceBackward>)
# 287 34.41950988769531 tensor([1.8647, 1.5192], grad_fn=<SliceBackward>)
# 288 34.00492477416992 tensor([1.8683, 1.5221], grad_fn=<SliceBackward>)
# 289 33.89970779418945 tensor([1.8719, 1.5250], grad_fn=<SliceBackward>)
# 290 34.012176513671875 tensor([1.8753, 1.5279], grad_fn=<SliceBackward>)
# 291 33.674285888671875 tensor([1.8788, 1.5307], grad_fn=<SliceBackward>)
# 292 33.36639404296875 tensor([1.8823, 1.5335], grad_fn=<SliceBackward>)
# 293 33.20478820800781 tensor([1.8857, 1.5362], grad_fn=<SliceBackward>)
# 294 33.14109802246094 tensor([1.8892, 1.5390], grad_fn=<SliceBackward>)
# 295 33.12305450439453 tensor([1.8926, 1.5417], grad_fn=<SliceBackward>)
# 296 33.047760009765625 tensor([1.8959, 1.5445], grad_fn=<SliceBackward>)
# 297 32.77023696899414 tensor([1.8992, 1.5473], grad_fn=<SliceBackward>)
# 298 32.630584716796875 tensor([1.9025, 1.5500], grad_fn=<SliceBackward>)
# 299 32.588966369628906 tensor([1.9057, 1.5527], grad_fn=<SliceBackward>)
# 300 32.47749328613281 tensor([1.9089, 1.5555], grad_fn=<SliceBackward>)
# 301 32.197322845458984 tensor([1.9120, 1.5583], grad_fn=<SliceBackward>)
# 302 32.12593078613281 tensor([1.9150, 1.5611], grad_fn=<SliceBackward>)
# 303 31.91546058654785 tensor([1.9181, 1.5638], grad_fn=<SliceBackward>)
# 304 31.976377487182617 tensor([1.9212, 1.5666], grad_fn=<SliceBackward>)
# 305 31.727636337280273 tensor([1.9242, 1.5693], grad_fn=<SliceBackward>)
# 306 31.7717227935791 tensor([1.9272, 1.5720], grad_fn=<SliceBackward>)
# 307 31.662187576293945 tensor([1.9302, 1.5747], grad_fn=<SliceBackward>)
# 308 31.457473754882812 tensor([1.9331, 1.5773], grad_fn=<SliceBackward>)
# 309 31.295888900756836 tensor([1.9360, 1.5799], grad_fn=<SliceBackward>)
# 310 31.17711639404297 tensor([1.9390, 1.5825], grad_fn=<SliceBackward>)
# 311 31.162994384765625 tensor([1.9419, 1.5850], grad_fn=<SliceBackward>)
# 312 31.073482513427734 tensor([1.9450, 1.5876], grad_fn=<SliceBackward>)
# 313 31.138750076293945 tensor([1.9479, 1.5901], grad_fn=<SliceBackward>)
# 314 30.921253204345703 tensor([1.9509, 1.5926], grad_fn=<SliceBackward>)
# 315 31.028757095336914 tensor([1.9540, 1.5951], grad_fn=<SliceBackward>)
# 316 30.70861053466797 tensor([1.9570, 1.5977], grad_fn=<SliceBackward>)
# 317 30.474939346313477 tensor([1.9600, 1.6002], grad_fn=<SliceBackward>)
# 318 30.68999671936035 tensor([1.9629, 1.6027], grad_fn=<SliceBackward>)
# 319 30.349807739257812 tensor([1.9659, 1.6052], grad_fn=<SliceBackward>)
# 320 30.33157730102539 tensor([1.9689, 1.6077], grad_fn=<SliceBackward>)
# 321 30.026504516601562 tensor([1.9717, 1.6103], grad_fn=<SliceBackward>)
# 322 30.003070831298828 tensor([1.9745, 1.6128], grad_fn=<SliceBackward>)
# 323 29.80970573425293 tensor([1.9773, 1.6153], grad_fn=<SliceBackward>)
# 324 29.94659423828125 tensor([1.9801, 1.6178], grad_fn=<SliceBackward>)
# 325 29.680984497070312 tensor([1.9829, 1.6203], grad_fn=<SliceBackward>)
# 326 29.857999801635742 tensor([1.9857, 1.6227], grad_fn=<SliceBackward>)
# 327 29.736705780029297 tensor([1.9885, 1.6252], grad_fn=<SliceBackward>)
# 328 29.623353958129883 tensor([1.9913, 1.6276], grad_fn=<SliceBackward>)
# 329 29.586166381835938 tensor([1.9941, 1.6301], grad_fn=<SliceBackward>)
# 330 29.480112075805664 tensor([1.9969, 1.6324], grad_fn=<SliceBackward>)
# 331 29.182050704956055 tensor([1.9996, 1.6348], grad_fn=<SliceBackward>)
# 332 29.317617416381836 tensor([2.0024, 1.6371], grad_fn=<SliceBackward>)
# 333 29.329471588134766 tensor([2.0052, 1.6393], grad_fn=<SliceBackward>)
# 334 28.829992294311523 tensor([2.0081, 1.6415], grad_fn=<SliceBackward>)
# 335 29.05769920349121 tensor([2.0107, 1.6437], grad_fn=<SliceBackward>)
# 336 28.925199508666992 tensor([2.0134, 1.6459], grad_fn=<SliceBackward>)
# 337 28.955307006835938 tensor([2.0160, 1.6480], grad_fn=<SliceBackward>)
# 338 28.86064338684082 tensor([2.0187, 1.6501], grad_fn=<SliceBackward>)
# 339 28.86071014404297 tensor([2.0213, 1.6522], grad_fn=<SliceBackward>)
# 340 28.767730712890625 tensor([2.0239, 1.6542], grad_fn=<SliceBackward>)
# 341 28.73188591003418 tensor([2.0265, 1.6563], grad_fn=<SliceBackward>)
# 342 28.357513427734375 tensor([2.0291, 1.6583], grad_fn=<SliceBackward>)
# 343 28.267410278320312 tensor([2.0315, 1.6604], grad_fn=<SliceBackward>)
# 344 28.30758285522461 tensor([2.0340, 1.6624], grad_fn=<SliceBackward>)
# 345 28.328533172607422 tensor([2.0364, 1.6644], grad_fn=<SliceBackward>)
# 346 28.27145767211914 tensor([2.0389, 1.6664], grad_fn=<SliceBackward>)
# 347 28.322402954101562 tensor([2.0413, 1.6684], grad_fn=<SliceBackward>)
# 348 28.151348114013672 tensor([2.0437, 1.6704], grad_fn=<SliceBackward>)
# 349 27.919933319091797 tensor([2.0461, 1.6724], grad_fn=<SliceBackward>)
# 350 27.981340408325195 tensor([2.0485, 1.6743], grad_fn=<SliceBackward>)
# 351 28.04499053955078 tensor([2.0508, 1.6762], grad_fn=<SliceBackward>)
# 352 28.083873748779297 tensor([2.0532, 1.6781], grad_fn=<SliceBackward>)
# 353 27.997486114501953 tensor([2.0556, 1.6800], grad_fn=<SliceBackward>)
# 354 27.73126220703125 tensor([2.0579, 1.6820], grad_fn=<SliceBackward>)
# 355 27.707359313964844 tensor([2.0602, 1.6839], grad_fn=<SliceBackward>)
# 356 27.77459144592285 tensor([2.0625, 1.6859], grad_fn=<SliceBackward>)
# 357 27.72327995300293 tensor([2.0648, 1.6879], grad_fn=<SliceBackward>)
# 358 27.80376434326172 tensor([2.0670, 1.6898], grad_fn=<SliceBackward>)
# 359 27.7032470703125 tensor([2.0692, 1.6918], grad_fn=<SliceBackward>)
# 360 27.61316680908203 tensor([2.0715, 1.6938], grad_fn=<SliceBackward>)
# 361 27.635719299316406 tensor([2.0738, 1.6957], grad_fn=<SliceBackward>)
# 362 27.57929801940918 tensor([2.0760, 1.6977], grad_fn=<SliceBackward>)
# 363 27.42816162109375 tensor([2.0782, 1.6996], grad_fn=<SliceBackward>)
# 364 27.37179183959961 tensor([2.0804, 1.7016], grad_fn=<SliceBackward>)
# 365 27.495431900024414 tensor([2.0826, 1.7035], grad_fn=<SliceBackward>)
# 366 27.575971603393555 tensor([2.0849, 1.7054], grad_fn=<SliceBackward>)
# 367 27.542299270629883 tensor([2.0871, 1.7073], grad_fn=<SliceBackward>)
# 368 27.142210006713867 tensor([2.0893, 1.7091], grad_fn=<SliceBackward>)
# 369 27.273534774780273 tensor([2.0915, 1.7109], grad_fn=<SliceBackward>)
# 370 27.25986671447754 tensor([2.0936, 1.7128], grad_fn=<SliceBackward>)
# 371 27.337127685546875 tensor([2.0956, 1.7146], grad_fn=<SliceBackward>)
# 372 27.033226013183594 tensor([2.0977, 1.7165], grad_fn=<SliceBackward>)
# 373 27.021203994750977 tensor([2.0997, 1.7184], grad_fn=<SliceBackward>)
# 374 27.061864852905273 tensor([2.1017, 1.7202], grad_fn=<SliceBackward>)
# 375 26.777145385742188 tensor([2.1038, 1.7220], grad_fn=<SliceBackward>)
# 376 26.894325256347656 tensor([2.1059, 1.7237], grad_fn=<SliceBackward>)
# 377 26.902193069458008 tensor([2.1079, 1.7254], grad_fn=<SliceBackward>)
# 378 26.848356246948242 tensor([2.1098, 1.7272], grad_fn=<SliceBackward>)
# 379 26.692750930786133 tensor([2.1118, 1.7289], grad_fn=<SliceBackward>)
# 380 26.627243041992188 tensor([2.1137, 1.7306], grad_fn=<SliceBackward>)
# 381 26.465412139892578 tensor([2.1156, 1.7321], grad_fn=<SliceBackward>)
# 382 26.38257598876953 tensor([2.1175, 1.7336], grad_fn=<SliceBackward>)
# 383 26.435819625854492 tensor([2.1195, 1.7352], grad_fn=<SliceBackward>)
# 384 26.239084243774414 tensor([2.1213, 1.7368], grad_fn=<SliceBackward>)
# 385 26.285831451416016 tensor([2.1230, 1.7384], grad_fn=<SliceBackward>)
# 386 26.306156158447266 tensor([2.1248, 1.7399], grad_fn=<SliceBackward>)
# 387 26.0935115814209 tensor([2.1264, 1.7415], grad_fn=<SliceBackward>)
# 388 26.090885162353516 tensor([2.1280, 1.7432], grad_fn=<SliceBackward>)
# 389 25.92308807373047 tensor([2.1294, 1.7451], grad_fn=<SliceBackward>)
# 390 26.092906951904297 tensor([2.1310, 1.7469], grad_fn=<SliceBackward>)
# 391 25.94002342224121 tensor([2.1325, 1.7486], grad_fn=<SliceBackward>)
# 392 25.874698638916016 tensor([2.1341, 1.7504], grad_fn=<SliceBackward>)
# 393 25.83750343322754 tensor([2.1356, 1.7520], grad_fn=<SliceBackward>)
# 394 25.593338012695312 tensor([2.1372, 1.7537], grad_fn=<SliceBackward>)
# 395 25.748456954956055 tensor([2.1387, 1.7553], grad_fn=<SliceBackward>)
# 396 25.661060333251953 tensor([2.1403, 1.7569], grad_fn=<SliceBackward>)
# 397 25.723976135253906 tensor([2.1419, 1.7585], grad_fn=<SliceBackward>)
# 398 25.606889724731445 tensor([2.1434, 1.7601], grad_fn=<SliceBackward>)
# 399 25.753055572509766 tensor([2.1448, 1.7618], grad_fn=<SliceBackward>)
# 400 25.629119873046875 tensor([2.1462, 1.7634], grad_fn=<SliceBackward>)
# 401 25.369491577148438 tensor([2.1476, 1.7650], grad_fn=<SliceBackward>)
# 402 25.555875778198242 tensor([2.1491, 1.7665], grad_fn=<SliceBackward>)
# 403 25.284528732299805 tensor([2.1506, 1.7680], grad_fn=<SliceBackward>)
# 404 25.3505916595459 tensor([2.1520, 1.7693], grad_fn=<SliceBackward>)
# 405 25.172367095947266 tensor([2.1534, 1.7706], grad_fn=<SliceBackward>)
# 406 25.230649948120117 tensor([2.1547, 1.7719], grad_fn=<SliceBackward>)
# 407 25.207674026489258 tensor([2.1560, 1.7732], grad_fn=<SliceBackward>)
# 408 24.967769622802734 tensor([2.1572, 1.7746], grad_fn=<SliceBackward>)
# 409 24.931190490722656 tensor([2.1584, 1.7759], grad_fn=<SliceBackward>)
# 410 25.168987274169922 tensor([2.1595, 1.7773], grad_fn=<SliceBackward>)
# 411 24.9997615814209 tensor([2.1605, 1.7787], grad_fn=<SliceBackward>)
# 412 25.057952880859375 tensor([2.1615, 1.7801], grad_fn=<SliceBackward>)
# 413 25.077917098999023 tensor([2.1625, 1.7815], grad_fn=<SliceBackward>)
# 414 25.091903686523438 tensor([2.1636, 1.7829], grad_fn=<SliceBackward>)
# 415 24.834110260009766 tensor([2.1645, 1.7843], grad_fn=<SliceBackward>)
# 416 24.84699249267578 tensor([2.1656, 1.7856], grad_fn=<SliceBackward>)
# 417 24.590465545654297 tensor([2.1667, 1.7870], grad_fn=<SliceBackward>)
# 418 24.87361717224121 tensor([2.1677, 1.7882], grad_fn=<SliceBackward>)
# 419 24.904054641723633 tensor([2.1689, 1.7896], grad_fn=<SliceBackward>)
# 420 24.5640869140625 tensor([2.1701, 1.7911], grad_fn=<SliceBackward>)
# 421 24.809110641479492 tensor([2.1711, 1.7925], grad_fn=<SliceBackward>)
# 422 24.81036949157715 tensor([2.1722, 1.7938], grad_fn=<SliceBackward>)
# 423 24.70536994934082 tensor([2.1733, 1.7952], grad_fn=<SliceBackward>)
# 424 24.496028900146484 tensor([2.1744, 1.7965], grad_fn=<SliceBackward>)
# 425 24.515655517578125 tensor([2.1756, 1.7979], grad_fn=<SliceBackward>)
# 426 24.486339569091797 tensor([2.1767, 1.7993], grad_fn=<SliceBackward>)
# 427 24.579431533813477 tensor([2.1778, 1.8006], grad_fn=<SliceBackward>)
# 428 24.52664566040039 tensor([2.1791, 1.8019], grad_fn=<SliceBackward>)
# 429 24.255342483520508 tensor([2.1804, 1.8033], grad_fn=<SliceBackward>)
# 430 24.529159545898438 tensor([2.1817, 1.8046], grad_fn=<SliceBackward>)
# 431 24.216291427612305 tensor([2.1830, 1.8059], grad_fn=<SliceBackward>)
# 432 24.145423889160156 tensor([2.1842, 1.8073], grad_fn=<SliceBackward>)
# 433 24.360506057739258 tensor([2.1854, 1.8086], grad_fn=<SliceBackward>)
# 434 24.171001434326172 tensor([2.1866, 1.8100], grad_fn=<SliceBackward>)
# 435 24.024497985839844 tensor([2.1878, 1.8114], grad_fn=<SliceBackward>)
# 436 24.132516860961914 tensor([2.1889, 1.8128], grad_fn=<SliceBackward>)
# 437 23.981719970703125 tensor([2.1901, 1.8142], grad_fn=<SliceBackward>)
# 438 24.136123657226562 tensor([2.1912, 1.8156], grad_fn=<SliceBackward>)
# 439 23.886917114257812 tensor([2.1924, 1.8170], grad_fn=<SliceBackward>)
# 440 23.84801483154297 tensor([2.1936, 1.8184], grad_fn=<SliceBackward>)
# 441 23.967811584472656 tensor([2.1947, 1.8198], grad_fn=<SliceBackward>)
# 442 24.041912078857422 tensor([2.1959, 1.8211], grad_fn=<SliceBackward>)
# 443 24.00223159790039 tensor([2.1971, 1.8224], grad_fn=<SliceBackward>)
# 444 23.755718231201172 tensor([2.1982, 1.8237], grad_fn=<SliceBackward>)
# 445 23.68703269958496 tensor([2.1995, 1.8251], grad_fn=<SliceBackward>)
# 446 23.613922119140625 tensor([2.2007, 1.8263], grad_fn=<SliceBackward>)
# 447 23.789758682250977 tensor([2.2020, 1.8276], grad_fn=<SliceBackward>)
# 448 23.547773361206055 tensor([2.2032, 1.8289], grad_fn=<SliceBackward>)
# 449 23.671192169189453 tensor([2.2045, 1.8302], grad_fn=<SliceBackward>)
# 450 23.704139709472656 tensor([2.2057, 1.8314], grad_fn=<SliceBackward>)
# 451 23.543174743652344 tensor([2.2071, 1.8327], grad_fn=<SliceBackward>)
# 452 23.50825309753418 tensor([2.2085, 1.8338], grad_fn=<SliceBackward>)
# 453 23.44448471069336 tensor([2.2098, 1.8348], grad_fn=<SliceBackward>)
# 454 23.572973251342773 tensor([2.2111, 1.8358], grad_fn=<SliceBackward>)
# 455 23.39876937866211 tensor([2.2124, 1.8368], grad_fn=<SliceBackward>)
# 456 23.300065994262695 tensor([2.2137, 1.8376], grad_fn=<SliceBackward>)
# 457 23.384756088256836 tensor([2.2150, 1.8385], grad_fn=<SliceBackward>)
# 458 23.4549560546875 tensor([2.2164, 1.8394], grad_fn=<SliceBackward>)
# 459 23.30215072631836 tensor([2.2178, 1.8402], grad_fn=<SliceBackward>)
# 460 22.975831985473633 tensor([2.2192, 1.8410], grad_fn=<SliceBackward>)
# 461 23.290210723876953 tensor([2.2206, 1.8420], grad_fn=<SliceBackward>)
# 462 22.961759567260742 tensor([2.2220, 1.8429], grad_fn=<SliceBackward>)
# 463 23.116315841674805 tensor([2.2234, 1.8438], grad_fn=<SliceBackward>)
# 464 23.073423385620117 tensor([2.2247, 1.8448], grad_fn=<SliceBackward>)
# 465 23.07425308227539 tensor([2.2261, 1.8459], grad_fn=<SliceBackward>)
# 466 22.9299259185791 tensor([2.2274, 1.8470], grad_fn=<SliceBackward>)
# 467 22.882396697998047 tensor([2.2288, 1.8481], grad_fn=<SliceBackward>)
# 468 22.813682556152344 tensor([2.2301, 1.8493], grad_fn=<SliceBackward>)
# 469 22.87168312072754 tensor([2.2314, 1.8504], grad_fn=<SliceBackward>)
# 470 22.840274810791016 tensor([2.2326, 1.8515], grad_fn=<SliceBackward>)
# 471 22.79520034790039 tensor([2.2339, 1.8526], grad_fn=<SliceBackward>)
# 472 22.609172821044922 tensor([2.2351, 1.8536], grad_fn=<SliceBackward>)
# 473 22.494709014892578 tensor([2.2363, 1.8546], grad_fn=<SliceBackward>)
# 474 22.62497329711914 tensor([2.2375, 1.8557], grad_fn=<SliceBackward>)
# 475 22.62024688720703 tensor([2.2388, 1.8568], grad_fn=<SliceBackward>)
# 476 22.798583984375 tensor([2.2401, 1.8579], grad_fn=<SliceBackward>)
# 477 22.55720329284668 tensor([2.2414, 1.8589], grad_fn=<SliceBackward>)
# 478 22.7078857421875 tensor([2.2427, 1.8599], grad_fn=<SliceBackward>)
# 479 22.50153350830078 tensor([2.2441, 1.8610], grad_fn=<SliceBackward>)
# 480 22.66424560546875 tensor([2.2455, 1.8620], grad_fn=<SliceBackward>)
# 481 22.353668212890625 tensor([2.2469, 1.8631], grad_fn=<SliceBackward>)
# 482 22.347816467285156 tensor([2.2485, 1.8641], grad_fn=<SliceBackward>)
# 483 22.15563201904297 tensor([2.2501, 1.8650], grad_fn=<SliceBackward>)
# 484 22.277217864990234 tensor([2.2517, 1.8658], grad_fn=<SliceBackward>)
# 485 22.264747619628906 tensor([2.2534, 1.8666], grad_fn=<SliceBackward>)
# 486 22.476585388183594 tensor([2.2550, 1.8674], grad_fn=<SliceBackward>)
# 487 22.216983795166016 tensor([2.2566, 1.8681], grad_fn=<SliceBackward>)
# 488 22.352142333984375 tensor([2.2583, 1.8689], grad_fn=<SliceBackward>)
# 489 22.359176635742188 tensor([2.2600, 1.8696], grad_fn=<SliceBackward>)
# 490 22.13416290283203 tensor([2.2616, 1.8704], grad_fn=<SliceBackward>)
# 491 22.294208526611328 tensor([2.2632, 1.8712], grad_fn=<SliceBackward>)
# 492 22.005786895751953 tensor([2.2647, 1.8719], grad_fn=<SliceBackward>)
# 493 22.04710578918457 tensor([2.2661, 1.8726], grad_fn=<SliceBackward>)
# 494 22.01561164855957 tensor([2.2675, 1.8733], grad_fn=<SliceBackward>)
# 495 22.160804748535156 tensor([2.2688, 1.8740], grad_fn=<SliceBackward>)
# 496 21.96441650390625 tensor([2.2701, 1.8747], grad_fn=<SliceBackward>)
# 497 21.86968231201172 tensor([2.2715, 1.8754], grad_fn=<SliceBackward>)
# 498 21.889667510986328 tensor([2.2731, 1.8760], grad_fn=<SliceBackward>)
# 499 21.88167953491211 tensor([2.2746, 1.8766], grad_fn=<SliceBackward>)
# 500 21.825422286987305 tensor([2.2761, 1.8772], grad_fn=<SliceBackward>)
# 501 21.93993377685547 tensor([2.2775, 1.8778], grad_fn=<SliceBackward>)
# 502 21.804658889770508 tensor([2.2789, 1.8785], grad_fn=<SliceBackward>)
# 503 21.816627502441406 tensor([2.2803, 1.8791], grad_fn=<SliceBackward>)
# 504 21.890426635742188 tensor([2.2817, 1.8797], grad_fn=<SliceBackward>)
# 505 21.781362533569336 tensor([2.2832, 1.8803], grad_fn=<SliceBackward>)
# 506 21.88914680480957 tensor([2.2847, 1.8810], grad_fn=<SliceBackward>)
# 507 21.838197708129883 tensor([2.2861, 1.8817], grad_fn=<SliceBackward>)
# 508 21.65178680419922 tensor([2.2875, 1.8824], grad_fn=<SliceBackward>)
# 509 21.79622459411621 tensor([2.2889, 1.8831], grad_fn=<SliceBackward>)
# 510 21.620849609375 tensor([2.2905, 1.8838], grad_fn=<SliceBackward>)
# 511 21.410255432128906 tensor([2.2921, 1.8845], grad_fn=<SliceBackward>)
# 512 21.70374298095703 tensor([2.2936, 1.8851], grad_fn=<SliceBackward>)
# 513 21.625110626220703 tensor([2.2951, 1.8858], grad_fn=<SliceBackward>)
# 514 21.603160858154297 tensor([2.2967, 1.8864], grad_fn=<SliceBackward>)
# 515 21.56976890563965 tensor([2.2983, 1.8870], grad_fn=<SliceBackward>)
# 516 21.44287872314453 tensor([2.3000, 1.8876], grad_fn=<SliceBackward>)
# 517 21.340713500976562 tensor([2.3018, 1.8883], grad_fn=<SliceBackward>)
# 518 21.6252384185791 tensor([2.3035, 1.8891], grad_fn=<SliceBackward>)
# 519 21.45233917236328 tensor([2.3053, 1.8899], grad_fn=<SliceBackward>)
# 520 21.278339385986328 tensor([2.3071, 1.8908], grad_fn=<SliceBackward>)
# 521 21.37535285949707 tensor([2.3088, 1.8917], grad_fn=<SliceBackward>)
# 522 21.274856567382812 tensor([2.3105, 1.8926], grad_fn=<SliceBackward>)
# 523 21.33898162841797 tensor([2.3122, 1.8934], grad_fn=<SliceBackward>)
# 524 21.378677368164062 tensor([2.3140, 1.8943], grad_fn=<SliceBackward>)
# 525 21.185253143310547 tensor([2.3157, 1.8952], grad_fn=<SliceBackward>)
# 526 21.25812530517578 tensor([2.3175, 1.8961], grad_fn=<SliceBackward>)
# 527 21.425941467285156 tensor([2.3192, 1.8970], grad_fn=<SliceBackward>)
# 528 21.225452423095703 tensor([2.3209, 1.8979], grad_fn=<SliceBackward>)
# 529 21.068927764892578 tensor([2.3226, 1.8989], grad_fn=<SliceBackward>)
# 530 21.3421688079834 tensor([2.3243, 1.8998], grad_fn=<SliceBackward>)
# 531 21.206501007080078 tensor([2.3261, 1.9006], grad_fn=<SliceBackward>)
# 532 21.390207290649414 tensor([2.3277, 1.9015], grad_fn=<SliceBackward>)
# 533 21.087125778198242 tensor([2.3294, 1.9023], grad_fn=<SliceBackward>)
# 534 21.099956512451172 tensor([2.3309, 1.9030], grad_fn=<SliceBackward>)
# 535 21.105695724487305 tensor([2.3325, 1.9038], grad_fn=<SliceBackward>)
# 536 21.294471740722656 tensor([2.3342, 1.9046], grad_fn=<SliceBackward>)
# 537 21.265731811523438 tensor([2.3358, 1.9053], grad_fn=<SliceBackward>)
# 538 21.114612579345703 tensor([2.3376, 1.9059], grad_fn=<SliceBackward>)
# 539 20.889366149902344 tensor([2.3394, 1.9066], grad_fn=<SliceBackward>)
# 540 21.052322387695312 tensor([2.3412, 1.9073], grad_fn=<SliceBackward>)
# 541 20.9217586517334 tensor([2.3429, 1.9080], grad_fn=<SliceBackward>)
# 542 21.010128021240234 tensor([2.3445, 1.9087], grad_fn=<SliceBackward>)
# 543 21.148094177246094 tensor([2.3461, 1.9093], grad_fn=<SliceBackward>)
# 544 21.150482177734375 tensor([2.3477, 1.9100], grad_fn=<SliceBackward>)
# 545 21.052227020263672 tensor([2.3492, 1.9108], grad_fn=<SliceBackward>)
# 546 20.910808563232422 tensor([2.3508, 1.9115], grad_fn=<SliceBackward>)
# 547 21.017501831054688 tensor([2.3523, 1.9123], grad_fn=<SliceBackward>)
# 548 20.928180694580078 tensor([2.3539, 1.9130], grad_fn=<SliceBackward>)
# 549 20.947019577026367 tensor([2.3555, 1.9137], grad_fn=<SliceBackward>)
# 550 20.902751922607422 tensor([2.3571, 1.9143], grad_fn=<SliceBackward>)
# 551 20.95113182067871 tensor([2.3586, 1.9148], grad_fn=<SliceBackward>)
# 552 20.67839813232422 tensor([2.3603, 1.9153], grad_fn=<SliceBackward>)
# 553 20.742895126342773 tensor([2.3618, 1.9158], grad_fn=<SliceBackward>)
# 554 20.824398040771484 tensor([2.3633, 1.9165], grad_fn=<SliceBackward>)
# 555 20.861438751220703 tensor([2.3648, 1.9172], grad_fn=<SliceBackward>)
# 556 20.75763702392578 tensor([2.3664, 1.9178], grad_fn=<SliceBackward>)
# 557 20.859533309936523 tensor([2.3678, 1.9183], grad_fn=<SliceBackward>)
# 558 20.678266525268555 tensor([2.3694, 1.9187], grad_fn=<SliceBackward>)
# 559 20.762161254882812 tensor([2.3708, 1.9192], grad_fn=<SliceBackward>)
# 560 21.022480010986328 tensor([2.3722, 1.9197], grad_fn=<SliceBackward>)
# 561 20.691932678222656 tensor([2.3736, 1.9202], grad_fn=<SliceBackward>)
# 562 20.747175216674805 tensor([2.3751, 1.9207], grad_fn=<SliceBackward>)
# 563 20.857196807861328 tensor([2.3765, 1.9211], grad_fn=<SliceBackward>)
# 564 20.90884017944336 tensor([2.3779, 1.9216], grad_fn=<SliceBackward>)
# 565 20.540618896484375 tensor([2.3793, 1.9221], grad_fn=<SliceBackward>)
# 566 20.75530242919922 tensor([2.3806, 1.9226], grad_fn=<SliceBackward>)
# 567 20.401142120361328 tensor([2.3819, 1.9230], grad_fn=<SliceBackward>)
# 568 20.744342803955078 tensor([2.3831, 1.9234], grad_fn=<SliceBackward>)
# 569 20.730865478515625 tensor([2.3845, 1.9239], grad_fn=<SliceBackward>)
# 570 20.623748779296875 tensor([2.3858, 1.9244], grad_fn=<SliceBackward>)
# 571 20.74842071533203 tensor([2.3873, 1.9249], grad_fn=<SliceBackward>)
# 572 20.524566650390625 tensor([2.3887, 1.9254], grad_fn=<SliceBackward>)
# 573 20.691003799438477 tensor([2.3901, 1.9259], grad_fn=<SliceBackward>)
# 574 20.665048599243164 tensor([2.3916, 1.9265], grad_fn=<SliceBackward>)
# 575 20.831298828125 tensor([2.3929, 1.9271], grad_fn=<SliceBackward>)
# 576 20.605064392089844 tensor([2.3942, 1.9275], grad_fn=<SliceBackward>)
# 577 20.470298767089844 tensor([2.3956, 1.9279], grad_fn=<SliceBackward>)
# 578 20.384078979492188 tensor([2.3970, 1.9282], grad_fn=<SliceBackward>)
# 579 20.322765350341797 tensor([2.3985, 1.9285], grad_fn=<SliceBackward>)
# 580 20.43952751159668 tensor([2.3998, 1.9288], grad_fn=<SliceBackward>)
# 581 20.458690643310547 tensor([2.4011, 1.9291], grad_fn=<SliceBackward>)
# 582 20.420879364013672 tensor([2.4023, 1.9296], grad_fn=<SliceBackward>)
# 583 20.43982696533203 tensor([2.4034, 1.9300], grad_fn=<SliceBackward>)
# 584 20.4173583984375 tensor([2.4046, 1.9304], grad_fn=<SliceBackward>)
# 585 20.32861328125 tensor([2.4057, 1.9307], grad_fn=<SliceBackward>)
# 586 20.284778594970703 tensor([2.4069, 1.9310], grad_fn=<SliceBackward>)
# 587 20.24380111694336 tensor([2.4079, 1.9313], grad_fn=<SliceBackward>)
# 588 20.30335235595703 tensor([2.4090, 1.9317], grad_fn=<SliceBackward>)
# 589 20.314748764038086 tensor([2.4101, 1.9318], grad_fn=<SliceBackward>)
# 590 20.350114822387695 tensor([2.4112, 1.9320], grad_fn=<SliceBackward>)
# 591 20.170513153076172 tensor([2.4124, 1.9323], grad_fn=<SliceBackward>)
# 592 20.272418975830078 tensor([2.4135, 1.9326], grad_fn=<SliceBackward>)
# 593 20.11285400390625 tensor([2.4145, 1.9329], grad_fn=<SliceBackward>)
# 594 20.20614242553711 tensor([2.4155, 1.9331], grad_fn=<SliceBackward>)
# 595 20.385116577148438 tensor([2.4164, 1.9334], grad_fn=<SliceBackward>)
# 596 20.318889617919922 tensor([2.4174, 1.9338], grad_fn=<SliceBackward>)
# 597 20.355470657348633 tensor([2.4183, 1.9341], grad_fn=<SliceBackward>)
# 598 20.284286499023438 tensor([2.4192, 1.9345], grad_fn=<SliceBackward>)
# 599 19.944133758544922 tensor([2.4201, 1.9349], grad_fn=<SliceBackward>)
# 600 20.23114585876465 tensor([2.4209, 1.9353], grad_fn=<SliceBackward>)
# 601 20.059249877929688 tensor([2.4216, 1.9357], grad_fn=<SliceBackward>)
# 602 20.137184143066406 tensor([2.4223, 1.9361], grad_fn=<SliceBackward>)
# 603 20.138479232788086 tensor([2.4232, 1.9365], grad_fn=<SliceBackward>)
# 604 20.204410552978516 tensor([2.4240, 1.9369], grad_fn=<SliceBackward>)
# 605 20.042240142822266 tensor([2.4248, 1.9372], grad_fn=<SliceBackward>)
# 606 20.04104995727539 tensor([2.4256, 1.9375], grad_fn=<SliceBackward>)
# 607 19.987266540527344 tensor([2.4264, 1.9379], grad_fn=<SliceBackward>)
# 608 20.0833797454834 tensor([2.4273, 1.9382], grad_fn=<SliceBackward>)
# 609 20.072439193725586 tensor([2.4283, 1.9386], grad_fn=<SliceBackward>)
# 610 20.192703247070312 tensor([2.4291, 1.9390], grad_fn=<SliceBackward>)
# 611 19.98087501525879 tensor([2.4300, 1.9395], grad_fn=<SliceBackward>)
# 612 19.899478912353516 tensor([2.4309, 1.9400], grad_fn=<SliceBackward>)
# 613 20.033584594726562 tensor([2.4318, 1.9405], grad_fn=<SliceBackward>)
# 614 20.03131103515625 tensor([2.4327, 1.9410], grad_fn=<SliceBackward>)
# 615 19.766746520996094 tensor([2.4338, 1.9415], grad_fn=<SliceBackward>)
# 616 19.809288024902344 tensor([2.4347, 1.9420], grad_fn=<SliceBackward>)
# 617 19.855052947998047 tensor([2.4357, 1.9426], grad_fn=<SliceBackward>)
# 618 19.882844924926758 tensor([2.4366, 1.9431], grad_fn=<SliceBackward>)
# 619 19.727596282958984 tensor([2.4375, 1.9436], grad_fn=<SliceBackward>)
# 620 19.851036071777344 tensor([2.4384, 1.9442], grad_fn=<SliceBackward>)
# 621 20.029531478881836 tensor([2.4393, 1.9446], grad_fn=<SliceBackward>)
# 622 19.831623077392578 tensor([2.4402, 1.9451], grad_fn=<SliceBackward>)
# 623 19.654712677001953 tensor([2.4411, 1.9456], grad_fn=<SliceBackward>)
# 624 19.74478530883789 tensor([2.4419, 1.9460], grad_fn=<SliceBackward>)
# 625 19.754806518554688 tensor([2.4426, 1.9464], grad_fn=<SliceBackward>)
# 626 19.81916618347168 tensor([2.4434, 1.9469], grad_fn=<SliceBackward>)
# 627 19.9329833984375 tensor([2.4442, 1.9474], grad_fn=<SliceBackward>)
# 628 19.868925094604492 tensor([2.4451, 1.9479], grad_fn=<SliceBackward>)
# 629 19.83130645751953 tensor([2.4459, 1.9485], grad_fn=<SliceBackward>)
# 630 19.824764251708984 tensor([2.4467, 1.9492], grad_fn=<SliceBackward>)
# 631 19.7901668548584 tensor([2.4475, 1.9498], grad_fn=<SliceBackward>)
# 632 19.736793518066406 tensor([2.4482, 1.9505], grad_fn=<SliceBackward>)
# 633 19.485084533691406 tensor([2.4490, 1.9513], grad_fn=<SliceBackward>)
# 634 19.572784423828125 tensor([2.4497, 1.9520], grad_fn=<SliceBackward>)
# 635 19.701675415039062 tensor([2.4503, 1.9527], grad_fn=<SliceBackward>)
# 636 19.612524032592773 tensor([2.4510, 1.9534], grad_fn=<SliceBackward>)
# 637 19.790653228759766 tensor([2.4517, 1.9541], grad_fn=<SliceBackward>)
# 638 19.789772033691406 tensor([2.4524, 1.9546], grad_fn=<SliceBackward>)
# 639 19.65665054321289 tensor([2.4529, 1.9553], grad_fn=<SliceBackward>)
# 640 19.728374481201172 tensor([2.4535, 1.9560], grad_fn=<SliceBackward>)
# 641 19.759979248046875 tensor([2.4542, 1.9567], grad_fn=<SliceBackward>)
# 642 19.591379165649414 tensor([2.4550, 1.9574], grad_fn=<SliceBackward>)
# 643 19.515357971191406 tensor([2.4558, 1.9581], grad_fn=<SliceBackward>)
# 644 19.470483779907227 tensor([2.4566, 1.9589], grad_fn=<SliceBackward>)
# 645 19.526023864746094 tensor([2.4571, 1.9595], grad_fn=<SliceBackward>)
# 646 19.45846939086914 tensor([2.4576, 1.9603], grad_fn=<SliceBackward>)
# 647 19.548524856567383 tensor([2.4581, 1.9612], grad_fn=<SliceBackward>)
# 648 19.660369873046875 tensor([2.4586, 1.9619], grad_fn=<SliceBackward>)
# 649 19.634220123291016 tensor([2.4590, 1.9626], grad_fn=<SliceBackward>)
# 650 19.541362762451172 tensor([2.4594, 1.9632], grad_fn=<SliceBackward>)
# 651 19.501232147216797 tensor([2.4598, 1.9638], grad_fn=<SliceBackward>)
# 652 19.645782470703125 tensor([2.4603, 1.9643], grad_fn=<SliceBackward>)
# 653 19.567415237426758 tensor([2.4608, 1.9648], grad_fn=<SliceBackward>)
# 654 19.500431060791016 tensor([2.4613, 1.9652], grad_fn=<SliceBackward>)
# 655 19.370487213134766 tensor([2.4618, 1.9656], grad_fn=<SliceBackward>)
# 656 19.520095825195312 tensor([2.4624, 1.9661], grad_fn=<SliceBackward>)
# 657 19.369342803955078 tensor([2.4630, 1.9665], grad_fn=<SliceBackward>)
# 658 19.441322326660156 tensor([2.4635, 1.9671], grad_fn=<SliceBackward>)
# 659 19.41485595703125 tensor([2.4640, 1.9676], grad_fn=<SliceBackward>)
# 660 19.417144775390625 tensor([2.4644, 1.9682], grad_fn=<SliceBackward>)
# 661 19.2882080078125 tensor([2.4649, 1.9687], grad_fn=<SliceBackward>)
# 662 19.44598388671875 tensor([2.4654, 1.9692], grad_fn=<SliceBackward>)
# 663 19.239931106567383 tensor([2.4658, 1.9696], grad_fn=<SliceBackward>)
# ...
# 784 20.682918548583984 tensor([1.0621, 2.2731], grad_fn=<SliceBackward>)
# 785 20.648845672607422 tensor([1.0614, 2.2730], grad_fn=<SliceBackward>)
# 786 20.719005584716797 tensor([1.0604, 2.2727], grad_fn=<SliceBackward>)
# 787 20.740198135375977 tensor([1.0596, 2.2725], grad_fn=<SliceBackward>)
# 788 20.64586639404297 tensor([1.0589, 2.2724], grad_fn=<SliceBackward>)
# 789 20.65503692626953 tensor([1.0581, 2.2723], grad_fn=<SliceBackward>)
# 790 20.601497650146484 tensor([1.0574, 2.2722], grad_fn=<SliceBackward>)
# 791 20.657325744628906 tensor([1.0566, 2.2720], grad_fn=<SliceBackward>)
# 792 20.619041442871094 tensor([1.0560, 2.2718], grad_fn=<SliceBackward>)
# 793 20.40253448486328 tensor([1.0554, 2.2716], grad_fn=<SliceBackward>)
# 794 20.609859466552734 tensor([1.0545, 2.2714], grad_fn=<SliceBackward>)
# 795 20.573490142822266 tensor([1.0537, 2.2710], grad_fn=<SliceBackward>)
# 796 20.663911819458008 tensor([1.0528, 2.2708], grad_fn=<SliceBackward>)
# 797 20.417102813720703 tensor([1.0521, 2.2705], grad_fn=<SliceBackward>)
# 798 20.588150024414062 tensor([1.0514, 2.2703], grad_fn=<SliceBackward>)
# 799 20.546716690063477 tensor([1.0505, 2.2701], grad_fn=<SliceBackward>)
# 800 20.34510040283203 tensor([1.0496, 2.2700], grad_fn=<SliceBackward>)
# 801 20.432910919189453 tensor([1.0487, 2.2700], grad_fn=<SliceBackward>)
# 802 20.22201156616211 tensor([1.0478, 2.2699], grad_fn=<SliceBackward>)
# 803 20.437580108642578 tensor([1.0469, 2.2697], grad_fn=<SliceBackward>)
# 804 20.422515869140625 tensor([1.0459, 2.2695], grad_fn=<SliceBackward>)
# 805 20.4802188873291 tensor([1.0447, 2.2694], grad_fn=<SliceBackward>)
# 806 20.44873809814453 tensor([1.0436, 2.2693], grad_fn=<SliceBackward>)
# 807 20.38521957397461 tensor([1.0426, 2.2692], grad_fn=<SliceBackward>)
# 808 20.303348541259766 tensor([1.0416, 2.2692], grad_fn=<SliceBackward>)
# 809 20.24062728881836 tensor([1.0409, 2.2693], grad_fn=<SliceBackward>)
# 810 20.3377685546875 tensor([1.0402, 2.2692], grad_fn=<SliceBackward>)
# 811 20.485580444335938 tensor([1.0394, 2.2692], grad_fn=<SliceBackward>)
# 812 20.342294692993164 tensor([1.0389, 2.2693], grad_fn=<SliceBackward>)
# 813 20.263538360595703 tensor([1.0385, 2.2693], grad_fn=<SliceBackward>)
# 814 20.262248992919922 tensor([1.0380, 2.2693], grad_fn=<SliceBackward>)
# 815 20.23613739013672 tensor([1.0376, 2.2692], grad_fn=<SliceBackward>)
# 816 20.238109588623047 tensor([1.0374, 2.2691], grad_fn=<SliceBackward>)
# 817 20.169811248779297 tensor([1.0372, 2.2690], grad_fn=<SliceBackward>)
# 818 20.19811248779297 tensor([1.0369, 2.2688], grad_fn=<SliceBackward>)
# 819 20.112483978271484 tensor([1.0367, 2.2686], grad_fn=<SliceBackward>)
# 820 20.24365234375 tensor([1.0368, 2.2683], grad_fn=<SliceBackward>)
# 821 20.246976852416992 tensor([1.0369, 2.2681], grad_fn=<SliceBackward>)
# 822 20.124797821044922 tensor([1.0370, 2.2678], grad_fn=<SliceBackward>)
# 823 20.083370208740234 tensor([1.0367, 2.2675], grad_fn=<SliceBackward>)
# 824 20.104642868041992 tensor([1.0366, 2.2671], grad_fn=<SliceBackward>)
# 825 20.02597999572754 tensor([1.0362, 2.2667], grad_fn=<SliceBackward>)
# 826 19.946969985961914 tensor([1.0359, 2.2664], grad_fn=<SliceBackward>)
# 827 19.91326141357422 tensor([1.0355, 2.2660], grad_fn=<SliceBackward>)
# 828 20.042980194091797 tensor([1.0348, 2.2656], grad_fn=<SliceBackward>)
# 829 20.071014404296875 tensor([1.0340, 2.2653], grad_fn=<SliceBackward>)
# 830 20.117141723632812 tensor([1.0333, 2.2651], grad_fn=<SliceBackward>)
# 831 20.02907943725586 tensor([1.0328, 2.2646], grad_fn=<SliceBackward>)
# 832 20.03692054748535 tensor([1.0321, 2.2641], grad_fn=<SliceBackward>)
# 833 20.08346176147461 tensor([1.0312, 2.2636], grad_fn=<SliceBackward>)
# 834 19.949617385864258 tensor([1.0305, 2.2631], grad_fn=<SliceBackward>)
# 835 19.814464569091797 tensor([1.0298, 2.2627], grad_fn=<SliceBackward>)
# 836 20.049697875976562 tensor([1.0288, 2.2622], grad_fn=<SliceBackward>)
# 837 19.82794952392578 tensor([1.0281, 2.2617], grad_fn=<SliceBackward>)
# 838 20.02755355834961 tensor([1.0274, 2.2613], grad_fn=<SliceBackward>)
# 839 19.815731048583984 tensor([1.0268, 2.2608], grad_fn=<SliceBackward>)
# 840 19.774761199951172 tensor([1.0260, 2.2604], grad_fn=<SliceBackward>)
# 841 19.885194778442383 tensor([1.0252, 2.2601], grad_fn=<SliceBackward>)
# 842 19.728919982910156 tensor([1.0247, 2.2597], grad_fn=<SliceBackward>)
# 843 19.774127960205078 tensor([1.0241, 2.2596], grad_fn=<SliceBackward>)
# 844 19.74298858642578 tensor([1.0235, 2.2595], grad_fn=<SliceBackward>)
# 845 19.71915054321289 tensor([1.0232, 2.2593], grad_fn=<SliceBackward>)
# 846 19.62712860107422 tensor([1.0230, 2.2592], grad_fn=<SliceBackward>)
# 847 19.653858184814453 tensor([1.0226, 2.2591], grad_fn=<SliceBackward>)
# 848 19.79470443725586 tensor([1.0223, 2.2590], grad_fn=<SliceBackward>)
# 849 19.902971267700195 tensor([1.0221, 2.2589], grad_fn=<SliceBackward>)
# 850 19.673690795898438 tensor([1.0221, 2.2587], grad_fn=<SliceBackward>)
# 851 19.423616409301758 tensor([1.0223, 2.2585], grad_fn=<SliceBackward>)
# 852 19.672245025634766 tensor([1.0223, 2.2583], grad_fn=<SliceBackward>)
# 853 19.569107055664062 tensor([1.0222, 2.2581], grad_fn=<SliceBackward>)
# 854 19.659215927124023 tensor([1.0221, 2.2578], grad_fn=<SliceBackward>)
# 855 19.620038986206055 tensor([1.0222, 2.2576], grad_fn=<SliceBackward>)
# 856 19.752635955810547 tensor([1.0223, 2.2574], grad_fn=<SliceBackward>)
# 857 19.58545684814453 tensor([1.0226, 2.2573], grad_fn=<SliceBackward>)
# 858 19.41024398803711 tensor([1.0228, 2.2572], grad_fn=<SliceBackward>)
# 859 19.420989990234375 tensor([1.0228, 2.2571], grad_fn=<SliceBackward>)
# 860 19.607837677001953 tensor([1.0227, 2.2570], grad_fn=<SliceBackward>)
# 861 19.413532257080078 tensor([1.0228, 2.2569], grad_fn=<SliceBackward>)
# 862 19.422836303710938 tensor([1.0224, 2.2567], grad_fn=<SliceBackward>)
# 863 19.317893981933594 tensor([1.0221, 2.2564], grad_fn=<SliceBackward>)
# 864 19.394258499145508 tensor([1.0218, 2.2561], grad_fn=<SliceBackward>)
# 865 19.31023406982422 tensor([1.0215, 2.2558], grad_fn=<SliceBackward>)
# 866 19.39107322692871 tensor([1.0208, 2.2555], grad_fn=<SliceBackward>)
# 867 19.156003952026367 tensor([1.0201, 2.2550], grad_fn=<SliceBackward>)
# 868 19.30039405822754 tensor([1.0192, 2.2546], grad_fn=<SliceBackward>)
# 869 19.225000381469727 tensor([1.0186, 2.2543], grad_fn=<SliceBackward>)
# 870 19.418956756591797 tensor([1.0180, 2.2542], grad_fn=<SliceBackward>)
# 871 19.38591766357422 tensor([1.0175, 2.2541], grad_fn=<SliceBackward>)
# 872 19.233301162719727 tensor([1.0169, 2.2540], grad_fn=<SliceBackward>)
# 873 19.297426223754883 tensor([1.0163, 2.2540], grad_fn=<SliceBackward>)
# 874 19.26005744934082 tensor([1.0157, 2.2539], grad_fn=<SliceBackward>)
# 875 19.35250473022461 tensor([1.0146, 2.2538], grad_fn=<SliceBackward>)
# 876 19.412656784057617 tensor([1.0134, 2.2536], grad_fn=<SliceBackward>)
# 877 19.280508041381836 tensor([1.0124, 2.2535], grad_fn=<SliceBackward>)
# 878 19.198413848876953 tensor([1.0113, 2.2534], grad_fn=<SliceBackward>)
# 879 19.15908432006836 tensor([1.0099, 2.2533], grad_fn=<SliceBackward>)
# 880 19.461931228637695 tensor([1.0085, 2.2533], grad_fn=<SliceBackward>)
# 881 19.268640518188477 tensor([1.0075, 2.2533], grad_fn=<SliceBackward>)
# 882 19.309043884277344 tensor([1.0063, 2.2533], grad_fn=<SliceBackward>)
# 883 19.209238052368164 tensor([1.0055, 2.2534], grad_fn=<SliceBackward>)
# 884 19.146202087402344 tensor([1.0047, 2.2535], grad_fn=<SliceBackward>)
# 885 19.193138122558594 tensor([1.0043, 2.2536], grad_fn=<SliceBackward>)
# 886 19.23748779296875 tensor([1.0039, 2.2537], grad_fn=<SliceBackward>)
# 887 19.18072509765625 tensor([1.0034, 2.2538], grad_fn=<SliceBackward>)
# 888 19.1424560546875 tensor([1.0031, 2.2538], grad_fn=<SliceBackward>)
# 889 19.171527862548828 tensor([1.0024, 2.2539], grad_fn=<SliceBackward>)
# 890 19.068111419677734 tensor([1.0016, 2.2539], grad_fn=<SliceBackward>)
# 891 19.330236434936523 tensor([1.0008, 2.2539], grad_fn=<SliceBackward>)
# 892 19.1994686126709 tensor([1.0000, 2.2539], grad_fn=<SliceBackward>)
# 893 19.082279205322266 tensor([0.9990, 2.2541], grad_fn=<SliceBackward>)
# 894 19.220787048339844 tensor([0.9979, 2.2542], grad_fn=<SliceBackward>)
# 895 19.07638168334961 tensor([0.9968, 2.2542], grad_fn=<SliceBackward>)
# 896 19.162046432495117 tensor([0.9953, 2.2544], grad_fn=<SliceBackward>)
# 897 19.091896057128906 tensor([0.9937, 2.2545], grad_fn=<SliceBackward>)
# 898 18.95700454711914 tensor([0.9924, 2.2548], grad_fn=<SliceBackward>)
# 899 19.063146591186523 tensor([0.9910, 2.2550], grad_fn=<SliceBackward>)
# 900 19.00246810913086 tensor([0.9894, 2.2554], grad_fn=<SliceBackward>)
# 901 19.08029556274414 tensor([0.9879, 2.2557], grad_fn=<SliceBackward>)
# 902 18.858428955078125 tensor([0.9866, 2.2560], grad_fn=<SliceBackward>)
# 903 18.9016056060791 tensor([0.9852, 2.2564], grad_fn=<SliceBackward>)
# 904 19.038663864135742 tensor([0.9840, 2.2568], grad_fn=<SliceBackward>)
# 905 19.146141052246094 tensor([0.9826, 2.2571], grad_fn=<SliceBackward>)
# 906 18.887168884277344 tensor([0.9815, 2.2576], grad_fn=<SliceBackward>)
# 907 19.088056564331055 tensor([0.9803, 2.2580], grad_fn=<SliceBackward>)
# 908 18.796472549438477 tensor([0.9795, 2.2584], grad_fn=<SliceBackward>)
# 909 18.89369010925293 tensor([0.9784, 2.2588], grad_fn=<SliceBackward>)
# 910 18.869550704956055 tensor([0.9773, 2.2592], grad_fn=<SliceBackward>)
# 911 18.794719696044922 tensor([0.9760, 2.2595], grad_fn=<SliceBackward>)
# 912 18.934043884277344 tensor([0.9748, 2.2599], grad_fn=<SliceBackward>)
# 913 18.848690032958984 tensor([0.9734, 2.2603], grad_fn=<SliceBackward>)
# 914 18.773014068603516 tensor([0.9720, 2.2606], grad_fn=<SliceBackward>)
# 915 18.875961303710938 tensor([0.9708, 2.2609], grad_fn=<SliceBackward>)
# 916 18.861536026000977 tensor([0.9697, 2.2612], grad_fn=<SliceBackward>)
# 917 18.88568878173828 tensor([0.9688, 2.2616], grad_fn=<SliceBackward>)
# 918 18.604406356811523 tensor([0.9681, 2.2619], grad_fn=<SliceBackward>)
# 919 18.690462112426758 tensor([0.9677, 2.2622], grad_fn=<SliceBackward>)
# 920 18.73044204711914 tensor([0.9670, 2.2625], grad_fn=<SliceBackward>)
# 921 18.77117156982422 tensor([0.9666, 2.2627], grad_fn=<SliceBackward>)
# 922 18.686378479003906 tensor([0.9660, 2.2630], grad_fn=<SliceBackward>)
# 923 18.63496208190918 tensor([0.9650, 2.2632], grad_fn=<SliceBackward>)
# 924 18.571460723876953 tensor([0.9638, 2.2636], grad_fn=<SliceBackward>)
# 925 18.819808959960938 tensor([0.9627, 2.2639], grad_fn=<SliceBackward>)
# 926 18.619998931884766 tensor([0.9619, 2.2644], grad_fn=<SliceBackward>)
# 927 18.625244140625 tensor([0.9611, 2.2648], grad_fn=<SliceBackward>)
# 928 18.589427947998047 tensor([0.9603, 2.2652], grad_fn=<SliceBackward>)
# 929 18.538497924804688 tensor([0.9596, 2.2656], grad_fn=<SliceBackward>)
# 930 18.49496078491211 tensor([0.9589, 2.2660], grad_fn=<SliceBackward>)
# 931 18.56648063659668 tensor([0.9581, 2.2664], grad_fn=<SliceBackward>)
# 932 18.504104614257812 tensor([0.9568, 2.2668], grad_fn=<SliceBackward>)
# 933 18.48925018310547 tensor([0.9553, 2.2672], grad_fn=<SliceBackward>)
# 934 18.624237060546875 tensor([0.9534, 2.2676], grad_fn=<SliceBackward>)
# 935 18.431425094604492 tensor([0.9517, 2.2680], grad_fn=<SliceBackward>)
# 936 18.50411033630371 tensor([0.9503, 2.2683], grad_fn=<SliceBackward>)
# 937 18.38256072998047 tensor([0.9488, 2.2686], grad_fn=<SliceBackward>)
# 938 18.593555450439453 tensor([0.9475, 2.2688], grad_fn=<SliceBackward>)
# 939 18.5690860748291 tensor([0.9461, 2.2692], grad_fn=<SliceBackward>)
# 940 18.529216766357422 tensor([0.9449, 2.2695], grad_fn=<SliceBackward>)
# 941 18.653724670410156 tensor([0.9439, 2.2699], grad_fn=<SliceBackward>)
# 942 18.501033782958984 tensor([0.9431, 2.2702], grad_fn=<SliceBackward>)
# 943 18.50225067138672 tensor([0.9420, 2.2704], grad_fn=<SliceBackward>)
# 944 18.464197158813477 tensor([0.9409, 2.2706], grad_fn=<SliceBackward>)
# 945 18.497705459594727 tensor([0.9396, 2.2708], grad_fn=<SliceBackward>)
# 946 18.47945785522461 tensor([0.9385, 2.2711], grad_fn=<SliceBackward>)
# 947 18.542320251464844 tensor([0.9377, 2.2713], grad_fn=<SliceBackward>)
# 948 18.41204833984375 tensor([0.9369, 2.2714], grad_fn=<SliceBackward>)
# 949 18.465187072753906 tensor([0.9360, 2.2716], grad_fn=<SliceBackward>)
# 950 18.46563720703125 tensor([0.9350, 2.2718], grad_fn=<SliceBackward>)
# 951 18.37073516845703 tensor([0.9339, 2.2719], grad_fn=<SliceBackward>)
# 952 18.58084487915039 tensor([0.9331, 2.2720], grad_fn=<SliceBackward>)
# 953 18.4433650970459 tensor([0.9328, 2.2723], grad_fn=<SliceBackward>)
# 954 18.429733276367188 tensor([0.9329, 2.2725], grad_fn=<SliceBackward>)
# 955 18.33685874938965 tensor([0.9327, 2.2728], grad_fn=<SliceBackward>)
# 956 18.33039093017578 tensor([0.9325, 2.2731], grad_fn=<SliceBackward>)
# 957 18.18162727355957 tensor([0.9318, 2.2732], grad_fn=<SliceBackward>)
# 958 18.333751678466797 tensor([0.9309, 2.2734], grad_fn=<SliceBackward>)
# 959 18.29189682006836 tensor([0.9297, 2.2735], grad_fn=<SliceBackward>)
# 960 18.362342834472656 tensor([0.9285, 2.2737], grad_fn=<SliceBackward>)
# 961 18.462657928466797 tensor([0.9273, 2.2739], grad_fn=<SliceBackward>)
# 962 18.258991241455078 tensor([0.9263, 2.2740], grad_fn=<SliceBackward>)
# 963 18.171239852905273 tensor([0.9252, 2.2742], grad_fn=<SliceBackward>)
# 964 18.395626068115234 tensor([0.9242, 2.2743], grad_fn=<SliceBackward>)
# 965 18.415576934814453 tensor([0.9232, 2.2745], grad_fn=<SliceBackward>)
# 966 18.278324127197266 tensor([0.9218, 2.2746], grad_fn=<SliceBackward>)
# 967 18.180540084838867 tensor([0.9205, 2.2746], grad_fn=<SliceBackward>)
# 968 18.14682388305664 tensor([0.9191, 2.2748], grad_fn=<SliceBackward>)
# 969 18.20370101928711 tensor([0.9175, 2.2751], grad_fn=<SliceBackward>)
# 970 18.29305648803711 tensor([0.9160, 2.2754], grad_fn=<SliceBackward>)
# 971 18.115558624267578 tensor([0.9145, 2.2757], grad_fn=<SliceBackward>)
# 972 18.3072509765625 tensor([0.9128, 2.2759], grad_fn=<SliceBackward>)
# 973 18.291015625 tensor([0.9112, 2.2762], grad_fn=<SliceBackward>)
# 974 18.04668617248535 tensor([0.9098, 2.2765], grad_fn=<SliceBackward>)
# 975 18.35977554321289 tensor([0.9083, 2.2768], grad_fn=<SliceBackward>)
# 976 18.17218017578125 tensor([0.9069, 2.2771], grad_fn=<SliceBackward>)
# 977 18.195819854736328 tensor([0.9057, 2.2775], grad_fn=<SliceBackward>)
# 978 18.078083038330078 tensor([0.9045, 2.2779], grad_fn=<SliceBackward>)
# 979 18.434112548828125 tensor([0.9035, 2.2785], grad_fn=<SliceBackward>)
# 980 18.043323516845703 tensor([0.9027, 2.2790], grad_fn=<SliceBackward>)
# 981 18.29422950744629 tensor([0.9015, 2.2795], grad_fn=<SliceBackward>)
# 982 18.12401580810547 tensor([0.9004, 2.2801], grad_fn=<SliceBackward>)
# 983 18.093521118164062 tensor([0.8995, 2.2806], grad_fn=<SliceBackward>)
# 984 18.267444610595703 tensor([0.8988, 2.2811], grad_fn=<SliceBackward>)
# 985 18.072391510009766 tensor([0.8979, 2.2817], grad_fn=<SliceBackward>)
# 986 18.282129287719727 tensor([0.8970, 2.2821], grad_fn=<SliceBackward>)
# 987 18.19820213317871 tensor([0.8960, 2.2826], grad_fn=<SliceBackward>)
# 988 18.148176193237305 tensor([0.8950, 2.2832], grad_fn=<SliceBackward>)
# 989 18.05994415283203 tensor([0.8940, 2.2838], grad_fn=<SliceBackward>)
# 990 18.128610610961914 tensor([0.8926, 2.2844], grad_fn=<SliceBackward>)
# 991 18.041303634643555 tensor([0.8910, 2.2849], grad_fn=<SliceBackward>)
# 992 18.075407028198242 tensor([0.8896, 2.2854], grad_fn=<SliceBackward>)
# 993 18.10580825805664 tensor([0.8881, 2.2859], grad_fn=<SliceBackward>)
# 994 18.102230072021484 tensor([0.8865, 2.2864], grad_fn=<SliceBackward>)
# 995 18.037677764892578 tensor([0.8851, 2.2869], grad_fn=<SliceBackward>)
# 996 18.122344970703125 tensor([0.8837, 2.2873], grad_fn=<SliceBackward>)
# 997 17.929847717285156 tensor([0.8826, 2.2876], grad_fn=<SliceBackward>)
# 998 18.125165939331055 tensor([0.8813, 2.2879], grad_fn=<SliceBackward>)
# 999 18.18866729736328 tensor([0.8801, 2.2882], grad_fn=<SliceBackward>)
# 338.98516845703125
# 18.18866729736328
# tensor([ 0.8791,  2.2885,  2.0917,  0.2160,  2.5044,  0.8610,  1.2305, -3.1144,
#          3.2165,  3.4887,  2.4489,  2.7570,  3.0903,  3.6302],
#        requires_grad=True)
# 5 [0.7828947368421053, 0.7894736842105263, 0.8223684210526315, 0.7894736842105263, 0.8092105263157895]

# %%
print(test_acc)
test_acc = np.array(test_acc)
print('{}({})'.format(test_acc.mean(), test_acc.std()))
# Out:
# [0.7828947368421053, 0.7894736842105263, 0.8223684210526315, 0.7894736842105263, 0.8092105263157895]
# 0.7986842105263158(0.014769700210949742)

# %% [markdown]
# # RPM 20% Noise

# %%
from scipy.io import loadmat, savemat
import os
import numpy as np
import math
import random
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.normal import Normal
from torch.distributions.kl import kl_divergence
from torch.nn import BCEWithLogitsLoss
from util import VNet3
from torch.distributions.beta import Beta
import pandas as pd

def evaluate_likelihood(Y, score):#, sigma
    s = torch.sigmoid(score)
    likelihood = s ** Y * (1 - s) ** (1 - Y)
    return likelihood

test_acc = []

for k in range(5):
    
    
    data = loadmat('./heart_20%_{}.mat'.format(k+1))
    X_train = torch.tensor(data['X_train'], dtype=torch.float32)
    y_train = torch.tensor(data['y_train'], dtype=torch.float32)
    X_meta = torch.tensor(data['X_meta'], dtype=torch.float32)
    y_meta = torch.tensor(data['y_meta'], dtype=torch.float32)
    X_test = torch.tensor(data['X_test'], dtype=torch.float32)
    y_test = torch.tensor(data['y_test'], dtype=torch.float32)
    print(X_train.shape[0], X_meta.shape[0], X_test.shape[0])
    
    l = 1000

    Y_train = y_train.repeat(l, 1).t()
    Y_test = y_test.repeat(l, 1).t()
    Y_meta = y_meta.repeat(l, 1).t()
    
    n, p = np.shape(X_train)
    p = p + 1
    
    
    lam = 100
    beta_prior = MultivariateNormal(loc=torch.zeros(p), covariance_matrix=lam * torch.eye(p))
    v_prior = Beta(0.01 * torch.ones(n), 0.01 * torch.ones(n))

    
    mu = torch.zeros(p, requires_grad=True)
    v_log_diag = torch.rand([p], requires_grad=True)
    v_non_diag = torch.randn([int(p * (p - 1) / 2)], requires_grad=True)
    L_indices_non_diag = torch.tril_indices(row=p, col=p, offset=-1)
    a = torch.rand(n, requires_grad=True)
    b = torch.rand(n, requires_grad=True)

    
    likelihood = BCEWithLogitsLoss(reduction='sum')

   
    l = 1000
    Y_train = y_train.repeat(l, 1).t()

    optimizer = torch.optim.Adam([mu, v_log_diag, v_non_diag, a, b], lr=0.01)

    num_iters = 1000

    loss_all = []

    for iters in range(num_iters):
        
        L = torch.diag(torch.exp(v_log_diag))
        L[L_indices_non_diag[0], L_indices_non_diag[1]] = v_non_diag

        
        beta_post = MultivariateNormal(loc=mu, scale_tril=L)

        
        beta = beta_post.rsample(sample_shape=[l])
    
        v_post = Beta(a, b)
        v = v_post.rsample(sample_shape=[l])

        # pred_logit = torch.matmul(X_train, beta.t())
        pred_logit = torch.matmul(X_train, beta[:,:p-1].t()) + beta[:,p-1].repeat(X_train.shape[0], 1)
        likeli = evaluate_likelihood(Y_train, pred_logit) + 1e-40
        loss = - (v.mean(dim = 0) * torch.log(likeli).mean(dim = 1)).mean() + kl_divergence(beta_post, beta_prior) + kl_divergence(v_post, v_prior).sum()
    
        print(iters, loss.item(), mu[:2])

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_all.append(loss.item())

    print(loss_all[0])
    print(loss_all[-1])
    print(mu)

    plt.plot(loss_all)
    plt.show()
    
    y_test[y_test == 0] = -1
    
    def acc_cal(a,b):
        
        l = a.shape[0]
        assert l == b.shape[0]
    
        t = torch.sign(a * b)
        hit = t[t>0].shape[0]
        # hit = torch.sign(a*b).sum()
    
        return hit / l

    beta_post = MultivariateNormal(loc = mu, scale_tril = L)
    wb = beta_post.rsample(sample_shape=[l])
    aa = torch.matmul(X_test, wb[:,:p-1].t()) + wb[:,p-1].repeat(X_test.shape[0], 1)
    acc = acc_cal(aa.mean(dim = 1), y_test[0])
    test_acc.append(acc)

    print(k+1, test_acc)
# Out:
# 121 26 152
# 0 442.11895751953125 tensor([0., 0.], grad_fn=<SliceBackward>)
# 1 325.900390625 tensor([0.0100, 0.0100], grad_fn=<SliceBackward>)
# 2 306.657470703125 tensor([0.0200, 0.0200], grad_fn=<SliceBackward>)
# 3 302.4735107421875 tensor([0.0300, 0.0300], grad_fn=<SliceBackward>)
# 4 298.27105712890625 tensor([0.0400, 0.0400], grad_fn=<SliceBackward>)
# 5 291.34808349609375 tensor([0.0499, 0.0499], grad_fn=<SliceBackward>)
# 6 285.4355773925781 tensor([0.0599, 0.0599], grad_fn=<SliceBackward>)
# 7 286.656494140625 tensor([0.0698, 0.0699], grad_fn=<SliceBackward>)
# 8 276.5207214355469 tensor([0.0798, 0.0798], grad_fn=<SliceBackward>)
# 9 278.8672180175781 tensor([0.0897, 0.0898], grad_fn=<SliceBackward>)
# 10 268.8357849121094 tensor([0.0995, 0.0996], grad_fn=<SliceBackward>)
# 11 265.66229248046875 tensor([0.1093, 0.1094], grad_fn=<SliceBackward>)
# 12 257.9359130859375 tensor([0.1191, 0.1191], grad_fn=<SliceBackward>)
# 13 267.5944519042969 tensor([0.1287, 0.1288], grad_fn=<SliceBackward>)
# 14 300.25146484375 tensor([0.1383, 0.1385], grad_fn=<SliceBackward>)
# 15 250.89134216308594 tensor([0.1479, 0.1481], grad_fn=<SliceBackward>)
# 16 245.30747985839844 tensor([0.1574, 0.1576], grad_fn=<SliceBackward>)
# 17 241.89483642578125 tensor([0.1668, 0.1671], grad_fn=<SliceBackward>)
# 18 243.67929077148438 tensor([0.1764, 0.1766], grad_fn=<SliceBackward>)
# 19 281.6033020019531 tensor([0.1858, 0.1861], grad_fn=<SliceBackward>)
# 20 241.8236846923828 tensor([0.1953, 0.1954], grad_fn=<SliceBackward>)
# 21 225.5389404296875 tensor([0.2048, 0.2046], grad_fn=<SliceBackward>)
# 22 165.00314331054688 tensor([0.2143, 0.2137], grad_fn=<SliceBackward>)
# 23 357.83343505859375 tensor([0.2239, 0.2228], grad_fn=<SliceBackward>)
# 24 215.9283447265625 tensor([0.2336, 0.2316], grad_fn=<SliceBackward>)
# 25 211.24185180664062 tensor([0.2432, 0.2403], grad_fn=<SliceBackward>)
# 26 231.8912353515625 tensor([0.2528, 0.2488], grad_fn=<SliceBackward>)
# 27 190.6070556640625 tensor([0.2624, 0.2573], grad_fn=<SliceBackward>)
# 28 201.578369140625 tensor([0.2718, 0.2657], grad_fn=<SliceBackward>)
# 29 229.050048828125 tensor([0.2811, 0.2741], grad_fn=<SliceBackward>)
# 30 193.93031311035156 tensor([0.2904, 0.2824], grad_fn=<SliceBackward>)
# 31 207.32379150390625 tensor([0.2997, 0.2906], grad_fn=<SliceBackward>)
# 32 154.76296997070312 tensor([0.3089, 0.2986], grad_fn=<SliceBackward>)
# 33 181.15110778808594 tensor([0.3182, 0.3065], grad_fn=<SliceBackward>)
# 34 178.91619873046875 tensor([0.3274, 0.3144], grad_fn=<SliceBackward>)
# 35 200.8904266357422 tensor([0.3363, 0.3221], grad_fn=<SliceBackward>)
# 36 171.88148498535156 tensor([0.3448, 0.3299], grad_fn=<SliceBackward>)
# 37 121.64096069335938 tensor([0.3530, 0.3377], grad_fn=<SliceBackward>)
# 38 140.87049865722656 tensor([0.3611, 0.3457], grad_fn=<SliceBackward>)
# 39 140.95355224609375 tensor([0.3690, 0.3538], grad_fn=<SliceBackward>)
# 40 156.7012939453125 tensor([0.3768, 0.3619], grad_fn=<SliceBackward>)
# 41 148.6787109375 tensor([0.3842, 0.3701], grad_fn=<SliceBackward>)
# 42 126.16030883789062 tensor([0.3914, 0.3781], grad_fn=<SliceBackward>)
# 43 148.48876953125 tensor([0.3983, 0.3862], grad_fn=<SliceBackward>)
# 44 145.931640625 tensor([0.4051, 0.3943], grad_fn=<SliceBackward>)
# 45 138.10105895996094 tensor([0.4117, 0.4023], grad_fn=<SliceBackward>)
# 46 143.0311279296875 tensor([0.4181, 0.4102], grad_fn=<SliceBackward>)
# 47 137.34658813476562 tensor([0.4242, 0.4181], grad_fn=<SliceBackward>)
# 48 -24.348464965820312 tensor([0.4302, 0.4259], grad_fn=<SliceBackward>)
# 49 127.95785522460938 tensor([0.4357, 0.4336], grad_fn=<SliceBackward>)
# 50 109.49314880371094 tensor([0.4408, 0.4414], grad_fn=<SliceBackward>)
# 51 101.49153137207031 tensor([0.4455, 0.4492], grad_fn=<SliceBackward>)
# 52 107.37169647216797 tensor([0.4498, 0.4570], grad_fn=<SliceBackward>)
# 53 112.4654769897461 tensor([0.4538, 0.4648], grad_fn=<SliceBackward>)
# 54 111.69486999511719 tensor([0.4576, 0.4726], grad_fn=<SliceBackward>)
# 55 115.53790283203125 tensor([0.4612, 0.4804], grad_fn=<SliceBackward>)
# 56 112.43295288085938 tensor([0.4647, 0.4881], grad_fn=<SliceBackward>)
# 57 79.6434097290039 tensor([0.4680, 0.4959], grad_fn=<SliceBackward>)
# 58 109.01553344726562 tensor([0.4708, 0.5035], grad_fn=<SliceBackward>)
# 59 104.70435333251953 tensor([0.4735, 0.5113], grad_fn=<SliceBackward>)
# 60 119.26258087158203 tensor([0.4761, 0.5188], grad_fn=<SliceBackward>)
# 61 87.73505401611328 tensor([0.4782, 0.5262], grad_fn=<SliceBackward>)
# 62 88.95162963867188 tensor([0.4800, 0.5334], grad_fn=<SliceBackward>)
# 63 93.36772918701172 tensor([0.4815, 0.5406], grad_fn=<SliceBackward>)
# 64 97.9400863647461 tensor([0.4828, 0.5478], grad_fn=<SliceBackward>)
# 65 90.68866729736328 tensor([0.4839, 0.5549], grad_fn=<SliceBackward>)
# 66 88.68024444580078 tensor([0.4850, 0.5620], grad_fn=<SliceBackward>)
# 67 82.14676666259766 tensor([0.4859, 0.5690], grad_fn=<SliceBackward>)
# 68 81.8432388305664 tensor([0.4869, 0.5761], grad_fn=<SliceBackward>)
# 69 77.52873229980469 tensor([0.4880, 0.5833], grad_fn=<SliceBackward>)
# 70 93.1711654663086 tensor([0.4889, 0.5906], grad_fn=<SliceBackward>)
# 71 76.67236328125 tensor([0.4901, 0.5981], grad_fn=<SliceBackward>)
# 72 180.84939575195312 tensor([0.4912, 0.6058], grad_fn=<SliceBackward>)
# 73 62.180973052978516 tensor([0.4927, 0.6136], grad_fn=<SliceBackward>)
# 74 46.26260757446289 tensor([0.4944, 0.6215], grad_fn=<SliceBackward>)
# 75 73.52581787109375 tensor([0.4966, 0.6295], grad_fn=<SliceBackward>)
# 76 83.65338134765625 tensor([0.4995, 0.6377], grad_fn=<SliceBackward>)
# 77 62.02740478515625 tensor([0.5031, 0.6461], grad_fn=<SliceBackward>)
# 78 81.47984313964844 tensor([0.5073, 0.6544], grad_fn=<SliceBackward>)
# 79 75.18352508544922 tensor([0.5116, 0.6630], grad_fn=<SliceBackward>)
# 80 80.75871276855469 tensor([0.5160, 0.6715], grad_fn=<SliceBackward>)
# 81 138.2562255859375 tensor([0.5205, 0.6803], grad_fn=<SliceBackward>)
# 82 73.21927642822266 tensor([0.5250, 0.6891], grad_fn=<SliceBackward>)
# 83 37.1221809387207 tensor([0.5296, 0.6979], grad_fn=<SliceBackward>)
# 84 55.502845764160156 tensor([0.5339, 0.7068], grad_fn=<SliceBackward>)
# 85 77.16143798828125 tensor([0.5381, 0.7158], grad_fn=<SliceBackward>)
# 86 74.27008819580078 tensor([0.5420, 0.7248], grad_fn=<SliceBackward>)
# 87 65.4482192993164 tensor([0.5454, 0.7339], grad_fn=<SliceBackward>)
# 88 105.72001647949219 tensor([0.5487, 0.7431], grad_fn=<SliceBackward>)
# 89 55.88543701171875 tensor([0.5516, 0.7526], grad_fn=<SliceBackward>)
# 90 74.6788330078125 tensor([0.5544, 0.7623], grad_fn=<SliceBackward>)
# 91 78.52597045898438 tensor([0.5571, 0.7719], grad_fn=<SliceBackward>)
# 92 75.63273620605469 tensor([0.5596, 0.7817], grad_fn=<SliceBackward>)
# 93 76.17020416259766 tensor([0.5619, 0.7915], grad_fn=<SliceBackward>)
# 94 76.40213012695312 tensor([0.5639, 0.8014], grad_fn=<SliceBackward>)
# 95 77.04253387451172 tensor([0.5658, 0.8112], grad_fn=<SliceBackward>)
# 96 77.07076263427734 tensor([0.5674, 0.8210], grad_fn=<SliceBackward>)
# 97 77.22665405273438 tensor([0.5688, 0.8308], grad_fn=<SliceBackward>)
# 98 77.04683685302734 tensor([0.5701, 0.8406], grad_fn=<SliceBackward>)
# 99 76.8470230102539 tensor([0.5712, 0.8504], grad_fn=<SliceBackward>)
# 100 76.7056884765625 tensor([0.5719, 0.8602], grad_fn=<SliceBackward>)
# 101 76.1209945678711 tensor([0.5725, 0.8702], grad_fn=<SliceBackward>)
# 102 75.94074249267578 tensor([0.5726, 0.8800], grad_fn=<SliceBackward>)
# 103 70.49779510498047 tensor([0.5728, 0.8899], grad_fn=<SliceBackward>)
# 104 75.89822387695312 tensor([0.5726, 0.8997], grad_fn=<SliceBackward>)
# 105 75.09346771240234 tensor([0.5724, 0.9094], grad_fn=<SliceBackward>)
# 106 70.20032501220703 tensor([0.5720, 0.9191], grad_fn=<SliceBackward>)
# 107 80.59632873535156 tensor([0.5716, 0.9288], grad_fn=<SliceBackward>)
# 108 75.12260437011719 tensor([0.5711, 0.9385], grad_fn=<SliceBackward>)
# 109 74.73175811767578 tensor([0.5705, 0.9481], grad_fn=<SliceBackward>)
# 110 74.78421020507812 tensor([0.5697, 0.9577], grad_fn=<SliceBackward>)
# 111 74.71046447753906 tensor([0.5689, 0.9674], grad_fn=<SliceBackward>)
# 112 74.92955780029297 tensor([0.5680, 0.9770], grad_fn=<SliceBackward>)
# 113 74.64855194091797 tensor([0.5668, 0.9867], grad_fn=<SliceBackward>)
# 114 74.47389221191406 tensor([0.5655, 0.9964], grad_fn=<SliceBackward>)
# 115 74.479248046875 tensor([0.5641, 1.0060], grad_fn=<SliceBackward>)
# 116 74.24039459228516 tensor([0.5626, 1.0157], grad_fn=<SliceBackward>)
# 117 74.17565155029297 tensor([0.5609, 1.0252], grad_fn=<SliceBackward>)
# 118 73.9671401977539 tensor([0.5593, 1.0348], grad_fn=<SliceBackward>)
# 119 73.74305725097656 tensor([0.5576, 1.0443], grad_fn=<SliceBackward>)
# 120 73.48085021972656 tensor([0.5558, 1.0538], grad_fn=<SliceBackward>)
# 121 73.50018310546875 tensor([0.5540, 1.0632], grad_fn=<SliceBackward>)
# 122 73.13545227050781 tensor([0.5523, 1.0725], grad_fn=<SliceBackward>)
# 123 72.9182357788086 tensor([0.5504, 1.0819], grad_fn=<SliceBackward>)
# 124 72.66594696044922 tensor([0.5484, 1.0913], grad_fn=<SliceBackward>)
# 125 72.31898498535156 tensor([0.5465, 1.1006], grad_fn=<SliceBackward>)
# 126 72.0137710571289 tensor([0.5447, 1.1100], grad_fn=<SliceBackward>)
# 127 71.8903579711914 tensor([0.5428, 1.1192], grad_fn=<SliceBackward>)
# 128 71.54228210449219 tensor([0.5409, 1.1284], grad_fn=<SliceBackward>)
# 129 71.24824523925781 tensor([0.5390, 1.1375], grad_fn=<SliceBackward>)
# 130 71.02290344238281 tensor([0.5371, 1.1466], grad_fn=<SliceBackward>)
# 131 70.65304565429688 tensor([0.5354, 1.1556], grad_fn=<SliceBackward>)
# 132 70.3428955078125 tensor([0.5338, 1.1646], grad_fn=<SliceBackward>)
# 133 70.0589370727539 tensor([0.5323, 1.1736], grad_fn=<SliceBackward>)
# 134 69.84432983398438 tensor([0.5310, 1.1825], grad_fn=<SliceBackward>)
# 135 69.59422302246094 tensor([0.5297, 1.1913], grad_fn=<SliceBackward>)
# 136 69.15348815917969 tensor([0.5285, 1.2001], grad_fn=<SliceBackward>)
# 137 68.9322738647461 tensor([0.5274, 1.2088], grad_fn=<SliceBackward>)
# 138 68.59547424316406 tensor([0.5265, 1.2174], grad_fn=<SliceBackward>)
# 139 68.2311782836914 tensor([0.5257, 1.2260], grad_fn=<SliceBackward>)
# 140 68.12083435058594 tensor([0.5250, 1.2343], grad_fn=<SliceBackward>)
# 141 67.8121109008789 tensor([0.5244, 1.2426], grad_fn=<SliceBackward>)
# 142 67.50067138671875 tensor([0.5238, 1.2508], grad_fn=<SliceBackward>)
# 143 67.14360046386719 tensor([0.5234, 1.2589], grad_fn=<SliceBackward>)
# 144 66.83184051513672 tensor([0.5230, 1.2669], grad_fn=<SliceBackward>)
# 145 66.49897003173828 tensor([0.5227, 1.2748], grad_fn=<SliceBackward>)
# 146 66.2421646118164 tensor([0.5223, 1.2826], grad_fn=<SliceBackward>)
# 147 66.00360870361328 tensor([0.5220, 1.2904], grad_fn=<SliceBackward>)
# 148 65.59503173828125 tensor([0.5219, 1.2983], grad_fn=<SliceBackward>)
# 149 65.29780578613281 tensor([0.5218, 1.3062], grad_fn=<SliceBackward>)
# 150 65.1636734008789 tensor([0.5218, 1.3141], grad_fn=<SliceBackward>)
# 151 64.8665542602539 tensor([0.5218, 1.3220], grad_fn=<SliceBackward>)
# 152 64.27228546142578 tensor([0.5220, 1.3299], grad_fn=<SliceBackward>)
# 153 63.999534606933594 tensor([0.5223, 1.3377], grad_fn=<SliceBackward>)
# 154 63.604949951171875 tensor([0.5225, 1.3453], grad_fn=<SliceBackward>)
# 155 63.391029357910156 tensor([0.5229, 1.3529], grad_fn=<SliceBackward>)
# 156 63.00801086425781 tensor([0.5234, 1.3605], grad_fn=<SliceBackward>)
# 157 62.76101303100586 tensor([0.5239, 1.3681], grad_fn=<SliceBackward>)
# 158 62.56694793701172 tensor([0.5245, 1.3756], grad_fn=<SliceBackward>)
# 159 62.26182556152344 tensor([0.5251, 1.3831], grad_fn=<SliceBackward>)
# 160 62.007568359375 tensor([0.5257, 1.3906], grad_fn=<SliceBackward>)
# 161 61.72618103027344 tensor([0.5262, 1.3980], grad_fn=<SliceBackward>)
# 162 61.430416107177734 tensor([0.5270, 1.4054], grad_fn=<SliceBackward>)
# 163 61.09161376953125 tensor([0.5277, 1.4128], grad_fn=<SliceBackward>)
# 164 60.857025146484375 tensor([0.5283, 1.4202], grad_fn=<SliceBackward>)
# 165 60.736976623535156 tensor([0.5288, 1.4275], grad_fn=<SliceBackward>)
# 166 60.5546875 tensor([0.5292, 1.4347], grad_fn=<SliceBackward>)
# 167 60.114471435546875 tensor([0.5297, 1.4419], grad_fn=<SliceBackward>)
# 168 59.96720504760742 tensor([0.5304, 1.4490], grad_fn=<SliceBackward>)
# 169 59.6779670715332 tensor([0.5312, 1.4561], grad_fn=<SliceBackward>)
# 170 59.33938980102539 tensor([0.5320, 1.4632], grad_fn=<SliceBackward>)
# 171 59.00507354736328 tensor([0.5329, 1.4703], grad_fn=<SliceBackward>)
# 172 58.79590606689453 tensor([0.5338, 1.4773], grad_fn=<SliceBackward>)
# 173 58.342735290527344 tensor([0.5347, 1.4844], grad_fn=<SliceBackward>)
# 174 58.14253616333008 tensor([0.5356, 1.4914], grad_fn=<SliceBackward>)
# 175 57.872779846191406 tensor([0.5365, 1.4986], grad_fn=<SliceBackward>)
# 176 57.681758880615234 tensor([0.5375, 1.5057], grad_fn=<SliceBackward>)
# 177 57.164794921875 tensor([0.5384, 1.5128], grad_fn=<SliceBackward>)
# 178 56.95500564575195 tensor([0.5393, 1.5200], grad_fn=<SliceBackward>)
# 179 56.68492889404297 tensor([0.5405, 1.5272], grad_fn=<SliceBackward>)
# 180 56.475120544433594 tensor([0.5420, 1.5344], grad_fn=<SliceBackward>)
# 181 56.035526275634766 tensor([0.5437, 1.5418], grad_fn=<SliceBackward>)
# 182 55.7835693359375 tensor([0.5454, 1.5491], grad_fn=<SliceBackward>)
# 183 55.512672424316406 tensor([0.5470, 1.5565], grad_fn=<SliceBackward>)
# 184 55.40815353393555 tensor([0.5486, 1.5639], grad_fn=<SliceBackward>)
# 185 55.05485534667969 tensor([0.5508, 1.5713], grad_fn=<SliceBackward>)
# 186 54.89790725708008 tensor([0.5530, 1.5787], grad_fn=<SliceBackward>)
# 187 54.73069381713867 tensor([0.5553, 1.5860], grad_fn=<SliceBackward>)
# 188 54.4497184753418 tensor([0.5577, 1.5935], grad_fn=<SliceBackward>)
# 189 54.3155517578125 tensor([0.5602, 1.6008], grad_fn=<SliceBackward>)
# 190 54.15250015258789 tensor([0.5628, 1.6082], grad_fn=<SliceBackward>)
# 191 53.891780853271484 tensor([0.5651, 1.6157], grad_fn=<SliceBackward>)
# 192 53.58880615234375 tensor([0.5672, 1.6230], grad_fn=<SliceBackward>)
# 193 53.46642303466797 tensor([0.5693, 1.6305], grad_fn=<SliceBackward>)
# 194 53.559967041015625 tensor([0.5712, 1.6379], grad_fn=<SliceBackward>)
# 195 53.215354919433594 tensor([0.5734, 1.6453], grad_fn=<SliceBackward>)
# 196 52.816368103027344 tensor([0.5756, 1.6529], grad_fn=<SliceBackward>)
# 197 52.729957580566406 tensor([0.5775, 1.6604], grad_fn=<SliceBackward>)
# 198 52.597145080566406 tensor([0.5796, 1.6679], grad_fn=<SliceBackward>)
# 199 52.29564666748047 tensor([0.5818, 1.6755], grad_fn=<SliceBackward>)
# 200 52.03236389160156 tensor([0.5837, 1.6832], grad_fn=<SliceBackward>)
# 201 51.95655059814453 tensor([0.5856, 1.6908], grad_fn=<SliceBackward>)
# 202 51.65961456298828 tensor([0.5875, 1.6984], grad_fn=<SliceBackward>)
# 203 51.2800178527832 tensor([0.5894, 1.7061], grad_fn=<SliceBackward>)
# 204 51.28938674926758 tensor([0.5911, 1.7138], grad_fn=<SliceBackward>)
# 205 50.97983169555664 tensor([0.5927, 1.7215], grad_fn=<SliceBackward>)
# 206 50.89604568481445 tensor([0.5942, 1.7291], grad_fn=<SliceBackward>)
# 207 50.48613739013672 tensor([0.5957, 1.7368], grad_fn=<SliceBackward>)
# 208 50.28811264038086 tensor([0.5971, 1.7444], grad_fn=<SliceBackward>)
# 209 50.16504669189453 tensor([0.5984, 1.7519], grad_fn=<SliceBackward>)
# 210 50.03770446777344 tensor([0.5996, 1.7593], grad_fn=<SliceBackward>)
# 211 49.76953887939453 tensor([0.6008, 1.7668], grad_fn=<SliceBackward>)
# 212 49.48065185546875 tensor([0.6018, 1.7743], grad_fn=<SliceBackward>)
# 213 49.42759323120117 tensor([0.6025, 1.7818], grad_fn=<SliceBackward>)
# 214 49.170406341552734 tensor([0.6031, 1.7893], grad_fn=<SliceBackward>)
# 215 49.049720764160156 tensor([0.6037, 1.7968], grad_fn=<SliceBackward>)
# 216 49.02118682861328 tensor([0.6045, 1.8044], grad_fn=<SliceBackward>)
# 217 48.803489685058594 tensor([0.6054, 1.8120], grad_fn=<SliceBackward>)
# 218 48.685523986816406 tensor([0.6063, 1.8196], grad_fn=<SliceBackward>)
# 219 48.47615432739258 tensor([0.6073, 1.8272], grad_fn=<SliceBackward>)
# 220 48.331329345703125 tensor([0.6083, 1.8347], grad_fn=<SliceBackward>)
# 221 48.21223449707031 tensor([0.6093, 1.8424], grad_fn=<SliceBackward>)
# 222 48.012168884277344 tensor([0.6102, 1.8500], grad_fn=<SliceBackward>)
# 223 47.94495391845703 tensor([0.6109, 1.8577], grad_fn=<SliceBackward>)
# 224 47.6147575378418 tensor([0.6116, 1.8652], grad_fn=<SliceBackward>)
# 225 47.4833984375 tensor([0.6123, 1.8728], grad_fn=<SliceBackward>)
# 226 47.423011779785156 tensor([0.6131, 1.8803], grad_fn=<SliceBackward>)
# 227 47.107818603515625 tensor([0.6137, 1.8879], grad_fn=<SliceBackward>)
# 228 47.03299331665039 tensor([0.6141, 1.8955], grad_fn=<SliceBackward>)
# 229 46.834903717041016 tensor([0.6146, 1.9030], grad_fn=<SliceBackward>)
# 230 46.54909896850586 tensor([0.6151, 1.9105], grad_fn=<SliceBackward>)
# 231 46.54713439941406 tensor([0.6155, 1.9179], grad_fn=<SliceBackward>)
# 232 46.3892707824707 tensor([0.6158, 1.9255], grad_fn=<SliceBackward>)
# 233 46.23213195800781 tensor([0.6159, 1.9330], grad_fn=<SliceBackward>)
# 234 45.957828521728516 tensor([0.6158, 1.9405], grad_fn=<SliceBackward>)
# 235 45.94350814819336 tensor([0.6156, 1.9481], grad_fn=<SliceBackward>)
# 236 45.513938903808594 tensor([0.6157, 1.9554], grad_fn=<SliceBackward>)
# 237 45.359458923339844 tensor([0.6159, 1.9629], grad_fn=<SliceBackward>)
# 238 45.39256286621094 tensor([0.6159, 1.9703], grad_fn=<SliceBackward>)
# 239 45.2015495300293 tensor([0.6163, 1.9777], grad_fn=<SliceBackward>)
# 240 44.97947692871094 tensor([0.6167, 1.9851], grad_fn=<SliceBackward>)
# 241 44.88481521606445 tensor([0.6171, 1.9925], grad_fn=<SliceBackward>)
# 242 44.64396286010742 tensor([0.6174, 1.9999], grad_fn=<SliceBackward>)
# 243 44.54700469970703 tensor([0.6179, 2.0072], grad_fn=<SliceBackward>)
# 244 44.23978805541992 tensor([0.6184, 2.0145], grad_fn=<SliceBackward>)
# 245 44.222721099853516 tensor([0.6190, 2.0216], grad_fn=<SliceBackward>)
# 246 43.927642822265625 tensor([0.6197, 2.0287], grad_fn=<SliceBackward>)
# 247 43.848968505859375 tensor([0.6207, 2.0358], grad_fn=<SliceBackward>)
# 248 43.57273864746094 tensor([0.6220, 2.0428], grad_fn=<SliceBackward>)
# 249 43.4957275390625 tensor([0.6232, 2.0497], grad_fn=<SliceBackward>)
# 250 43.238460540771484 tensor([0.6246, 2.0566], grad_fn=<SliceBackward>)
# 251 43.05708312988281 tensor([0.6264, 2.0633], grad_fn=<SliceBackward>)
# 252 42.86134338378906 tensor([0.6284, 2.0701], grad_fn=<SliceBackward>)
# 253 42.8668212890625 tensor([0.6305, 2.0769], grad_fn=<SliceBackward>)
# 254 42.725135803222656 tensor([0.6327, 2.0838], grad_fn=<SliceBackward>)
# 255 42.47096633911133 tensor([0.6351, 2.0908], grad_fn=<SliceBackward>)
# 256 42.185943603515625 tensor([0.6375, 2.0977], grad_fn=<SliceBackward>)
# 257 42.02035903930664 tensor([0.6401, 2.1046], grad_fn=<SliceBackward>)
# 258 42.17896270751953 tensor([0.6429, 2.1115], grad_fn=<SliceBackward>)
# 259 41.96412658691406 tensor([0.6456, 2.1184], grad_fn=<SliceBackward>)
# 260 41.86220932006836 tensor([0.6484, 2.1253], grad_fn=<SliceBackward>)
# 261 41.781455993652344 tensor([0.6512, 2.1321], grad_fn=<SliceBackward>)
# 262 41.543861389160156 tensor([0.6539, 2.1389], grad_fn=<SliceBackward>)
# 263 41.54362869262695 tensor([0.6566, 2.1457], grad_fn=<SliceBackward>)
# 264 41.47514343261719 tensor([0.6591, 2.1523], grad_fn=<SliceBackward>)
# 265 41.307945251464844 tensor([0.6615, 2.1589], grad_fn=<SliceBackward>)
# 266 41.18219757080078 tensor([0.6637, 2.1655], grad_fn=<SliceBackward>)
# 267 41.07061767578125 tensor([0.6658, 2.1720], grad_fn=<SliceBackward>)
# 268 41.031917572021484 tensor([0.6678, 2.1784], grad_fn=<SliceBackward>)
# 269 40.997371673583984 tensor([0.6697, 2.1848], grad_fn=<SliceBackward>)
# 270 40.785484313964844 tensor([0.6715, 2.1912], grad_fn=<SliceBackward>)
# 271 40.6674690246582 tensor([0.6735, 2.1974], grad_fn=<SliceBackward>)
# 272 40.483619689941406 tensor([0.6755, 2.2036], grad_fn=<SliceBackward>)
# 273 40.47019958496094 tensor([0.6774, 2.2098], grad_fn=<SliceBackward>)
# 274 40.262577056884766 tensor([0.6794, 2.2159], grad_fn=<SliceBackward>)
# 275 40.208229064941406 tensor([0.6810, 2.2219], grad_fn=<SliceBackward>)
# 276 39.958534240722656 tensor([0.6825, 2.2279], grad_fn=<SliceBackward>)
# 277 39.913082122802734 tensor([0.6840, 2.2339], grad_fn=<SliceBackward>)
# 278 39.78324890136719 tensor([0.6853, 2.2398], grad_fn=<SliceBackward>)
# 279 39.76686477661133 tensor([0.6865, 2.2457], grad_fn=<SliceBackward>)
# 280 39.511749267578125 tensor([0.6877, 2.2516], grad_fn=<SliceBackward>)
# 281 39.40884017944336 tensor([0.6886, 2.2575], grad_fn=<SliceBackward>)
# 282 39.20392608642578 tensor([0.6894, 2.2633], grad_fn=<SliceBackward>)
# 283 39.11577606201172 tensor([0.6903, 2.2691], grad_fn=<SliceBackward>)
# 284 39.16510009765625 tensor([0.6913, 2.2749], grad_fn=<SliceBackward>)
# 285 39.091461181640625 tensor([0.6924, 2.2805], grad_fn=<SliceBackward>)
# 286 39.0572509765625 tensor([0.6933, 2.2861], grad_fn=<SliceBackward>)
# 287 38.7968635559082 tensor([0.6938, 2.2919], grad_fn=<SliceBackward>)
# 288 38.679595947265625 tensor([0.6944, 2.2975], grad_fn=<SliceBackward>)
# 289 38.6106071472168 tensor([0.6950, 2.3031], grad_fn=<SliceBackward>)
# 290 38.529701232910156 tensor([0.6952, 2.3086], grad_fn=<SliceBackward>)
# 291 38.286861419677734 tensor([0.6952, 2.3140], grad_fn=<SliceBackward>)
# 292 38.34928894042969 tensor([0.6950, 2.3195], grad_fn=<SliceBackward>)
# 293 38.050235748291016 tensor([0.6949, 2.3248], grad_fn=<SliceBackward>)
# 294 38.231529235839844 tensor([0.6946, 2.3301], grad_fn=<SliceBackward>)
# 295 37.87047576904297 tensor([0.6942, 2.3354], grad_fn=<SliceBackward>)
# 296 38.021934509277344 tensor([0.6936, 2.3407], grad_fn=<SliceBackward>)
# 297 37.892173767089844 tensor([0.6928, 2.3460], grad_fn=<SliceBackward>)
# 298 37.67082595825195 tensor([0.6916, 2.3513], grad_fn=<SliceBackward>)
# 299 37.57550811767578 tensor([0.6903, 2.3566], grad_fn=<SliceBackward>)
# 300 37.77606201171875 tensor([0.6891, 2.3619], grad_fn=<SliceBackward>)
# 301 37.568458557128906 tensor([0.6879, 2.3672], grad_fn=<SliceBackward>)
# 302 37.53501892089844 tensor([0.6869, 2.3724], grad_fn=<SliceBackward>)
# 303 37.30630874633789 tensor([0.6858, 2.3775], grad_fn=<SliceBackward>)
# 304 37.337039947509766 tensor([0.6846, 2.3827], grad_fn=<SliceBackward>)
# 305 37.21642303466797 tensor([0.6834, 2.3879], grad_fn=<SliceBackward>)
# 306 37.22252655029297 tensor([0.6820, 2.3931], grad_fn=<SliceBackward>)
# 307 37.08727264404297 tensor([0.6807, 2.3982], grad_fn=<SliceBackward>)
# 308 36.97324752807617 tensor([0.6792, 2.4035], grad_fn=<SliceBackward>)
# 309 36.721309661865234 tensor([0.6776, 2.4088], grad_fn=<SliceBackward>)
# 310 36.7745246887207 tensor([0.6756, 2.4139], grad_fn=<SliceBackward>)
# 311 36.46449279785156 tensor([0.6735, 2.4190], grad_fn=<SliceBackward>)
# 312 36.35539245605469 tensor([0.6715, 2.4240], grad_fn=<SliceBackward>)
# 313 36.50325393676758 tensor([0.6693, 2.4291], grad_fn=<SliceBackward>)
# 314 36.426971435546875 tensor([0.6667, 2.4343], grad_fn=<SliceBackward>)
# 315 36.48247146606445 tensor([0.6639, 2.4395], grad_fn=<SliceBackward>)
# 316 36.088523864746094 tensor([0.6611, 2.4446], grad_fn=<SliceBackward>)
# 317 35.958770751953125 tensor([0.6582, 2.4496], grad_fn=<SliceBackward>)
# 318 36.00895690917969 tensor([0.6550, 2.4546], grad_fn=<SliceBackward>)
# 319 35.95927429199219 tensor([0.6518, 2.4596], grad_fn=<SliceBackward>)
# 320 35.78567123413086 tensor([0.6484, 2.4645], grad_fn=<SliceBackward>)
# 321 35.85782241821289 tensor([0.6451, 2.4694], grad_fn=<SliceBackward>)
# 322 35.652931213378906 tensor([0.6417, 2.4744], grad_fn=<SliceBackward>)
# 323 35.56283187866211 tensor([0.6382, 2.4794], grad_fn=<SliceBackward>)
# 324 35.56785583496094 tensor([0.6349, 2.4843], grad_fn=<SliceBackward>)
# 325 35.488311767578125 tensor([0.6315, 2.4892], grad_fn=<SliceBackward>)
# 326 35.63481521606445 tensor([0.6280, 2.4940], grad_fn=<SliceBackward>)
# 327 35.3709716796875 tensor([0.6245, 2.4988], grad_fn=<SliceBackward>)
# 328 35.266563415527344 tensor([0.6210, 2.5036], grad_fn=<SliceBackward>)
# 329 35.22315216064453 tensor([0.6173, 2.5083], grad_fn=<SliceBackward>)
# 330 35.306922912597656 tensor([0.6137, 2.5131], grad_fn=<SliceBackward>)
# 331 35.263694763183594 tensor([0.6101, 2.5178], grad_fn=<SliceBackward>)
# 332 35.07011795043945 tensor([0.6065, 2.5225], grad_fn=<SliceBackward>)
# 333 34.9530029296875 tensor([0.6030, 2.5271], grad_fn=<SliceBackward>)
# 334 35.11760711669922 tensor([0.5997, 2.5317], grad_fn=<SliceBackward>)
# 335 34.993377685546875 tensor([0.5967, 2.5362], grad_fn=<SliceBackward>)
# 336 34.851478576660156 tensor([0.5938, 2.5408], grad_fn=<SliceBackward>)
# 337 34.82063674926758 tensor([0.5911, 2.5454], grad_fn=<SliceBackward>)
# 338 34.87569808959961 tensor([0.5886, 2.5499], grad_fn=<SliceBackward>)
# 339 34.562889099121094 tensor([0.5859, 2.5545], grad_fn=<SliceBackward>)
# 340 34.78155517578125 tensor([0.5831, 2.5590], grad_fn=<SliceBackward>)
# 341 34.68353271484375 tensor([0.5806, 2.5635], grad_fn=<SliceBackward>)
# 342 34.632747650146484 tensor([0.5782, 2.5681], grad_fn=<SliceBackward>)
# 343 34.630615234375 tensor([0.5758, 2.5725], grad_fn=<SliceBackward>)
# 344 34.60540008544922 tensor([0.5734, 2.5769], grad_fn=<SliceBackward>)
# 345 34.467430114746094 tensor([0.5711, 2.5812], grad_fn=<SliceBackward>)
# 346 34.64222717285156 tensor([0.5687, 2.5856], grad_fn=<SliceBackward>)
# 347 34.45372009277344 tensor([0.5663, 2.5899], grad_fn=<SliceBackward>)
# 348 34.35955047607422 tensor([0.5638, 2.5943], grad_fn=<SliceBackward>)
# 349 34.37065124511719 tensor([0.5610, 2.5987], grad_fn=<SliceBackward>)
# 350 34.32671356201172 tensor([0.5583, 2.6031], grad_fn=<SliceBackward>)
# 351 34.17374038696289 tensor([0.5555, 2.6075], grad_fn=<SliceBackward>)
# 352 34.28386306762695 tensor([0.5527, 2.6117], grad_fn=<SliceBackward>)
# 353 34.12700271606445 tensor([0.5500, 2.6160], grad_fn=<SliceBackward>)
# 354 33.86195755004883 tensor([0.5475, 2.6202], grad_fn=<SliceBackward>)
# 355 33.95594787597656 tensor([0.5449, 2.6244], grad_fn=<SliceBackward>)
# 356 33.76390075683594 tensor([0.5422, 2.6285], grad_fn=<SliceBackward>)
# 357 33.81782150268555 tensor([0.5396, 2.6326], grad_fn=<SliceBackward>)
# 358 33.838417053222656 tensor([0.5372, 2.6366], grad_fn=<SliceBackward>)
# 359 33.81069564819336 tensor([0.5353, 2.6406], grad_fn=<SliceBackward>)
# 360 33.778648376464844 tensor([0.5337, 2.6445], grad_fn=<SliceBackward>)
# 361 33.81377410888672 tensor([0.5319, 2.6484], grad_fn=<SliceBackward>)
# 362 33.7196044921875 tensor([0.5304, 2.6522], grad_fn=<SliceBackward>)
# 363 33.678504943847656 tensor([0.5291, 2.6560], grad_fn=<SliceBackward>)
# 364 33.528324127197266 tensor([0.5280, 2.6599], grad_fn=<SliceBackward>)
# 365 33.42328643798828 tensor([0.5271, 2.6636], grad_fn=<SliceBackward>)
# 366 33.376991271972656 tensor([0.5262, 2.6673], grad_fn=<SliceBackward>)
# 367 33.541046142578125 tensor([0.5251, 2.6710], grad_fn=<SliceBackward>)
# 368 33.34941482543945 tensor([0.5242, 2.6747], grad_fn=<SliceBackward>)
# 369 33.3349609375 tensor([0.5228, 2.6783], grad_fn=<SliceBackward>)
# 370 33.43683624267578 tensor([0.5213, 2.6820], grad_fn=<SliceBackward>)
# 371 33.253753662109375 tensor([0.5198, 2.6856], grad_fn=<SliceBackward>)
# 372 33.12434387207031 tensor([0.5184, 2.6892], grad_fn=<SliceBackward>)
# 373 33.048057556152344 tensor([0.5169, 2.6928], grad_fn=<SliceBackward>)
# 374 33.04579162597656 tensor([0.5151, 2.6963], grad_fn=<SliceBackward>)
# 375 33.05229187011719 tensor([0.5135, 2.6998], grad_fn=<SliceBackward>)
# 376 32.99488067626953 tensor([0.5121, 2.7033], grad_fn=<SliceBackward>)
# 377 32.826805114746094 tensor([0.5107, 2.7069], grad_fn=<SliceBackward>)
# 378 32.929874420166016 tensor([0.5094, 2.7104], grad_fn=<SliceBackward>)
# 379 32.855865478515625 tensor([0.5081, 2.7139], grad_fn=<SliceBackward>)
# 380 32.66747283935547 tensor([0.5068, 2.7174], grad_fn=<SliceBackward>)
# 381 32.70720672607422 tensor([0.5057, 2.7209], grad_fn=<SliceBackward>)
# 382 32.76158142089844 tensor([0.5045, 2.7242], grad_fn=<SliceBackward>)
# 383 32.711753845214844 tensor([0.5036, 2.7276], grad_fn=<SliceBackward>)
# 384 32.52366638183594 tensor([0.5025, 2.7311], grad_fn=<SliceBackward>)
# 385 32.497589111328125 tensor([0.5014, 2.7346], grad_fn=<SliceBackward>)
# 386 32.46442794799805 tensor([0.5003, 2.7380], grad_fn=<SliceBackward>)
# 387 32.5893440246582 tensor([0.4991, 2.7414], grad_fn=<SliceBackward>)
# 388 32.443572998046875 tensor([0.4980, 2.7449], grad_fn=<SliceBackward>)
# 389 32.38185501098633 tensor([0.4967, 2.7484], grad_fn=<SliceBackward>)
# 390 32.252559661865234 tensor([0.4954, 2.7518], grad_fn=<SliceBackward>)
# 391 32.32007598876953 tensor([0.4941, 2.7553], grad_fn=<SliceBackward>)
# 392 32.18894958496094 tensor([0.4930, 2.7586], grad_fn=<SliceBackward>)
# 393 32.25078582763672 tensor([0.4919, 2.7621], grad_fn=<SliceBackward>)
# 394 32.16209411621094 tensor([0.4910, 2.7657], grad_fn=<SliceBackward>)
# 395 32.102474212646484 tensor([0.4899, 2.7692], grad_fn=<SliceBackward>)
# 396 32.145748138427734 tensor([0.4891, 2.7728], grad_fn=<SliceBackward>)
# 397 32.12171173095703 tensor([0.4884, 2.7764], grad_fn=<SliceBackward>)
# 398 31.79953384399414 tensor([0.4876, 2.7797], grad_fn=<SliceBackward>)
# 399 31.94553565979004 tensor([0.4868, 2.7830], grad_fn=<SliceBackward>)
# 400 31.956298828125 tensor([0.4859, 2.7862], grad_fn=<SliceBackward>)
# 401 31.8526611328125 tensor([0.4851, 2.7894], grad_fn=<SliceBackward>)
# 402 31.640060424804688 tensor([0.4844, 2.7926], grad_fn=<SliceBackward>)
# 403 31.789257049560547 tensor([0.4839, 2.7957], grad_fn=<SliceBackward>)
# 404 31.61943817138672 tensor([0.4836, 2.7988], grad_fn=<SliceBackward>)
# 405 31.549880981445312 tensor([0.4832, 2.8017], grad_fn=<SliceBackward>)
# 406 31.465007781982422 tensor([0.4828, 2.8045], grad_fn=<SliceBackward>)
# 407 31.60416603088379 tensor([0.4829, 2.8072], grad_fn=<SliceBackward>)
# 408 31.524473190307617 tensor([0.4830, 2.8100], grad_fn=<SliceBackward>)
# 409 31.433074951171875 tensor([0.4829, 2.8128], grad_fn=<SliceBackward>)
# 410 31.501331329345703 tensor([0.4827, 2.8155], grad_fn=<SliceBackward>)
# 411 31.369863510131836 tensor([0.4823, 2.8184], grad_fn=<SliceBackward>)
# 412 31.340923309326172 tensor([0.4818, 2.8213], grad_fn=<SliceBackward>)
# 413 31.370452880859375 tensor([0.4814, 2.8241], grad_fn=<SliceBackward>)
# 414 31.121925354003906 tensor([0.4812, 2.8270], grad_fn=<SliceBackward>)
# 415 31.13787269592285 tensor([0.4813, 2.8299], grad_fn=<SliceBackward>)
# 416 31.244665145874023 tensor([0.4813, 2.8329], grad_fn=<SliceBackward>)
# 417 31.05061912536621 tensor([0.4809, 2.8359], grad_fn=<SliceBackward>)
# 418 31.064186096191406 tensor([0.4804, 2.8389], grad_fn=<SliceBackward>)
# 419 31.05976104736328 tensor([0.4802, 2.8419], grad_fn=<SliceBackward>)
# 420 30.84435272216797 tensor([0.4800, 2.8449], grad_fn=<SliceBackward>)
# 421 31.025066375732422 tensor([0.4800, 2.8479], grad_fn=<SliceBackward>)
# 422 30.929855346679688 tensor([0.4799, 2.8509], grad_fn=<SliceBackward>)
# 423 30.939247131347656 tensor([0.4799, 2.8540], grad_fn=<SliceBackward>)
# 424 30.892532348632812 tensor([0.4800, 2.8569], grad_fn=<SliceBackward>)
# 425 30.784215927124023 tensor([0.4801, 2.8597], grad_fn=<SliceBackward>)
# 426 30.59552001953125 tensor([0.4801, 2.8627], grad_fn=<SliceBackward>)
# 427 30.53144645690918 tensor([0.4800, 2.8656], grad_fn=<SliceBackward>)
# 428 30.624141693115234 tensor([0.4797, 2.8684], grad_fn=<SliceBackward>)
# 429 30.46613311767578 tensor([0.4796, 2.8712], grad_fn=<SliceBackward>)
# 430 30.554073333740234 tensor([0.4796, 2.8738], grad_fn=<SliceBackward>)
# 431 30.339210510253906 tensor([0.4796, 2.8764], grad_fn=<SliceBackward>)
# 432 30.526317596435547 tensor([0.4793, 2.8790], grad_fn=<SliceBackward>)
# 433 30.367324829101562 tensor([0.4793, 2.8816], grad_fn=<SliceBackward>)
# 434 30.33041000366211 tensor([0.4793, 2.8841], grad_fn=<SliceBackward>)
# 435 30.089813232421875 tensor([0.4791, 2.8865], grad_fn=<SliceBackward>)
# 436 30.337520599365234 tensor([0.4789, 2.8889], grad_fn=<SliceBackward>)
# 437 30.326534271240234 tensor([0.4785, 2.8914], grad_fn=<SliceBackward>)
# 438 30.005783081054688 tensor([0.4782, 2.8939], grad_fn=<SliceBackward>)
# 439 30.2239933013916 tensor([0.4776, 2.8963], grad_fn=<SliceBackward>)
# 440 30.178897857666016 tensor([0.4771, 2.8987], grad_fn=<SliceBackward>)
# 441 30.049192428588867 tensor([0.4766, 2.9011], grad_fn=<SliceBackward>)
# 442 30.165311813354492 tensor([0.4757, 2.9035], grad_fn=<SliceBackward>)
# 443 30.13297462463379 tensor([0.4751, 2.9058], grad_fn=<SliceBackward>)
# 444 30.02444839477539 tensor([0.4747, 2.9083], grad_fn=<SliceBackward>)
# 445 29.998689651489258 tensor([0.4741, 2.9106], grad_fn=<SliceBackward>)
# 446 29.869945526123047 tensor([0.4730, 2.9129], grad_fn=<SliceBackward>)
# 447 29.85858154296875 tensor([0.4718, 2.9153], grad_fn=<SliceBackward>)
# 448 29.825008392333984 tensor([0.4707, 2.9177], grad_fn=<SliceBackward>)
# 449 29.821163177490234 tensor([0.4701, 2.9200], grad_fn=<SliceBackward>)
# 450 29.701339721679688 tensor([0.4695, 2.9225], grad_fn=<SliceBackward>)
# 451 29.833301544189453 tensor([0.4688, 2.9251], grad_fn=<SliceBackward>)
# 452 29.763917922973633 tensor([0.4682, 2.9276], grad_fn=<SliceBackward>)
# 453 29.613731384277344 tensor([0.4675, 2.9301], grad_fn=<SliceBackward>)
# 454 29.738515853881836 tensor([0.4665, 2.9326], grad_fn=<SliceBackward>)
# 455 29.56209945678711 tensor([0.4659, 2.9351], grad_fn=<SliceBackward>)
# 456 29.773353576660156 tensor([0.4654, 2.9374], grad_fn=<SliceBackward>)
# 457 29.695777893066406 tensor([0.4644, 2.9398], grad_fn=<SliceBackward>)
# 458 29.845680236816406 tensor([0.4638, 2.9422], grad_fn=<SliceBackward>)
# 459 29.639427185058594 tensor([0.4630, 2.9447], grad_fn=<SliceBackward>)
# 460 29.80997085571289 tensor([0.4621, 2.9471], grad_fn=<SliceBackward>)
# 461 29.828264236450195 tensor([0.4613, 2.9495], grad_fn=<SliceBackward>)
# 462 29.51761245727539 tensor([0.4606, 2.9520], grad_fn=<SliceBackward>)
# 463 29.427961349487305 tensor([0.4600, 2.9544], grad_fn=<SliceBackward>)
# 464 29.359920501708984 tensor([0.4592, 2.9569], grad_fn=<SliceBackward>)
# 465 29.667255401611328 tensor([0.4584, 2.9593], grad_fn=<SliceBackward>)
# 466 29.37067985534668 tensor([0.4579, 2.9616], grad_fn=<SliceBackward>)
# 467 29.527456283569336 tensor([0.4573, 2.9637], grad_fn=<SliceBackward>)
# 468 29.687950134277344 tensor([0.4565, 2.9660], grad_fn=<SliceBackward>)
# 469 29.601802825927734 tensor([0.4558, 2.9683], grad_fn=<SliceBackward>)
# 470 29.557281494140625 tensor([0.4552, 2.9706], grad_fn=<SliceBackward>)
# 471 29.582691192626953 tensor([0.4547, 2.9729], grad_fn=<SliceBackward>)
# 472 29.463199615478516 tensor([0.4540, 2.9753], grad_fn=<SliceBackward>)
# 473 29.595932006835938 tensor([0.4535, 2.9776], grad_fn=<SliceBackward>)
# 474 29.60399627685547 tensor([0.4530, 2.9800], grad_fn=<SliceBackward>)
# 475 29.543479919433594 tensor([0.4526, 2.9824], grad_fn=<SliceBackward>)
# 476 29.460872650146484 tensor([0.4523, 2.9848], grad_fn=<SliceBackward>)
# 477 29.42107391357422 tensor([0.4519, 2.9872], grad_fn=<SliceBackward>)
# 478 29.382335662841797 tensor([0.4517, 2.9895], grad_fn=<SliceBackward>)
# 479 29.361980438232422 tensor([0.4515, 2.9917], grad_fn=<SliceBackward>)
# 480 29.372310638427734 tensor([0.4510, 2.9940], grad_fn=<SliceBackward>)
# 481 29.297945022583008 tensor([0.4506, 2.9963], grad_fn=<SliceBackward>)
# 482 29.140438079833984 tensor([0.4502, 2.9985], grad_fn=<SliceBackward>)
# 483 29.204181671142578 tensor([0.4495, 3.0007], grad_fn=<SliceBackward>)
# 484 29.14017105102539 tensor([0.4491, 3.0029], grad_fn=<SliceBackward>)
# 485 29.158540725708008 tensor([0.4487, 3.0050], grad_fn=<SliceBackward>)
# 486 29.127779006958008 tensor([0.4481, 3.0071], grad_fn=<SliceBackward>)
# 487 28.999526977539062 tensor([0.4475, 3.0091], grad_fn=<SliceBackward>)
# 488 28.862197875976562 tensor([0.4467, 3.0113], grad_fn=<SliceBackward>)
# 489 28.864627838134766 tensor([0.4458, 3.0135], grad_fn=<SliceBackward>)
# 490 29.00679588317871 tensor([0.4452, 3.0155], grad_fn=<SliceBackward>)
# 491 28.74078369140625 tensor([0.4446, 3.0176], grad_fn=<SliceBackward>)
# 492 28.6344051361084 tensor([0.4439, 3.0197], grad_fn=<SliceBackward>)
# 493 28.533626556396484 tensor([0.4432, 3.0217], grad_fn=<SliceBackward>)
# 494 28.447134017944336 tensor([0.4426, 3.0235], grad_fn=<SliceBackward>)
# 495 28.238525390625 tensor([0.4419, 3.0253], grad_fn=<SliceBackward>)
# 496 28.597972869873047 tensor([0.4414, 3.0271], grad_fn=<SliceBackward>)
# 497 28.26528549194336 tensor([0.4413, 3.0289], grad_fn=<SliceBackward>)
# 498 28.231271743774414 tensor([0.4416, 3.0306], grad_fn=<SliceBackward>)
# 499 28.03221321105957 tensor([0.4420, 3.0323], grad_fn=<SliceBackward>)
# 500 28.286787033081055 tensor([0.4424, 3.0340], grad_fn=<SliceBackward>)
# 501 28.18412971496582 tensor([0.4431, 3.0355], grad_fn=<SliceBackward>)
# 502 28.14287567138672 tensor([0.4435, 3.0370], grad_fn=<SliceBackward>)
# 503 27.961284637451172 tensor([0.4439, 3.0386], grad_fn=<SliceBackward>)
# 504 27.971214294433594 tensor([0.4445, 3.0400], grad_fn=<SliceBackward>)
# 505 27.990188598632812 tensor([0.4453, 3.0413], grad_fn=<SliceBackward>)
# 506 28.007034301757812 tensor([0.4461, 3.0426], grad_fn=<SliceBackward>)
# 507 27.94011688232422 tensor([0.4471, 3.0439], grad_fn=<SliceBackward>)
# 508 27.87737274169922 tensor([0.4481, 3.0449], grad_fn=<SliceBackward>)
# 509 27.797183990478516 tensor([0.4489, 3.0459], grad_fn=<SliceBackward>)
# 510 27.86817169189453 tensor([0.4495, 3.0470], grad_fn=<SliceBackward>)
# 511 27.66634178161621 tensor([0.4504, 3.0482], grad_fn=<SliceBackward>)
# 512 27.619388580322266 tensor([0.4515, 3.0494], grad_fn=<SliceBackward>)
# 513 27.5855712890625 tensor([0.4528, 3.0506], grad_fn=<SliceBackward>)
# 514 27.572772979736328 tensor([0.4541, 3.0517], grad_fn=<SliceBackward>)
# 515 27.49982261657715 tensor([0.4555, 3.0526], grad_fn=<SliceBackward>)
# 516 27.49146270751953 tensor([0.4571, 3.0535], grad_fn=<SliceBackward>)
# 517 27.580829620361328 tensor([0.4589, 3.0544], grad_fn=<SliceBackward>)
# 518 27.557483673095703 tensor([0.4609, 3.0550], grad_fn=<SliceBackward>)
# 519 27.515846252441406 tensor([0.4627, 3.0557], grad_fn=<SliceBackward>)
# 520 27.616321563720703 tensor([0.4648, 3.0563], grad_fn=<SliceBackward>)
# 521 27.363834381103516 tensor([0.4667, 3.0571], grad_fn=<SliceBackward>)
# 522 27.395549774169922 tensor([0.4690, 3.0579], grad_fn=<SliceBackward>)
# 523 27.44328498840332 tensor([0.4710, 3.0587], grad_fn=<SliceBackward>)
# 524 27.411788940429688 tensor([0.4729, 3.0594], grad_fn=<SliceBackward>)
# 525 27.40300941467285 tensor([0.4750, 3.0603], grad_fn=<SliceBackward>)
# 526 27.354949951171875 tensor([0.4772, 3.0612], grad_fn=<SliceBackward>)
# 527 27.297191619873047 tensor([0.4789, 3.0619], grad_fn=<SliceBackward>)
# 528 27.251327514648438 tensor([0.4806, 3.0625], grad_fn=<SliceBackward>)
# 529 27.265626907348633 tensor([0.4823, 3.0631], grad_fn=<SliceBackward>)
# 530 27.31836700439453 tensor([0.4835, 3.0638], grad_fn=<SliceBackward>)
# 531 27.230714797973633 tensor([0.4848, 3.0644], grad_fn=<SliceBackward>)
# 532 27.208480834960938 tensor([0.4859, 3.0651], grad_fn=<SliceBackward>)
# 533 27.066898345947266 tensor([0.4872, 3.0658], grad_fn=<SliceBackward>)
# 534 27.31583595275879 tensor([0.4885, 3.0664], grad_fn=<SliceBackward>)
# 535 27.133892059326172 tensor([0.4900, 3.0669], grad_fn=<SliceBackward>)
# 536 27.086000442504883 tensor([0.4914, 3.0674], grad_fn=<SliceBackward>)
# 537 27.08432388305664 tensor([0.4930, 3.0679], grad_fn=<SliceBackward>)
# 538 27.023183822631836 tensor([0.4946, 3.0684], grad_fn=<SliceBackward>)
# 539 26.982118606567383 tensor([0.4960, 3.0690], grad_fn=<SliceBackward>)
# 540 26.997623443603516 tensor([0.4977, 3.0695], grad_fn=<SliceBackward>)
# 541 27.01749038696289 tensor([0.4996, 3.0700], grad_fn=<SliceBackward>)
# 542 26.827720642089844 tensor([0.5016, 3.0705], grad_fn=<SliceBackward>)
# 543 26.902557373046875 tensor([0.5033, 3.0709], grad_fn=<SliceBackward>)
# 544 26.90162467956543 tensor([0.5049, 3.0713], grad_fn=<SliceBackward>)
# 545 26.775123596191406 tensor([0.5064, 3.0717], grad_fn=<SliceBackward>)
# 546 26.94778060913086 tensor([0.5077, 3.0720], grad_fn=<SliceBackward>)
# 547 26.843799591064453 tensor([0.5094, 3.0724], grad_fn=<SliceBackward>)
# 548 26.81753921508789 tensor([0.5114, 3.0727], grad_fn=<SliceBackward>)
# 549 26.7916202545166 tensor([0.5137, 3.0729], grad_fn=<SliceBackward>)
# 550 26.891279220581055 tensor([0.5159, 3.0731], grad_fn=<SliceBackward>)
# 551 26.666645050048828 tensor([0.5183, 3.0734], grad_fn=<SliceBackward>)
# 552 26.8068904876709 tensor([0.5203, 3.0736], grad_fn=<SliceBackward>)
# 553 26.66327476501465 tensor([0.5223, 3.0738], grad_fn=<SliceBackward>)
# 554 26.70574188232422 tensor([0.5243, 3.0740], grad_fn=<SliceBackward>)
# 555 26.79428482055664 tensor([0.5264, 3.0742], grad_fn=<SliceBackward>)
# 556 26.701902389526367 tensor([0.5285, 3.0744], grad_fn=<SliceBackward>)
# 557 26.601011276245117 tensor([0.5308, 3.0746], grad_fn=<SliceBackward>)
# 558 26.560791015625 tensor([0.5327, 3.0748], grad_fn=<SliceBackward>)
# 559 26.613391876220703 tensor([0.5346, 3.0749], grad_fn=<SliceBackward>)
# 560 26.505842208862305 tensor([0.5369, 3.0750], grad_fn=<SliceBackward>)
# 561 26.58348846435547 tensor([0.5390, 3.0750], grad_fn=<SliceBackward>)
# 562 26.422332763671875 tensor([0.5410, 3.0749], grad_fn=<SliceBackward>)
# 563 26.462177276611328 tensor([0.5431, 3.0747], grad_fn=<SliceBackward>)
# 564 26.49988555908203 tensor([0.5452, 3.0744], grad_fn=<SliceBackward>)
# 565 26.563791275024414 tensor([0.5469, 3.0740], grad_fn=<SliceBackward>)
# 566 26.50398826599121 tensor([0.5484, 3.0736], grad_fn=<SliceBackward>)
# 567 26.418752670288086 tensor([0.5496, 3.0732], grad_fn=<SliceBackward>)
# 568 26.420028686523438 tensor([0.5502, 3.0728], grad_fn=<SliceBackward>)
# 569 26.281673431396484 tensor([0.5506, 3.0724], grad_fn=<SliceBackward>)
# 570 26.369844436645508 tensor([0.5512, 3.0720], grad_fn=<SliceBackward>)
# 571 26.239973068237305 tensor([0.5520, 3.0716], grad_fn=<SliceBackward>)
# 572 26.27634048461914 tensor([0.5525, 3.0712], grad_fn=<SliceBackward>)
# 573 26.43442153930664 tensor([0.5530, 3.0708], grad_fn=<SliceBackward>)
# 574 26.25247573852539 tensor([0.5536, 3.0704], grad_fn=<SliceBackward>)
# 575 26.520782470703125 tensor([0.5540, 3.0700], grad_fn=<SliceBackward>)
# 576 26.36189079284668 tensor([0.5543, 3.0696], grad_fn=<SliceBackward>)
# 577 26.3609561920166 tensor([0.5545, 3.0691], grad_fn=<SliceBackward>)
# 578 26.273361206054688 tensor([0.5547, 3.0687], grad_fn=<SliceBackward>)
# 579 26.46344757080078 tensor([0.5548, 3.0683], grad_fn=<SliceBackward>)
# 580 26.198352813720703 tensor([0.5549, 3.0678], grad_fn=<SliceBackward>)
# 581 26.207120895385742 tensor([0.5550, 3.0675], grad_fn=<SliceBackward>)
# 582 26.26947021484375 tensor([0.5551, 3.0671], grad_fn=<SliceBackward>)
# 583 26.189464569091797 tensor([0.5550, 3.0665], grad_fn=<SliceBackward>)
# 584 26.239595413208008 tensor([0.5551, 3.0660], grad_fn=<SliceBackward>)
# 585 26.25493621826172 tensor([0.5553, 3.0653], grad_fn=<SliceBackward>)
# 586 26.185388565063477 tensor([0.5554, 3.0647], grad_fn=<SliceBackward>)
# 587 26.098936080932617 tensor([0.5557, 3.0642], grad_fn=<SliceBackward>)
# 588 26.13378143310547 tensor([0.5557, 3.0638], grad_fn=<SliceBackward>)
# 589 26.001808166503906 tensor([0.5558, 3.0634], grad_fn=<SliceBackward>)
# 590 26.124053955078125 tensor([0.5562, 3.0629], grad_fn=<SliceBackward>)
# 591 25.98610496520996 tensor([0.5563, 3.0623], grad_fn=<SliceBackward>)
# 592 25.903602600097656 tensor([0.5565, 3.0616], grad_fn=<SliceBackward>)
# 593 26.22059440612793 tensor([0.5565, 3.0610], grad_fn=<SliceBackward>)
# 594 25.999448776245117 tensor([0.5566, 3.0603], grad_fn=<SliceBackward>)
# 595 26.169254302978516 tensor([0.5568, 3.0595], grad_fn=<SliceBackward>)
# 596 25.94350242614746 tensor([0.5572, 3.0587], grad_fn=<SliceBackward>)
# 597 25.843975067138672 tensor([0.5571, 3.0579], grad_fn=<SliceBackward>)
# 598 25.86583709716797 tensor([0.5569, 3.0569], grad_fn=<SliceBackward>)
# 599 25.9649600982666 tensor([0.5562, 3.0559], grad_fn=<SliceBackward>)
# 600 25.86821174621582 tensor([0.5558, 3.0550], grad_fn=<SliceBackward>)
# 601 26.005050659179688 tensor([0.5556, 3.0543], grad_fn=<SliceBackward>)
# 602 25.828163146972656 tensor([0.5554, 3.0536], grad_fn=<SliceBackward>)
# 603 25.812301635742188 tensor([0.5551, 3.0528], grad_fn=<SliceBackward>)
# 604 25.910701751708984 tensor([0.5549, 3.0519], grad_fn=<SliceBackward>)
# 605 25.745315551757812 tensor([0.5547, 3.0511], grad_fn=<SliceBackward>)
# 606 25.727628707885742 tensor([0.5545, 3.0502], grad_fn=<SliceBackward>)
# 607 25.77886199951172 tensor([0.5542, 3.0492], grad_fn=<SliceBackward>)
# 608 25.60828971862793 tensor([0.5541, 3.0482], grad_fn=<SliceBackward>)
# 609 25.675933837890625 tensor([0.5541, 3.0474], grad_fn=<SliceBackward>)
# 610 25.634273529052734 tensor([0.5539, 3.0464], grad_fn=<SliceBackward>)
# 611 25.575729370117188 tensor([0.5538, 3.0454], grad_fn=<SliceBackward>)
# 612 25.76726531982422 tensor([0.5536, 3.0444], grad_fn=<SliceBackward>)
# 613 25.695476531982422 tensor([0.5534, 3.0435], grad_fn=<SliceBackward>)
# 614 25.655471801757812 tensor([0.5530, 3.0425], grad_fn=<SliceBackward>)
# 615 25.739376068115234 tensor([0.5526, 3.0414], grad_fn=<SliceBackward>)
# 616 25.624942779541016 tensor([0.5525, 3.0402], grad_fn=<SliceBackward>)
# 617 25.658287048339844 tensor([0.5523, 3.0391], grad_fn=<SliceBackward>)
# 618 25.639768600463867 tensor([0.5519, 3.0378], grad_fn=<SliceBackward>)
# 619 25.74694061279297 tensor([0.5518, 3.0365], grad_fn=<SliceBackward>)
# 620 25.41016387939453 tensor([0.5515, 3.0352], grad_fn=<SliceBackward>)
# 621 25.74083709716797 tensor([0.5512, 3.0339], grad_fn=<SliceBackward>)
# 622 25.48949432373047 tensor([0.5514, 3.0325], grad_fn=<SliceBackward>)
# 623 25.53560447692871 tensor([0.5512, 3.0313], grad_fn=<SliceBackward>)
# 624 25.440387725830078 tensor([0.5510, 3.0300], grad_fn=<SliceBackward>)
# 625 25.5451602935791 tensor([0.5509, 3.0286], grad_fn=<SliceBackward>)
# 626 25.55091667175293 tensor([0.5509, 3.0274], grad_fn=<SliceBackward>)
# 627 25.474285125732422 tensor([0.5512, 3.0264], grad_fn=<SliceBackward>)
# 628 25.31640625 tensor([0.5510, 3.0254], grad_fn=<SliceBackward>)
# 629 25.575613021850586 tensor([0.5507, 3.0244], grad_fn=<SliceBackward>)
# 630 25.49121856689453 tensor([0.5505, 3.0234], grad_fn=<SliceBackward>)
# 631 25.44741439819336 tensor([0.5502, 3.0225], grad_fn=<SliceBackward>)
# 632 25.417190551757812 tensor([0.5503, 3.0216], grad_fn=<SliceBackward>)
# 633 25.370546340942383 tensor([0.5501, 3.0206], grad_fn=<SliceBackward>)
# 634 25.47296714782715 tensor([0.5499, 3.0197], grad_fn=<SliceBackward>)
# 635 25.398168563842773 tensor([0.5498, 3.0190], grad_fn=<SliceBackward>)
# 636 25.389404296875 tensor([0.5500, 3.0181], grad_fn=<SliceBackward>)
# 637 25.456045150756836 tensor([0.5503, 3.0173], grad_fn=<SliceBackward>)
# 638 25.350257873535156 tensor([0.5507, 3.0165], grad_fn=<SliceBackward>)
# 639 25.357513427734375 tensor([0.5510, 3.0157], grad_fn=<SliceBackward>)
# 640 25.334861755371094 tensor([0.5514, 3.0149], grad_fn=<SliceBackward>)
# 641 25.394123077392578 tensor([0.5517, 3.0142], grad_fn=<SliceBackward>)
# 642 25.254499435424805 tensor([0.5520, 3.0136], grad_fn=<SliceBackward>)
# 643 25.215303421020508 tensor([0.5524, 3.0130], grad_fn=<SliceBackward>)
# 644 25.243324279785156 tensor([0.5526, 3.0123], grad_fn=<SliceBackward>)
# 645 25.222137451171875 tensor([0.5527, 3.0117], grad_fn=<SliceBackward>)
# 646 25.322317123413086 tensor([0.5531, 3.0110], grad_fn=<SliceBackward>)
# 647 25.239892959594727 tensor([0.5536, 3.0105], grad_fn=<SliceBackward>)
# 648 25.461225509643555 tensor([0.5538, 3.0098], grad_fn=<SliceBackward>)
# 649 25.06908416748047 tensor([0.5539, 3.0093], grad_fn=<SliceBackward>)
# 650 25.130481719970703 tensor([0.5537, 3.0088], grad_fn=<SliceBackward>)
# 651 25.03482437133789 tensor([0.5531, 3.0083], grad_fn=<SliceBackward>)
# 652 25.189533233642578 tensor([0.5521, 3.0078], grad_fn=<SliceBackward>)
# 653 25.125526428222656 tensor([0.5506, 3.0073], grad_fn=<SliceBackward>)
# 654 25.069446563720703 tensor([0.5486, 3.0069], grad_fn=<SliceBackward>)
# 655 25.069217681884766 tensor([0.5465, 3.0064], grad_fn=<SliceBackward>)
# 656 25.06363868713379 tensor([0.5447, 3.0059], grad_fn=<SliceBackward>)
# 657 25.000179290771484 tensor([0.5431, 3.0054], grad_fn=<SliceBackward>)
# 658 24.83111000061035 tensor([0.5412, 3.0051], grad_fn=<SliceBackward>)
# 659 25.009916305541992 tensor([0.5393, 3.0048], grad_fn=<SliceBackward>)
# 660 24.78675651550293 tensor([0.5374, 3.0045], grad_fn=<SliceBackward>)
# 661 24.94324493408203 tensor([0.5354, 3.0041], grad_fn=<SliceBackward>)
# 662 24.777114868164062 tensor([0.5334, 3.0037], grad_fn=<SliceBackward>)
# 663 24.75959587097168 tensor([0.5317, 3.0033], grad_fn=<SliceBackward>)
# 664 25.080745697021484 tensor([0.5300, 3.0029], grad_fn=<SliceBackward>)
# ...
# 784 21.026206970214844 tensor([1.9020, 1.8897], grad_fn=<SliceBackward>)
# 785 21.069761276245117 tensor([1.9026, 1.8887], grad_fn=<SliceBackward>)
# 786 21.12001609802246 tensor([1.9031, 1.8878], grad_fn=<SliceBackward>)
# 787 20.99750518798828 tensor([1.9035, 1.8869], grad_fn=<SliceBackward>)
# 788 21.098552703857422 tensor([1.9040, 1.8861], grad_fn=<SliceBackward>)
# 789 21.236772537231445 tensor([1.9046, 1.8852], grad_fn=<SliceBackward>)
# 790 21.047996520996094 tensor([1.9052, 1.8844], grad_fn=<SliceBackward>)
# 791 21.06570053100586 tensor([1.9058, 1.8836], grad_fn=<SliceBackward>)
# 792 21.10906982421875 tensor([1.9061, 1.8829], grad_fn=<SliceBackward>)
# 793 21.124643325805664 tensor([1.9066, 1.8823], grad_fn=<SliceBackward>)
# 794 20.984973907470703 tensor([1.9069, 1.8818], grad_fn=<SliceBackward>)
# 795 21.208160400390625 tensor([1.9073, 1.8811], grad_fn=<SliceBackward>)
# 796 21.169933319091797 tensor([1.9076, 1.8805], grad_fn=<SliceBackward>)
# 797 21.263816833496094 tensor([1.9079, 1.8800], grad_fn=<SliceBackward>)
# 798 21.204744338989258 tensor([1.9080, 1.8795], grad_fn=<SliceBackward>)
# 799 21.099258422851562 tensor([1.9081, 1.8790], grad_fn=<SliceBackward>)
# 800 21.264911651611328 tensor([1.9081, 1.8785], grad_fn=<SliceBackward>)
# 801 21.20262908935547 tensor([1.9080, 1.8779], grad_fn=<SliceBackward>)
# 802 21.04214859008789 tensor([1.9077, 1.8773], grad_fn=<SliceBackward>)
# 803 20.951845169067383 tensor([1.9075, 1.8766], grad_fn=<SliceBackward>)
# 804 20.911481857299805 tensor([1.9072, 1.8759], grad_fn=<SliceBackward>)
# 805 21.257604598999023 tensor([1.9069, 1.8752], grad_fn=<SliceBackward>)
# 806 21.03400421142578 tensor([1.9066, 1.8746], grad_fn=<SliceBackward>)
# 807 21.195213317871094 tensor([1.9064, 1.8739], grad_fn=<SliceBackward>)
# 808 21.26442527770996 tensor([1.9060, 1.8733], grad_fn=<SliceBackward>)
# 809 21.287933349609375 tensor([1.9056, 1.8728], grad_fn=<SliceBackward>)
# 810 21.32489776611328 tensor([1.9053, 1.8722], grad_fn=<SliceBackward>)
# 811 21.251663208007812 tensor([1.9051, 1.8715], grad_fn=<SliceBackward>)
# 812 21.178390502929688 tensor([1.9048, 1.8705], grad_fn=<SliceBackward>)
# 813 21.33285903930664 tensor([1.9043, 1.8696], grad_fn=<SliceBackward>)
# 814 21.450138092041016 tensor([1.9038, 1.8687], grad_fn=<SliceBackward>)
# 815 21.383331298828125 tensor([1.9032, 1.8678], grad_fn=<SliceBackward>)
# 816 21.46512222290039 tensor([1.9026, 1.8670], grad_fn=<SliceBackward>)
# 817 21.365707397460938 tensor([1.9020, 1.8662], grad_fn=<SliceBackward>)
# 818 21.34955596923828 tensor([1.9013, 1.8653], grad_fn=<SliceBackward>)
# 819 21.36809539794922 tensor([1.9005, 1.8644], grad_fn=<SliceBackward>)
# 820 21.442180633544922 tensor([1.8998, 1.8633], grad_fn=<SliceBackward>)
# 821 21.443851470947266 tensor([1.8992, 1.8621], grad_fn=<SliceBackward>)
# 822 21.303680419921875 tensor([1.8987, 1.8609], grad_fn=<SliceBackward>)
# 823 21.236835479736328 tensor([1.8983, 1.8597], grad_fn=<SliceBackward>)
# 824 21.39342498779297 tensor([1.8980, 1.8586], grad_fn=<SliceBackward>)
# 825 21.385986328125 tensor([1.8975, 1.8574], grad_fn=<SliceBackward>)
# 826 21.621322631835938 tensor([1.8971, 1.8563], grad_fn=<SliceBackward>)
# 827 21.353931427001953 tensor([1.8966, 1.8552], grad_fn=<SliceBackward>)
# 828 21.253408432006836 tensor([1.8961, 1.8540], grad_fn=<SliceBackward>)
# 829 21.31629180908203 tensor([1.8956, 1.8527], grad_fn=<SliceBackward>)
# 830 21.26070213317871 tensor([1.8951, 1.8516], grad_fn=<SliceBackward>)
# 831 21.31812286376953 tensor([1.8943, 1.8503], grad_fn=<SliceBackward>)
# 832 21.286283493041992 tensor([1.8936, 1.8492], grad_fn=<SliceBackward>)
# 833 21.361465454101562 tensor([1.8931, 1.8480], grad_fn=<SliceBackward>)
# 834 21.345264434814453 tensor([1.8925, 1.8468], grad_fn=<SliceBackward>)
# 835 21.45633316040039 tensor([1.8921, 1.8454], grad_fn=<SliceBackward>)
# 836 21.301313400268555 tensor([1.8918, 1.8442], grad_fn=<SliceBackward>)
# 837 21.40892791748047 tensor([1.8913, 1.8433], grad_fn=<SliceBackward>)
# 838 21.161163330078125 tensor([1.8909, 1.8423], grad_fn=<SliceBackward>)
# 839 21.272655487060547 tensor([1.8905, 1.8412], grad_fn=<SliceBackward>)
# 840 21.384614944458008 tensor([1.8901, 1.8401], grad_fn=<SliceBackward>)
# 841 21.26189422607422 tensor([1.8898, 1.8390], grad_fn=<SliceBackward>)
# 842 21.23564338684082 tensor([1.8896, 1.8378], grad_fn=<SliceBackward>)
# 843 21.343116760253906 tensor([1.8892, 1.8368], grad_fn=<SliceBackward>)
# 844 21.20427703857422 tensor([1.8890, 1.8357], grad_fn=<SliceBackward>)
# 845 21.283870697021484 tensor([1.8885, 1.8346], grad_fn=<SliceBackward>)
# 846 21.409908294677734 tensor([1.8882, 1.8334], grad_fn=<SliceBackward>)
# 847 21.163034439086914 tensor([1.8880, 1.8323], grad_fn=<SliceBackward>)
# 848 21.304344177246094 tensor([1.8879, 1.8312], grad_fn=<SliceBackward>)
# 849 21.33588409423828 tensor([1.8876, 1.8301], grad_fn=<SliceBackward>)
# 850 21.23301887512207 tensor([1.8873, 1.8289], grad_fn=<SliceBackward>)
# 851 21.168119430541992 tensor([1.8871, 1.8277], grad_fn=<SliceBackward>)
# 852 21.24323272705078 tensor([1.8865, 1.8265], grad_fn=<SliceBackward>)
# 853 21.255720138549805 tensor([1.8858, 1.8254], grad_fn=<SliceBackward>)
# 854 21.18752670288086 tensor([1.8852, 1.8243], grad_fn=<SliceBackward>)
# 855 21.258560180664062 tensor([1.8848, 1.8232], grad_fn=<SliceBackward>)
# 856 21.129745483398438 tensor([1.8842, 1.8222], grad_fn=<SliceBackward>)
# 857 21.3056640625 tensor([1.8835, 1.8214], grad_fn=<SliceBackward>)
# 858 21.245376586914062 tensor([1.8829, 1.8207], grad_fn=<SliceBackward>)
# 859 21.14098358154297 tensor([1.8824, 1.8201], grad_fn=<SliceBackward>)
# 860 21.18246078491211 tensor([1.8817, 1.8197], grad_fn=<SliceBackward>)
# 861 21.213062286376953 tensor([1.8810, 1.8194], grad_fn=<SliceBackward>)
# 862 21.052467346191406 tensor([1.8805, 1.8192], grad_fn=<SliceBackward>)
# 863 20.997879028320312 tensor([1.8800, 1.8188], grad_fn=<SliceBackward>)
# 864 21.164440155029297 tensor([1.8794, 1.8182], grad_fn=<SliceBackward>)
# 865 20.983280181884766 tensor([1.8788, 1.8176], grad_fn=<SliceBackward>)
# 866 21.03094482421875 tensor([1.8781, 1.8171], grad_fn=<SliceBackward>)
# 867 21.11791229248047 tensor([1.8776, 1.8165], grad_fn=<SliceBackward>)
# 868 21.056446075439453 tensor([1.8771, 1.8160], grad_fn=<SliceBackward>)
# 869 20.939605712890625 tensor([1.8765, 1.8156], grad_fn=<SliceBackward>)
# 870 21.002586364746094 tensor([1.8758, 1.8153], grad_fn=<SliceBackward>)
# 871 21.046905517578125 tensor([1.8751, 1.8148], grad_fn=<SliceBackward>)
# 872 20.962753295898438 tensor([1.8745, 1.8142], grad_fn=<SliceBackward>)
# 873 20.771377563476562 tensor([1.8739, 1.8137], grad_fn=<SliceBackward>)
# 874 20.75290298461914 tensor([1.8732, 1.8130], grad_fn=<SliceBackward>)
# 875 20.833721160888672 tensor([1.8724, 1.8121], grad_fn=<SliceBackward>)
# 876 20.707651138305664 tensor([1.8715, 1.8114], grad_fn=<SliceBackward>)
# 877 20.77529525756836 tensor([1.8712, 1.8108], grad_fn=<SliceBackward>)
# 878 20.787872314453125 tensor([1.8709, 1.8103], grad_fn=<SliceBackward>)
# 879 20.72028160095215 tensor([1.8705, 1.8098], grad_fn=<SliceBackward>)
# 880 20.81805419921875 tensor([1.8700, 1.8093], grad_fn=<SliceBackward>)
# 881 20.99695587158203 tensor([1.8695, 1.8088], grad_fn=<SliceBackward>)
# 882 20.884788513183594 tensor([1.8692, 1.8085], grad_fn=<SliceBackward>)
# 883 20.94704818725586 tensor([1.8687, 1.8083], grad_fn=<SliceBackward>)
# 884 21.18999481201172 tensor([1.8684, 1.8081], grad_fn=<SliceBackward>)
# 885 20.91408920288086 tensor([1.8682, 1.8078], grad_fn=<SliceBackward>)
# 886 20.878097534179688 tensor([1.8680, 1.8075], grad_fn=<SliceBackward>)
# 887 21.15904998779297 tensor([1.8679, 1.8073], grad_fn=<SliceBackward>)
# 888 20.918960571289062 tensor([1.8678, 1.8069], grad_fn=<SliceBackward>)
# 889 20.810001373291016 tensor([1.8675, 1.8067], grad_fn=<SliceBackward>)
# 890 20.96429443359375 tensor([1.8674, 1.8064], grad_fn=<SliceBackward>)
# 891 21.01360511779785 tensor([1.8673, 1.8062], grad_fn=<SliceBackward>)
# 892 21.04998779296875 tensor([1.8671, 1.8061], grad_fn=<SliceBackward>)
# 893 21.0272216796875 tensor([1.8666, 1.8060], grad_fn=<SliceBackward>)
# 894 20.94525146484375 tensor([1.8662, 1.8061], grad_fn=<SliceBackward>)
# 895 20.978530883789062 tensor([1.8657, 1.8061], grad_fn=<SliceBackward>)
# 896 20.880430221557617 tensor([1.8652, 1.8060], grad_fn=<SliceBackward>)
# 897 20.90718650817871 tensor([1.8647, 1.8061], grad_fn=<SliceBackward>)
# 898 21.013290405273438 tensor([1.8643, 1.8061], grad_fn=<SliceBackward>)
# 899 20.794837951660156 tensor([1.8641, 1.8061], grad_fn=<SliceBackward>)
# 900 20.78110122680664 tensor([1.8635, 1.8059], grad_fn=<SliceBackward>)
# 901 20.69232177734375 tensor([1.8631, 1.8058], grad_fn=<SliceBackward>)
# 902 20.68633460998535 tensor([1.8627, 1.8059], grad_fn=<SliceBackward>)
# 903 20.660438537597656 tensor([1.8623, 1.8060], grad_fn=<SliceBackward>)
# 904 20.72919464111328 tensor([1.8618, 1.8061], grad_fn=<SliceBackward>)
# 905 20.4326171875 tensor([1.8615, 1.8061], grad_fn=<SliceBackward>)
# 906 20.575960159301758 tensor([1.8610, 1.8061], grad_fn=<SliceBackward>)
# 907 20.591976165771484 tensor([1.8607, 1.8060], grad_fn=<SliceBackward>)
# 908 20.550697326660156 tensor([1.8606, 1.8061], grad_fn=<SliceBackward>)
# 909 20.476428985595703 tensor([1.8605, 1.8062], grad_fn=<SliceBackward>)
# 910 20.58411407470703 tensor([1.8604, 1.8064], grad_fn=<SliceBackward>)
# 911 20.65119171142578 tensor([1.8602, 1.8065], grad_fn=<SliceBackward>)
# 912 20.722362518310547 tensor([1.8600, 1.8065], grad_fn=<SliceBackward>)
# 913 20.556102752685547 tensor([1.8597, 1.8064], grad_fn=<SliceBackward>)
# 914 20.618873596191406 tensor([1.8592, 1.8063], grad_fn=<SliceBackward>)
# 915 20.77143096923828 tensor([1.8588, 1.8061], grad_fn=<SliceBackward>)
# 916 20.511566162109375 tensor([1.8586, 1.8060], grad_fn=<SliceBackward>)
# 917 20.648115158081055 tensor([1.8583, 1.8058], grad_fn=<SliceBackward>)
# 918 20.610538482666016 tensor([1.8581, 1.8055], grad_fn=<SliceBackward>)
# 919 20.362468719482422 tensor([1.8579, 1.8053], grad_fn=<SliceBackward>)
# 920 20.821998596191406 tensor([1.8577, 1.8050], grad_fn=<SliceBackward>)
# 921 20.458391189575195 tensor([1.8573, 1.8049], grad_fn=<SliceBackward>)
# 922 20.530656814575195 tensor([1.8566, 1.8047], grad_fn=<SliceBackward>)
# 923 20.283838272094727 tensor([1.8559, 1.8047], grad_fn=<SliceBackward>)
# 924 20.504432678222656 tensor([1.8552, 1.8044], grad_fn=<SliceBackward>)
# 925 20.530426025390625 tensor([1.8545, 1.8044], grad_fn=<SliceBackward>)
# 926 20.186391830444336 tensor([1.8540, 1.8044], grad_fn=<SliceBackward>)
# 927 20.32369613647461 tensor([1.8534, 1.8046], grad_fn=<SliceBackward>)
# 928 20.43340301513672 tensor([1.8527, 1.8048], grad_fn=<SliceBackward>)
# 929 20.42743492126465 tensor([1.8522, 1.8052], grad_fn=<SliceBackward>)
# 930 20.446773529052734 tensor([1.8518, 1.8058], grad_fn=<SliceBackward>)
# 931 20.462129592895508 tensor([1.8515, 1.8062], grad_fn=<SliceBackward>)
# 932 20.270883560180664 tensor([1.8512, 1.8066], grad_fn=<SliceBackward>)
# 933 20.3331298828125 tensor([1.8510, 1.8070], grad_fn=<SliceBackward>)
# 934 20.384380340576172 tensor([1.8511, 1.8076], grad_fn=<SliceBackward>)
# 935 20.362499237060547 tensor([1.8513, 1.8081], grad_fn=<SliceBackward>)
# 936 20.391443252563477 tensor([1.8513, 1.8088], grad_fn=<SliceBackward>)
# 937 20.286739349365234 tensor([1.8514, 1.8091], grad_fn=<SliceBackward>)
# 938 20.385360717773438 tensor([1.8518, 1.8095], grad_fn=<SliceBackward>)
# 939 20.266681671142578 tensor([1.8521, 1.8096], grad_fn=<SliceBackward>)
# 940 20.337299346923828 tensor([1.8522, 1.8098], grad_fn=<SliceBackward>)
# 941 20.17128562927246 tensor([1.8522, 1.8101], grad_fn=<SliceBackward>)
# 942 20.137876510620117 tensor([1.8520, 1.8105], grad_fn=<SliceBackward>)
# 943 20.246912002563477 tensor([1.8519, 1.8107], grad_fn=<SliceBackward>)
# 944 20.191326141357422 tensor([1.8514, 1.8111], grad_fn=<SliceBackward>)
# 945 20.314674377441406 tensor([1.8508, 1.8114], grad_fn=<SliceBackward>)
# 946 20.31252670288086 tensor([1.8503, 1.8115], grad_fn=<SliceBackward>)
# 947 20.257770538330078 tensor([1.8495, 1.8117], grad_fn=<SliceBackward>)
# 948 20.20987319946289 tensor([1.8487, 1.8119], grad_fn=<SliceBackward>)
# 949 20.18547821044922 tensor([1.8480, 1.8121], grad_fn=<SliceBackward>)
# 950 20.117530822753906 tensor([1.8472, 1.8124], grad_fn=<SliceBackward>)
# 951 20.112628936767578 tensor([1.8463, 1.8126], grad_fn=<SliceBackward>)
# 952 20.247774124145508 tensor([1.8457, 1.8127], grad_fn=<SliceBackward>)
# 953 20.126462936401367 tensor([1.8452, 1.8128], grad_fn=<SliceBackward>)
# 954 20.121761322021484 tensor([1.8445, 1.8129], grad_fn=<SliceBackward>)
# 955 20.17190933227539 tensor([1.8440, 1.8129], grad_fn=<SliceBackward>)
# 956 20.255207061767578 tensor([1.8435, 1.8130], grad_fn=<SliceBackward>)
# 957 20.061817169189453 tensor([1.8431, 1.8132], grad_fn=<SliceBackward>)
# 958 20.162353515625 tensor([1.8428, 1.8132], grad_fn=<SliceBackward>)
# 959 20.234209060668945 tensor([1.8421, 1.8132], grad_fn=<SliceBackward>)
# 960 20.24152374267578 tensor([1.8416, 1.8132], grad_fn=<SliceBackward>)
# 961 20.205963134765625 tensor([1.8413, 1.8131], grad_fn=<SliceBackward>)
# 962 20.01032257080078 tensor([1.8409, 1.8132], grad_fn=<SliceBackward>)
# 963 20.174367904663086 tensor([1.8406, 1.8132], grad_fn=<SliceBackward>)
# 964 20.150442123413086 tensor([1.8402, 1.8133], grad_fn=<SliceBackward>)
# 965 20.16720199584961 tensor([1.8400, 1.8132], grad_fn=<SliceBackward>)
# 966 20.13852310180664 tensor([1.8397, 1.8131], grad_fn=<SliceBackward>)
# 967 20.079830169677734 tensor([1.8393, 1.8130], grad_fn=<SliceBackward>)
# 968 20.142353057861328 tensor([1.8393, 1.8130], grad_fn=<SliceBackward>)
# 969 20.172447204589844 tensor([1.8392, 1.8130], grad_fn=<SliceBackward>)
# 970 20.235370635986328 tensor([1.8390, 1.8130], grad_fn=<SliceBackward>)
# 971 20.370393753051758 tensor([1.8386, 1.8131], grad_fn=<SliceBackward>)
# 972 20.21556854248047 tensor([1.8381, 1.8134], grad_fn=<SliceBackward>)
# 973 20.363494873046875 tensor([1.8375, 1.8137], grad_fn=<SliceBackward>)
# 974 20.267520904541016 tensor([1.8369, 1.8140], grad_fn=<SliceBackward>)
# 975 20.208110809326172 tensor([1.8363, 1.8143], grad_fn=<SliceBackward>)
# 976 20.124366760253906 tensor([1.8356, 1.8147], grad_fn=<SliceBackward>)
# 977 19.948776245117188 tensor([1.8351, 1.8151], grad_fn=<SliceBackward>)
# 978 20.403076171875 tensor([1.8342, 1.8155], grad_fn=<SliceBackward>)
# 979 20.330406188964844 tensor([1.8332, 1.8158], grad_fn=<SliceBackward>)
# 980 20.564420700073242 tensor([1.8325, 1.8160], grad_fn=<SliceBackward>)
# 981 20.391521453857422 tensor([1.8318, 1.8163], grad_fn=<SliceBackward>)
# 982 20.597457885742188 tensor([1.8310, 1.8167], grad_fn=<SliceBackward>)
# 983 20.58579444885254 tensor([1.8303, 1.8173], grad_fn=<SliceBackward>)
# 984 20.61334991455078 tensor([1.8297, 1.8178], grad_fn=<SliceBackward>)
# 985 20.52458381652832 tensor([1.8291, 1.8183], grad_fn=<SliceBackward>)
# 986 20.549575805664062 tensor([1.8287, 1.8189], grad_fn=<SliceBackward>)
# 987 20.618167877197266 tensor([1.8281, 1.8195], grad_fn=<SliceBackward>)
# 988 20.562082290649414 tensor([1.8275, 1.8202], grad_fn=<SliceBackward>)
# 989 20.551748275756836 tensor([1.8270, 1.8211], grad_fn=<SliceBackward>)
# 990 20.58708953857422 tensor([1.8262, 1.8221], grad_fn=<SliceBackward>)
# 991 20.63655662536621 tensor([1.8257, 1.8231], grad_fn=<SliceBackward>)
# 992 20.600791931152344 tensor([1.8252, 1.8240], grad_fn=<SliceBackward>)
# 993 20.680404663085938 tensor([1.8247, 1.8247], grad_fn=<SliceBackward>)
# 994 20.54619026184082 tensor([1.8242, 1.8254], grad_fn=<SliceBackward>)
# 995 20.67101287841797 tensor([1.8238, 1.8261], grad_fn=<SliceBackward>)
# 996 20.505428314208984 tensor([1.8234, 1.8268], grad_fn=<SliceBackward>)
# 997 20.64327621459961 tensor([1.8229, 1.8273], grad_fn=<SliceBackward>)
# 998 20.722400665283203 tensor([1.8225, 1.8279], grad_fn=<SliceBackward>)
# 999 20.622955322265625 tensor([1.8222, 1.8286], grad_fn=<SliceBackward>)
# 314.2334899902344
# 20.622955322265625
# tensor([ 1.8220,  1.8291,  1.1881,  1.8717,  1.1233,  2.1139,  0.7732, -1.7994,
#          3.0244,  1.5237, -0.3286,  2.6667,  2.2453,  4.2315],
#        requires_grad=True)
# 5 [0.756578947368421, 0.7763157894736842, 0.7697368421052632, 0.7828947368421053, 0.7697368421052632]

# %%
print(test_acc)
test_acc = np.array(test_acc)
print('{}({})'.format(test_acc.mean(), test_acc.std()))
# Out:
# [0.756578947368421, 0.7763157894736842, 0.7697368421052632, 0.7828947368421053, 0.7697368421052632]
# 0.7710526315789474(0.008727959974619493)
